# %% [markdown]
# # 3. Model training

# %%
# execute once and comment out afterwards again

# %pip uninstall -y numpy albumentations opencv-python-headless opencv-python

# %pip install "opencv-python-headless==4.9.0.80"

# %pip install --no-deps -r requirements.txt

# %pip install albumentations
# %pip show albumentations

# TODO in die requirements.txt packen
# TODO conda env wäre am besten

# %%
from pathlib import Path
from torch.utils.data import DataLoader, Dataset, random_split
from skimage.io import imread, imsave
import numpy as np
import albumentations as A
from albumentations.pytorch import ToTensorV2  # Used to convert to PyTorch tensors
import csv
import warnings

# %%
with open(Path('./image_preprocessing/image_data.csv'), newline='') as f:
    reader = csv.DictReader(f)
    row = next(reader)
    img_size = int(row['img_size'])

# %% [markdown]
# ### 3.1. Augmentation variant 1 |

# %%
# Block 1

warnings.filterwarnings("ignore", category=UserWarning, module="skimage")

preprocessed_train_images = Path('image_preprocessing') / 'preprocessed_data' / 'preprocessed_train_images'
preprocessed_train_masks  = Path('image_preprocessing') / 'preprocessed_data' / 'preprocessed_train_masks'

preprocessed_test_images  = Path('image_preprocessing') / 'preprocessed_data' / 'preprocessed_test_images'
preprocessed_test_masks   = Path('image_preprocessing') / 'preprocessed_data' / 'preprocessed_test_masks'


class SegmentationDataset(Dataset):
    def __init__(self, img_dir, mask_dir=None, transform=None):
        self.img_dir = img_dir
        self.mask_dir = mask_dir
        self.transform = transform
        # Properly extract image_ids by removing suffixes like '_image', '_enhanced', '_pp'
        self.image_ids = sorted([file.stem.replace('_image', '').replace('_enhanced', '').replace('_pp', '')
                                 for file in img_dir.iterdir() if file.suffix == '.png'])

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, index):
        image_id = self.image_ids[index]

        # Attempt to load the image
        img_path = self.img_dir / f'{image_id}.png'
        if not img_path.exists():
            img_path = self.img_dir / f'{image_id}_pp_enhanced.png'

        if not img_path.exists():
            raise FileNotFoundError(f'Image not found for {image_id} at {img_path}')

        image = imread(img_path).astype(np.float32) / 255.0  # Normalize image

        if self.mask_dir:
            # Correct mask path generation to include '_mask.png'
            mask_path = self.mask_dir / f'{image_id}_mask.png'

            if not mask_path.exists():
                raise FileNotFoundError(f'Mask not found for {image_id} at {mask_path}')

            mask = imread(mask_path).astype(np.float32) / 255.0  # Normalize mask

            # Ensure mask has shape [H, W] for binary segmentation
            if mask.ndim == 2:  # If mask is [H, W], add a channel dimension
                mask = np.expand_dims(mask, axis=2)  # Convert to [H, W, 1]

            if self.transform:
                augmented = self.transform(image=image, mask=mask)
                image = augmented['image']
                mask  = augmented['mask']

                ######################################################################################################## $ not reaaaally necessary just catches a few more nuclei
                if mask.ndim == 3 and mask.shape[-1] == 1:
                    mask = np.transpose(mask, (2, 0, 1))  # Convert to [1, H, W]
                # if mask.ndim == 2:
                #     mask = mask.unsqueeze(0)                          # [H,W] -> [1,H,W]
                # elif mask.ndim == 3 and mask.shape[0] != 1 and mask.shape[-1] == 1:
                #     mask = mask.permute(2, 0, 1)                      # [H,W,1] -> [1,H,W]
                # elif mask.ndim == 3 and mask.shape[0] != 1 and mask.shape[-1] != 1:
                #     mask = mask[0:1, ...]                             # [C,H,W] -> [1,H,W]
                # mask = (mask > 0.5).float()


            return image, mask
        else:
            if self.transform:
                augmented = self.transform(image=image)
                image = augmented['image']
            return image


# Define augmentations using Albumentations
train_transform = A.Compose([
    A.Resize(img_size, img_size),
    A.RandomRotate90(),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.3),  # Elastic deformation
    A.GridDistortion(p=0.3),  # Distorts the image grid
    ToTensorV2() # transpose_mask=True)                                                                                     # big difference
])

val_transform = A.Compose([
    A.Resize(img_size, img_size),
    ToTensorV2() # transpose_mask=True)                                                                                     # big difference
])

# Define datasets with transformations
train_dataset = SegmentationDataset(img_dir=preprocessed_train_images, mask_dir=preprocessed_train_masks, transform=train_transform)
test_dataset  = SegmentationDataset(preprocessed_test_images, transform=val_transform)

# Split the dataset into training (80%) and validation (20%) sets
train_size = int(0.9 * len(train_dataset))
val_size   = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Create data loaders
train_loader = DataLoader(train_subset, batch_size=8, shuffle=True)
val_loader   = DataLoader(val_subset, batch_size=8, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Print number of images in train, validation, and test sets
print(f'Number of training images: \t{train_size}')
print(f'Number of validation images: \t{val_size}')
print(f'Number of test images: \t\t{len(test_dataset)}')
# Out:
# Number of training images: 	900
# Number of validation images: 	100
# Number of test images: 		200

# %% [markdown]
# ### 3.2. Augmentation variant 2 |

# %%
# Block 2

# Define a custom dataset class to load the images and masks
'''
class SegmentationDataset(Dataset):
    def __init__(self, img_dir, mask_dir=None, transform=None):
        self.img_dir = img_dir
        self.mask_dir = mask_dir
        self.transform = transform
        # Properly extract image_ids by removing suffixes like '_image', '_enhanced', '_pp'
        self.image_ids = sorted([file.stem.replace('_image', '').replace('_enhanced', '').replace('_pp', '')
                                 for file in img_dir.iterdir() if file.suffix == '.png'])

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]

        # Attempt to load the image
        img_path = self.img_dir / f'{image_id}.png'
        if not img_path.exists():
            img_path = self.img_dir / f'{image_id}_pp_enhanced.png'

        if not img_path.exists():
            raise FileNotFoundError(f'Image not found for {image_id} at {img_path}')

        image = imread(img_path).astype(np.float32) / 255.0  # Normalize image

        if self.mask_dir:
            mask_path = self.mask_dir / f'{image_id}_mask.png'

            if not mask_path.exists():
                raise FileNotFoundError(f'Mask not found for {image_id} at {mask_path}')

            mask = imread(mask_path).astype(np.float32) / 255.0  # Normalize mask

            # Ensure both mask and image are resized to [H, W, 1]
            if len(mask.shape) == 2:  # If mask is [H, W], add a channel dimension
                mask = np.expand_dims(mask, axis=2)  # Convert to [H, W, 1]

            if self.transform:
                augmented = self.transform(image=image, mask=mask)
                image = augmented['image']
                mask = augmented['mask']

                # Ensure mask is [1, H, W] after transformation (transpose if necessary)
                if mask.ndim == 3 and mask.shape[-1] == 1:
                    mask = np.transpose(mask, (2, 0, 1))  # Convert to [1, H, W]

            return image, mask
        else:
            if self.transform:
                augmented = self.transform(image=image)
                image = augmented['image']
            return image


train_transform = A.Compose([
    A.RandomRotate90(),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    # A.ElasticTransform()
    # A.GridDistortion()
    A.GaussianBlur(p=0.2),
    A.Resize(256, 256),
    ToTensorV2()
])


val_transform = A.Compose([
    A.Resize(256, 256),
    ToTensorV2()
])


# Define datasets with transformations
train_dataset = SegmentationDataset(img_dir=preprocessed_train_images, mask_dir=preprocessed_train_masks, transform=train_transform)
test_dataset = SegmentationDataset(preprocessed_test_images, transform=val_transform)

# Split the dataset into training (90%) and validation (10%) sets
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Create data loaders
train_loader = DataLoader(train_subset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Check if loading is correct for the training set
for images, masks in train_loader:
    # DEBUGGING: Check shape of images and masks
    print(f'Train Batch - Images Shape: \t\t{images.shape} \tMasks Shape: {masks.shape}')
    break

# Check if loading is correct for the validation set
for images, masks in val_loader:
    # DEBUGGING: Check shape of images and masks
    print(f'Validation Batch - Images Shape: \t{images.shape} \tMasks Shape: {masks.shape}')
    break
'''
# Out:
# "\nclass SegmentationDataset(Dataset):\n    def __init__(self, img_dir, mask_dir=None, transform=None):\n        self.img_dir = img_dir\n        self.mask_dir = mask_dir\n        self.transform = transform\n        # Properly extract image_ids by removing suffixes like '_image', '_enhanced', '_pp'\n        self.image_ids = sorted([file.stem.replace('_image', '').replace('_enhanced', '').replace('_pp', '')\n                                 for file in img_dir.iterdir() if file.suffix == '.png'])\n\n    def __len__(self):\n        return len(self.image_ids)\n\n    def __getitem__(self, idx):\n        image_id = self.image_ids[idx]\n\n        # Attempt to load the image\n        img_path = self.img_dir / f'{image_id}.png'\n        if not img_path.exists():\n            img_path = self.img_dir / f'{image_id}_pp_enhanced.png'\n\n        if not img_path.exists():\n            raise FileNotFoundError(f'Image not found for {image_id} at {img_path}')\n\n        image = imread(img_path).astype(np.float32) / 255.0  # Normalize image\n\n        if self.mask_dir:\n            mask_path = self.mask_dir / f'{image_id}_mask.png'\n\n            if not mask_path.exists():\n                raise FileNotFoundError(f'Mask not found for {image_id} at {mask_path}')\n\n            mask = imread(mask_path).astype(np.float32) / 255.0  # Normalize mask\n\n            # Ensure both mask and image are resized to [H, W, 1]\n            if len(mask.shape) == 2:  # If mask is [H, W], add a channel dimension\n                mask = np.expand_dims(mask, axis=2)  # Convert to [H, W, 1]\n\n            if self.transform:\n                augmented = self.transform(image=image, mask=mask)\n                image = augmented['image']\n                mask = augmented['mask']\n\n                # Ensure mask is [1, H, W] after transformation (transpose if necessary)\n                if mask.ndim == 3 and mask.shape[-1] == 1:\n                    mask = np.transpose(mask, (2, 0, 1))  # Convert to [1, H, W]\n\n            return image, mask\n        else:\n            if self.transform:\n                augmented = self.transform(image=image)\n                image = augmented['image']\n            return image\n\n\ntrain_transform = A.Compose([\n    A.RandomRotate90(),\n    A.HorizontalFlip(p=0.5),\n    A.VerticalFlip(p=0.5),\n    A.RandomBrightnessContrast(p=0.2),\n    # A.ElasticTransform()\n    # A.GridDistortion()\n    A.GaussianBlur(p=0.2),\n    A.Resize(256, 256),\n    ToTensorV2()\n])\n\n\nval_transform = A.Compose([\n    A.Resize(256, 256),\n    ToTensorV2()\n])\n\n\n# Define datasets with transformations\ntrain_dataset = SegmentationDataset(img_dir=preprocessed_train_images, mask_dir=preprocessed_train_masks, transform=train_transform)\ntest_dataset = SegmentationDataset(preprocessed_test_images, transform=val_transform)\n\n# Split the dataset into training (90%) and validation (10%) sets\ntrain_size = int(0.9 * len(train_dataset))\nval_size = len(train_dataset) - train_size\ntrain_subset, val_subset = random_split(train_dataset, [train_size, val_size])\n\n# Create data loaders\ntrain_loader = DataLoader(train_subset, batch_size=16, shuffle=True)\nval_loader = DataLoader(val_subset, batch_size=16, shuffle=False)\ntest_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)\n\n# Check if loading is correct for the training set\nfor images, masks in train_loader:\n    # DEBUGGING: Check shape of images and masks\n    print(f'Train Batch - Images Shape: \t\t{images.shape} \tMasks Shape: {masks.shape}')\n    break\n\n# Check if loading is correct for the validation set\nfor images, masks in val_loader:\n    # DEBUGGING: Check shape of images and masks\n    print(f'Validation Batch - Images Shape: \t{images.shape} \tMasks Shape: {masks.shape}')\n    break\n"

# %% [markdown]
# ### 3.3. No Augmentation and batch size reduced from 16 to 8 |

# %%
# Block 3

import torch
from torchvision import transforms

'''
# Define a custom dataset class to load the images and masks
class SegmentationDataset(Dataset):
    def __init__(self, img_dir, mask_dir=None, transform=None):
        self.img_dir = img_dir
        self.mask_dir = mask_dir
        self.transform = transform
        # Properly extract image_ids by removing suffixes like '_image', '_enhanced', '_pp'
        self.image_ids = sorted([file.stem.replace('_image', '').replace('_enhanced', '').replace('_pp', '')
                                 for file in img_dir.iterdir() if file.suffix == '.png'])

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]

        # Attempt to load the image
        img_path = self.img_dir / f'{image_id}.png'
        #print(f"Trying to load image from: {img_path}")  # Debug statement
        if not img_path.exists():
            img_path = self.img_dir / f'{image_id}_pp_enhanced.png'
            #print(f"Trying alternative path: {img_path}")  # Debug statement

        if not img_path.exists():
            raise FileNotFoundError(f'Image not found for {image_id} at {img_path}')

        #print(f"Successfully loaded image: {img_path}")  # Debug statement
        image = imread(img_path).astype(np.float32) / 255.0  # Normalize image

        # Ensure image is in the format [C, H, W] (channels, height, width)
        if image.shape[-1] == 3:  # If the image is in [H, W, C] format
            image = np.transpose(image, (2, 0, 1))  # Convert to [C, H, W]

        if self.mask_dir:
            # Correct mask path generation to include '_mask.png'
            mask_path = self.mask_dir / f'{image_id}_mask.png'

            # Print the image ID and the mask path for debugging
            #print(f"Image ID: {image_id}, Mask Path: {mask_path}")

            if not mask_path.exists():
                raise FileNotFoundError(f"Mask not found for {image_id} at {mask_path}")

            #print(f"Successfully loaded mask: {mask_path}")  # Debug statement
            mask = imread(mask_path).astype(np.float32) / 255.0  # Normalize mask

            # Ensure mask has shape [1, H, W] for binary segmentation
            if len(mask.shape) == 2:  # If mask is [H, W], add a channel dimension
                mask = np.expand_dims(mask, axis=0)  # Convert to [1, H, W]

            # Apply transformations (if any)
            if self.transform:
                image = torch.tensor(image, dtype=torch.float32)  # Ensure image is float32
                mask = torch.tensor(mask, dtype=torch.float32)    # Ensure mask is float32

            return image, mask
        else:
            if self.transform:
                image = torch.tensor(image, dtype=torch.float32)  # Ensure image is float32
            return image


# Define transformations (if needed)
train_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor
])

val_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor
])

# Define datasets
train_dataset = SegmentationDataset(img_dir=preprocessed_train_images, mask_dir=preprocessed_train_masks, transform=train_transform)
test_dataset = SegmentationDataset(preprocessed_test_images, transform=val_transform)

# Split the dataset into training (80%) and validation (20%) sets
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Create data loaders
train_loader = DataLoader(train_subset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=8, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Check if loading is correct for the training set
for images, masks in train_loader:
    #print(f"Train Batch - Images Shape: {images.shape}, Masks Shape: {masks.shape}")
    break

# Check if loading is correct for the validation set
for images, masks in val_loader:
    #print(f"Validation Batch - Images Shape: {images.shape}, Masks Shape: {masks.shape}")
    break

# Check if loading is correct for the test set (without masks)
for images in test_loader:
    #print(f"Test Batch - Images Shape: {images.shape}")
    break


# Print number of images in train, validation, and test sets
print(f'Number of training images: \t{train_size}')
print(f'Number of validation images: \t{val_size}')
print(f'Number of test images: \t\t{len(test_dataset)}')
'''
# Out:
# '\n# Define a custom dataset class to load the images and masks\nclass SegmentationDataset(Dataset):\n    def __init__(self, img_dir, mask_dir=None, transform=None):\n        self.img_dir = img_dir\n        self.mask_dir = mask_dir\n        self.transform = transform\n        # Properly extract image_ids by removing suffixes like \'_image\', \'_enhanced\', \'_pp\'\n        self.image_ids = sorted([file.stem.replace(\'_image\', \'\').replace(\'_enhanced\', \'\').replace(\'_pp\', \'\')\n                                 for file in img_dir.iterdir() if file.suffix == \'.png\'])\n\n    def __len__(self):\n        return len(self.image_ids)\n\n    def __getitem__(self, idx):\n        image_id = self.image_ids[idx]\n\n        # Attempt to load the image\n        img_path = self.img_dir / f\'{image_id}.png\'\n        #print(f"Trying to load image from: {img_path}")  # Debug statement\n        if not img_path.exists():\n            img_path = self.img_dir / f\'{image_id}_pp_enhanced.png\'\n            #print(f"Trying alternative path: {img_path}")  # Debug statement\n\n        if not img_path.exists():\n            raise FileNotFoundError(f\'Image not found for {image_id} at {img_path}\')\n\n        #print(f"Successfully loaded image: {img_path}")  # Debug statement\n        image = imread(img_path).astype(np.float32) / 255.0  # Normalize image\n\n        # Ensure image is in the format [C, H, W] (channels, height, width)\n        if image.shape[-1] == 3:  # If the image is in [H, W, C] format\n            image = np.transpose(image, (2, 0, 1))  # Convert to [C, H, W]\n\n        if self.mask_dir:\n            # Correct mask path generation to include \'_mask.png\'\n            mask_path = self.mask_dir / f\'{image_id}_mask.png\'\n\n            # Print the image ID and the mask path for debugging\n            #print(f"Image ID: {image_id}, Mask Path: {mask_path}")\n\n            if not mask_path.exists():\n                raise FileNotFoundError(f"Mask not found for {image_id} at {mask_path}")\n\n            #print(f"Successfully loaded mask: {mask_path}")  # Debug statement\n            mask = imread(mask_path).astype(np.float32) / 255.0  # Normalize mask\n\n            # Ensure mask has shape [1, H, W] for binary segmentation\n            if len(mask.shape) == 2:  # If mask is [H, W], add a channel dimension\n                mask = np.expand_dims(mask, axis=0)  # Convert to [1, H, W]\n\n            # Apply transformations (if any)\n            if self.transform:\n                image = torch.tensor(image, dtype=torch.float32)  # Ensure image is float32\n                mask = torch.tensor(mask, dtype=torch.float32)    # Ensure mask is float32\n\n            return image, mask\n        else:\n            if self.transform:\n                image = torch.tensor(image, dtype=torch.float32)  # Ensure image is float32\n            return image\n\n\n# Define transformations (if needed)\ntrain_transform = transforms.Compose([\n    transforms.ToTensor(),  # Convert image to tensor\n])\n\nval_transform = transforms.Compose([\n    transforms.ToTensor(),  # Convert image to tensor\n])\n\n# Define datasets\ntrain_dataset = SegmentationDataset(img_dir=preprocessed_train_images, mask_dir=preprocessed_train_masks, transform=train_transform)\ntest_dataset = SegmentationDataset(preprocessed_test_images, transform=val_transform)\n\n# Split the dataset into training (80%) and validation (20%) sets\ntrain_size = int(0.9 * len(train_dataset))\nval_size = len(train_dataset) - train_size\ntrain_subset, val_subset = random_split(train_dataset, [train_size, val_size])\n\n# Create data loaders\ntrain_loader = DataLoader(train_subset, batch_size=8, shuffle=True)\nval_loader = DataLoader(val_subset, batch_size=8, shuffle=False)\ntest_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)\n\n# Check if loading is correct for the training set\nfor images, masks in train_loader:\n    #print(f"Train Batch - Images Shape: {images.shape}, Masks Shape: {masks ...

# %% [markdown]
# ### 3.4. Unet++ with NO attention |

# %%
# Block 4

import torch.nn as nn
import torch.nn.functional as F


# Define U-Net++ model architecture
class UNetPlusPlus(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNetPlusPlus, self).__init__()

        # Encoder path
        self.encoder1 = self.double_conv(in_channels, 64)
        self.encoder2 = self.double_conv(64, 128)
        self.encoder3 = self.double_conv(128, 256)
        self.encoder4 = self.double_conv(256, 512)

        # Bottleneck
        self.bottleneck = self.double_conv(512, 1024)

        # Decoder path with nested convolutions (UNet++)
        self.upconv4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.decoder4_1 = self.double_conv(1024, 512)
        self.decoder4_2 = self.double_conv(1024, 512)

        self.upconv3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.decoder3_1 = self.double_conv(512, 256)
        self.decoder3_2 = self.double_conv(512, 256)
        self.decoder3_3 = self.double_conv(512, 256)

        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.decoder2_1 = self.double_conv(256, 128)
        self.decoder2_2 = self.double_conv(256, 128)
        self.decoder2_3 = self.double_conv(256, 128)
        self.decoder2_4 = self.double_conv(256, 128)

        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.decoder1_1 = self.double_conv(128, 64)
        self.decoder1_2 = self.double_conv(128, 64)
        self.decoder1_3 = self.double_conv(128, 64)
        self.decoder1_4 = self.double_conv(128, 64)
        self.decoder1_5 = self.double_conv(128, 64)

        # Output layer
        self.out_conv = nn.Conv2d(64, out_channels, kernel_size=1)

    def double_conv(self, in_channels, out_channels, dropout_prob=0.1):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ELU(inplace=True),  # Switch to ELU activation
            nn.Dropout(dropout_prob),  # Add dropout
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ELU(inplace=True),  # Switch to ELU activation
        )

    def forward(self, x):
        # Encoder path
        e1 = self.encoder1(x)
        e2 = self.encoder2(F.max_pool2d(e1, 2))
        e3 = self.encoder3(F.max_pool2d(e2, 2))
        e4 = self.encoder4(F.max_pool2d(e3, 2))

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, 2))

        # Decoder path with nested convolutions (UNet++)
        d4_1 = self.upconv4(b)
        d4_1 = torch.cat([d4_1, e4], dim=1)
        d4_1 = self.decoder4_1(d4_1)

        d3_1 = self.upconv3(d4_1)
        d3_1 = torch.cat([d3_1, e3], dim=1)
        d3_1 = self.decoder3_1(d3_1)

        d2_1 = self.upconv2(d3_1)
        d2_1 = torch.cat([d2_1, e2], dim=1)
        d2_1 = self.decoder2_1(d2_1)

        d1_1 = self.upconv1(d2_1)
        d1_1 = torch.cat([d1_1, e1], dim=1)
        d1_1 = self.decoder1_1(d1_1)

        logit = self.out_conv(d1_1)                                                                                     # logit vs sigmoid function
        logit = F.interpolate(logit, size=(x.size(2), x.size(3)), mode='bilinear', align_corners=False)                 # it's unwise to turn the results immidiatly into sigmoids, as functions like binary_cross_entropy_with_logits calculate a sigmoid internaly
        return logit                                                                                                    # therefore: return raw scores instead of probabilities as they can be calculated when needed 

        # Output
        # out = torch.sigmoid(self.out_conv(d1_1))  # Use sigmoid for binary segmentation
        # # Resize output to match the size of the input masks
        # out = F.interpolate(out, size=(x.size(2), x.size(3)), mode='bilinear', align_corners=False)
        # return out

# %% [markdown]
# # 4. Training and Validation

# %% [markdown]
# ### 4.1. Training and Validation Unet++ NO attention |

# %%
# Block 5
import random
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

results = Path('results')
saved_models = results / 'saved_models'
Path(saved_models).mkdir(parents=True, exist_ok=True)


# Initialize weights using He initialization
def init_weights(m):
    if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight, nonlinearity='relu')

# Set a seed for reproducibility
seed = 777
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)
random.seed(seed)

# Instantiate the U-Net++ model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = UNetPlusPlus(in_channels=3, out_channels=1).to(device)
model.to(device)

model.apply(init_weights)

'''
# Focal Loss for class imbalance
# class FocalLoss(nn.Module):                                                                                           # legacy
#     def __init__(self, alpha=1, gamma=2):
#         super(FocalLoss, self).__init__()
#         self.alpha = alpha
#         self.gamma = gamma

#     def forward(self, inputs, targets):
#         BCE_loss = nn.BCEWithLogitsLoss()(inputs, targets)
#         pt = torch.exp(-BCE_loss)
#         F_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
#         return F_loss


# Dice loss                                                                                                             # legacy
# def dice_loss(preds, masks, smooth=1):
#     intersection = (preds * masks).sum()
#     dice = (2. * intersection + smooth) / (preds.sum() + masks.sum() + smooth)
#     return 1 - dice


# Dice coefficient function                                                                                             # legacy
# def dice_coefficient(preds, masks, smooth=1):
#     preds = torch.sigmoid(preds) > 0.5  # Threshold predictions at 0.5
#     preds = preds.float()
#     masks = masks.float()
#     intersection = (preds * masks).sum(dim=[1, 2])
#     dice = (2. * intersection + smooth) / (preds.sum(dim=[1, 2]) + masks.sum(dim=[1, 2]) + smooth)
#     return dice.mean()
'''

def focal_bce_with_logits(logits, targets, alpha=0.25, gamma=2.0):
    """
    This function essentially does the same as forward(self, inputs, targets) you can see right above.
    I switched BCEWithLogitsLoss() with binary_cross_entropy_with_logits() as it is slightly less bloated and can be
    done in a single line. 
    The important changes are:
    reduction='none' - needed to get the error per pixel and not for the entire image
    mean()           - a scalar is needed in the training logic, so the results need to be averaged
    """
    bce = F.binary_cross_entropy_with_logits(logits, targets, reduction='none')                                         # calculate bce (binary cross entropy) based on logits and targets (masks). bce calculates an error value per pixel                            
    p   = torch.sigmoid(logits)                                                                                         # 
    pt  = torch.where(targets==1, p, 1-p) # cross entropy loss                                                          # probabality of bce being correct | ground truth mask
    w   = alpha * targets * (1 - pt).pow(gamma)
    return (w * bce).mean()                                                                                             # mean is standard in BCEWithLogitsLoss but not in binary_cross_entropy_with_logits


# Dice coefficient function
def dice_coefficient(logits, targets, smooth=1.0):
    """
    It's the same function as before, I just adjusted the names to be consistent with the other changes and changed
    the dim to [1,2,3] as we have shape [B, C, H, W] we need to sum over C, H and W.

    The dice coefficient (or Sørensen-Dice index) meassures the similarity between two datasets. It's formular is:

        Dice Coefficient = 2 * |X ∩ Y| / |X| + |Y|
    
        with X and Y being the sets of pixels in those images. In other words, the formular can be written like:
        
        Dice Coefficient = 2 * Area of Overlap / Total Number of Pixels in Both Segmentations

    """
    p = (torch.sigmoid(logits) > 0.5).float()
    targets = targets.float()
    intersection = (p * targets).sum(dim=[1,2,3])
    return ((2 * intersection + smooth) / (p.sum(dim=[1,2,3]) + targets.sum(dim=[1,2,3]) + smooth)).mean()


def dice_loss(logits, targets, smooth=1.0):
    """
    basically the same as dice_loss but the sigmoid has to be calculated first and changed dim to [1,2,3] too, rather
    than leaving it out. In the end both works, but with dim=[1,2,3] the results seem to be slightly better 
    """
    p = torch.sigmoid(logits)
    intersection = (p * targets).sum(dim=[1,2,3])
    return (1 - (2 * intersection + smooth) / (p.sum(dim=[1,2,3]) + targets.sum(dim=[1,2,3]) + smooth)).mean()

# Combined BCE and Dice loss with Focal Loss
def combined_loss(logits, targets, bce_weight=0.5):
    """
    Adjusted to focal_bce_with_logits
    """
    return bce_weight * focal_bce_with_logits(logits, targets) + (1 - bce_weight) * dice_loss(logits, targets)

# Define optimizer with weight decay (L2 regularization)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)                                           # Weight decay 

# scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=2, factor=0.5, verbose=True)                            # would have been my next step in trying to improve cellseg if OneCycleLR wouldn't have worked
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=8e-4,
    steps_per_epoch=len(train_loader),
    epochs=500
)

# Early stopping parameters
patience = 30
best_val_loss = float('inf')
best_train_dice = float('-inf')  # Initialize for best training dice score
patience_counter = 0

# Store losses and metrics for visualization
train_losses = []
val_losses = []
train_dice_scores = []
val_dice_scores = []

# Training loop
epochs = 500  # hier

loss_list = []
val_loss_list = []

for epoch in range(epochs):
    model.train()
    train_loss = 0
    train_dice = 0
    num_train_samples = 0  # Initialize for normalizing across all examples
    for images, masks in train_loader:
        images = images.to(device).float()
        masks  = masks.to(device).float()

        # Forward pass
        logits = model(images)
        loss   = combined_loss(logits, masks)
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)                                                # gradient clipping, not necessary its more like a safety feature

        optimizer.step()
        scheduler.step()

        # Track the number of examples
        batch_size = images.size(0)
        num_train_samples += batch_size

        # Accumulate loss and dice score
        train_loss += loss.item() * batch_size  # Multiply by batch size for proper normalization
        train_dice += dice_coefficient(logits, masks).item() * batch_size

    loss_list.append(train_loss)  # hier

    # Validation loop
    model.eval()
    val_loss = 0
    val_dice = 0
    num_val_samples = 0  # Initialize for normalizing across all validation examples
    with torch.no_grad():
        for images, masks in val_loader:
            images = images.to(device).float()
            masks  = masks.to(device).float()
            logits = model(images)
            batch_size = images.size(0)
            num_val_samples += batch_size

            val_loss += combined_loss(logits, masks).item() * batch_size  # Multiply by batch size
            val_dice += dice_coefficient(logits, masks).item() * batch_size

    val_loss_list.append(val_loss)  # hier

    # Average loss and dice score per epoch normalized by the number of samples
    train_loss /= num_train_samples  # Normalize over total number of training examples
    train_dice /= num_train_samples
    val_dice /= num_val_samples        
    val_loss /= num_val_samples  # Normalize over total number of validation examples

    # Store losses and dice scores for visualization
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_dice_scores.append(train_dice)
    val_dice_scores.append(val_dice)

    print(f'Epoch [{epoch+1}/{epochs}]:'.ljust(16),
          f'Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f},'
          f'Train Dice: {train_dice:.4f}, Val Dice: {val_dice:.4f}')

    # Early stopping based on training dice
    if val_loss < best_val_loss:                                                                                        # changed from early stopping based on train_dice to val_loss, since train metrics can lead to overfitting
        best_val_loss = val_loss
        torch.save(model.state_dict(), saved_models / 'unet++_model.pth')
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print('Early stopping triggered based on validation loss!')
        break
# Out:
# Epoch [1/500]:   Train Loss: 0.3525, Val Loss: 0.3729,Train Dice: 0.2948, Val Dice: 0.2543
# Epoch [2/500]:   Train Loss: 0.3520, Val Loss: 0.3735,Train Dice: 0.2959, Val Dice: 0.2530
# Epoch [3/500]:   Train Loss: 0.3518, Val Loss: 0.3730,Train Dice: 0.2964, Val Dice: 0.2540
# Epoch [4/500]:   Train Loss: 0.3521, Val Loss: 0.3731,Train Dice: 0.2957, Val Dice: 0.2539
# Epoch [5/500]:   Train Loss: 0.3521, Val Loss: 0.3724,Train Dice: 0.2959, Val Dice: 0.2552
# Epoch [6/500]:   Train Loss: 0.3520, Val Loss: 0.3731,Train Dice: 0.2960, Val Dice: 0.2537
# Epoch [7/500]:   Train Loss: 0.3518, Val Loss: 0.3722,Train Dice: 0.2965, Val Dice: 0.2557
# Epoch [8/500]:   Train Loss: 0.3522, Val Loss: 0.3726,Train Dice: 0.2957, Val Dice: 0.2548
# Epoch [9/500]:   Train Loss: 0.3520, Val Loss: 0.3732,Train Dice: 0.2959, Val Dice: 0.2537
# Epoch [10/500]:  Train Loss: 0.3521, Val Loss: 0.3733,Train Dice: 0.2957, Val Dice: 0.2534
# Epoch [11/500]:  Train Loss: 0.3521, Val Loss: 0.3731,Train Dice: 0.2959, Val Dice: 0.2539
# Epoch [12/500]:  Train Loss: 0.3520, Val Loss: 0.3726,Train Dice: 0.2961, Val Dice: 0.2547
# Epoch [13/500]:  Train Loss: 0.3520, Val Loss: 0.3730,Train Dice: 0.2961, Val Dice: 0.2540
# Epoch [14/500]:  Train Loss: 0.3520, Val Loss: 0.3733,Train Dice: 0.2959, Val Dice: 0.2533
# Epoch [15/500]:  Train Loss: 0.3520, Val Loss: 0.3735,Train Dice: 0.2960, Val Dice: 0.2530
# Epoch [16/500]:  Train Loss: 0.3520, Val Loss: 0.3728,Train Dice: 0.2959, Val Dice: 0.2543
# Epoch [17/500]:  Train Loss: 0.3519, Val Loss: 0.3728,Train Dice: 0.2962, Val Dice: 0.2545
# Epoch [18/500]:  Train Loss: 0.3520, Val Loss: 0.3739,Train Dice: 0.2961, Val Dice: 0.2522
# Epoch [19/500]:  Train Loss: 0.3519, Val Loss: 0.3728,Train Dice: 0.2962, Val Dice: 0.2543
# Epoch [20/500]:  Train Loss: 0.3520, Val Loss: 0.3735,Train Dice: 0.2960, Val Dice: 0.2531
# Epoch [21/500]:  Train Loss: 0.3520, Val Loss: 0.3731,Train Dice: 0.2959, Val Dice: 0.2537
# Epoch [22/500]:  Train Loss: 0.3519, Val Loss: 0.3733,Train Dice: 0.2962, Val Dice: 0.2533
# Epoch [23/500]:  Train Loss: 0.3520, Val Loss: 0.3735,Train Dice: 0.2959, Val Dice: 0.2530
# Epoch [24/500]:  Train Loss: 0.3520, Val Loss: 0.3730,Train Dice: 0.2961, Val Dice: 0.2539
# Epoch [25/500]:  Train Loss: 0.3520, Val Loss: 0.3736,Train Dice: 0.2960, Val Dice: 0.2528
# Epoch [26/500]:  Train Loss: 0.3520, Val Loss: 0.3730,Train Dice: 0.2960, Val Dice: 0.2541
# Epoch [27/500]:  Train Loss: 0.3520, Val Loss: 0.3729,Train Dice: 0.2961, Val Dice: 0.2543
# Epoch [28/500]:  Train Loss: 0.3519, Val Loss: 0.3739,Train Dice: 0.2962, Val Dice: 0.2521
# Epoch [29/500]:  Train Loss: 0.3519, Val Loss: 0.3732,Train Dice: 0.2963, Val Dice: 0.2535
# Epoch [30/500]:  Train Loss: 0.3523, Val Loss: 0.3729,Train Dice: 0.2954, Val Dice: 0.2543
# Epoch [31/500]:  Train Loss: 0.3521, Val Loss: 0.3726,Train Dice: 0.2958, Val Dice: 0.2547
# Epoch [32/500]:  Train Loss: 0.3521, Val Loss: 0.3731,Train Dice: 0.2958, Val Dice: 0.2538
# Epoch [33/500]:  Train Loss: 0.3520, Val Loss: 0.3728,Train Dice: 0.2961, Val Dice: 0.2544
# Epoch [34/500]:  Train Loss: 0.3520, Val Loss: 0.3728,Train Dice: 0.2960, Val Dice: 0.2544
# Epoch [35/500]:  Train Loss: 0.3521, Val Loss: 0.3725,Train Dice: 0.2959, Val Dice: 0.2549
# Epoch [36/500]:  Train Loss: 0.3519, Val Loss: 0.3728,Train Dice: 0.2961, Val Dice: 0.2544
# Epoch [37/500]:  Train Loss: 0.3522, Val Loss: 0.3732,Train Dice: 0.2956, Val Dice: 0.2535
# Early stopping triggered based on validation loss!

# %% [markdown]
# ##### 4.1.1. Plot training and validation data

# %%
# Block 6
import matplotlib.pyplot as plt


# Plot losses and dice scores
plt.figure(figsize=(12, 6))

# Plot losses
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot dice scores
plt.subplot(1, 2, 2)
plt.plot(train_dice_scores, label='Train Dice')
plt.plot(val_dice_scores, label='Val Dice')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.title('Training and Validation Dice Coefficient')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2. Evaluation Metrics |

# %%
# Block 7

# Set your test paths
predicted_masks = results / 'predicted_masks'  # Directory to save predicted masks as pngs
model_path = saved_models / 'unet++_model.pth'

Path(predicted_masks).mkdir(parents=True, exist_ok=True)

model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()


# Custom dataset for test images
class TestDataset(Dataset):
    def __init__(self, img_dir, transform=None):
        self.img_dir = img_dir
        # Extract image IDs by removing '_pp_enhanced.png' from each filename
        self.image_ids = sorted([file.stem.replace('_pp_enhanced', '') for file in self.img_dir.iterdir() if file.suffix.lower()=='.png'])
        self.transform = transform

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        img_path = self.img_dir / f'{image_id}.png'
        print(f'Loading image: {img_path}')  # Debugging: Confirm the correct image path
        image = imread(img_path).astype(np.float32) / 255.0  # Normalize to [0, 1]
        image = self.transform(image=image)['image'] if self.transform else image

        return image, image_id

# Define a transformation for the test data
test_transform = A.Compose([
    A.Resize(img_size, img_size),
    ToTensorV2()
])

# DataLoader for test data
test_dataset = TestDataset(preprocessed_test_images, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)


# Function to calculate Dice coefficient
def dice_coefficient(pred_mask, gt_mask, smooth=1):
    # Ensure the masks are binary (0 or 1)
    pred_mask = (pred_mask > 0.5).astype(np.uint8)  # Threshold the predicted mask
    gt_mask = (gt_mask > 0.5).astype(np.uint8)      # Ensure ground truth mask is binary

    # Calculate intersection and Dice score
    intersection = np.sum(pred_mask * gt_mask)
    return (2. * intersection + smooth) / (np.sum(pred_mask) + np.sum(gt_mask) + smooth)

# Initialize an empty list to store Dice scores
dice_scores = []

# In the prediction loop, after resizing the predicted mask:
for images, image_ids in test_loader:
    images = images.to(device)

    # Make prediction
    with torch.no_grad():
        outputs = model(images)
        predicted_mask = torch.sigmoid(outputs).squeeze().cpu().numpy()

        # Ensure predicted mask is binary
        predicted_mask = (predicted_mask > 0.5).astype(np.uint8)  # Threshold to binary

    image_id = image_ids[0]
    print(f'Processing image ID: {image_id}')  # Debugging: Confirm current image_id

    # Load ground truth mask
    gt_mask_path_full = preprocessed_test_masks / f'{image_id}.png'
    gt_mask = imread(gt_mask_path_full).astype(np.uint8)

    print(f'Loaded ground truth mask for image ID: {image_id}')

    # Ensure the resized predicted mask is binary
    predicted_mask = (predicted_mask > 0.5).astype(np.uint8)

    # Calculate Dice coefficient
    dice_score = dice_coefficient(predicted_mask, gt_mask)

    # Append the dice_score to the list
    dice_scores.append(dice_score)  # FIXED: append to the dice_scores list, not dice_score itself
    print(f'Image ID {image_id}: Dice Score = {dice_score:.4f}')  # Debugging

    # Save the predicted mask as png
    save_path = predicted_masks / f'{image_id}_predicted_mask.png'
    imsave(save_path, (predicted_mask * 255).astype(np.uint8))  # Save as uint8
    print(f'Saved predicted mask for image ID {image_id} at {save_path}')  # Debugging

# Calculate and print the mean Dice score
mean_dice_score = np.mean(dice_scores)
print(f'Mean Dice Score on Test Set: {mean_dice_score:.4f}')
# Out:
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1004.png
# Processing image ID: fold_3_1004
# Loaded ground truth mask for image ID: fold_3_1004
# Image ID fold_3_1004: Dice Score = 0.3441
# Saved predicted mask for image ID fold_3_1004 at results\predicted_masks\fold_3_1004_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_102.png
# Processing image ID: fold_3_102
# Loaded ground truth mask for image ID: fold_3_102
# Image ID fold_3_102: Dice Score = 0.6127
# Saved predicted mask for image ID fold_3_102 at results\predicted_masks\fold_3_102_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1067.png
# Processing image ID: fold_3_1067
# Loaded ground truth mask for image ID: fold_3_1067
# Image ID fold_3_1067: Dice Score = 0.4848
# Saved predicted mask for image ID fold_3_1067 at results\predicted_masks\fold_3_1067_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1071.png
# Processing image ID: fold_3_1071
# Loaded ground truth mask for image ID: fold_3_1071
# Image ID fold_3_1071: Dice Score = 0.3846
# Saved predicted mask for image ID fold_3_1071 at results\predicted_masks\fold_3_1071_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1074.png
# Processing image ID: fold_3_1074
# Loaded ground truth mask for image ID: fold_3_1074
# Image ID fold_3_1074: Dice Score = 0.3721
# Saved predicted mask for image ID fold_3_1074 at results\predicted_masks\fold_3_1074_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1096.png
# Processing image ID: fold_3_1096
# Loaded ground truth mask for image ID: fold_3_1096
# Image ID fold_3_1096: Dice Score = 0.2827
# Saved predicted mask for image ID fold_3_1096 at results\predicted_masks\fold_3_1096_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1111.png
# Processing image ID: fold_3_1111
# Loaded ground truth mask for image ID: fold_3_1111
# Image ID fold_3_1111: Dice Score = 0.2333
# Saved predicted mask for image ID fold_3_1111 at results\predicted_masks\fold_3_1111_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1113.png
# Processing image ID: fold_3_1113
# Loaded ground truth mask for image ID: fold_3_1113
# Image ID fold_3_1113: Dice Score = 0.1635
# Saved predicted mask for image ID fold_3_1113 at results\predicted_masks\fold_3_1113_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1118.png
# Processing image ID: fold_3_1118
# Loaded ground truth mask for image ID: fold_3_1118
# Image ID fold_3_1118: Dice Score = 0.2141
# Saved predicted mask for image ID fold_3_1118 at results\predicted_masks\fold_3_1118_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1139.png
# Processing image ID: fold_3_1139
# Loaded ground truth mask for image ID: fold_3_1139
# Image ID fold_3_1139: Dice Score = 0.1407
# Saved predicted mask for image ID fold_3_1139 at results\predicted_masks\fold_3_1139_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1141.png
# Processing image ID: fold_3_1141
# Loaded ground truth mask for image ID: fold_3_1141
# Image ID fold_3_1141: Dice Score = 0.2240
# Saved predicted mask for image ID fold_3_1141 at results\predicted_masks\fold_3_1141_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1146.png
# Processing image ID: fold_3_1146
# Loaded ground truth mask for image ID: fold_3_1146
# Image ID fold_3_1146: Dice Score = 0.2365
# Saved predicted mask for image ID fold_3_1146 at results\predicted_masks\fold_3_1146_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1150.png
# Processing image ID: fold_3_1150
# Loaded ground truth mask for image ID: fold_3_1150
# Image ID fold_3_1150: Dice Score = 0.3694
# Saved predicted mask for image ID fold_3_1150 at results\predicted_masks\fold_3_1150_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1156.png
# Processing image ID: fold_3_1156
# Loaded ground truth mask for image ID: fold_3_1156
# Image ID fold_3_1156: Dice Score = 0.2927
# Saved predicted mask for image ID fold_3_1156 at results\predicted_masks\fold_3_1156_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1179.png
# Processing image ID: fold_3_1179
# Loaded ground truth mask for image ID: fold_3_1179
# Image ID fold_3_1179: Dice Score = 0.0645
# Saved predicted mask for image ID fold_3_1179 at results\predicted_masks\fold_3_1179_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1181.png
# Processing image ID: fold_3_1181
# Loaded ground truth mask for image ID: fold_3_1181
# Image ID fold_3_1181: Dice Score = 0.1574
# Saved predicted mask for image ID fold_3_1181 at results\predicted_masks\fold_3_1181_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1182.png
# Processing image ID: fold_3_1182
# Loaded ground truth mask for image ID: fold_3_1182
# Image ID fold_3_1182: Dice Score = 0.0137
# Saved predicted mask for image ID fold_3_1182 at results\predicted_masks\fold_3_1182_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1183.png
# Processing image ID: fold_3_1183
# Loaded ground truth mask for image ID: fold_3_1183
# Image ID fold_3_1183: Dice Score = 0.4080
# Saved predicted mask for image ID fold_3_1183 at results\predicted_masks\fold_3_1183_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1212.png
# Processing image ID: fold_3_1212
# Loaded ground truth mask for image ID: fold_3_1212
# Image ID fold_3_1212: Dice Score = 0.2192
# Saved predicted mask for image ID fold_3_1212 at results\predicted_masks\fold_3_1212_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1227.png
# Processing image ID: fold_3_1227
# Loaded ground truth mask for image ID: fold_3_1227
# Image ID fold_3_1227: Dice Score = 0.3939
# Saved predicted mask for image ID fold_3_1227 at results\predicted_masks\fold_3_1227_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1237.png
# Processing image ID: fold_3_1237
# Loaded ground truth mask for image ID: fold_3_1237
# Image ID fold_3_1237: Dice Score = 0.4131
# Saved predicted mask for image ID fold_3_1237 at results\predicted_masks\fold_3_1237_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1242.png
# Processing image ID: fold_3_1242
# Loaded ground truth mask for image ID: fold_3_1242
# Image ID fold_3_1242: Dice Score = 0.5325
# Saved predicted mask for image ID fold_3_1242 at results\predicted_masks\fold_3_1242_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1263.png
# Processing image ID: fold_3_1263
# Loaded ground truth mask for image ID: fold_3_1263
# Image ID fold_3_1263: Dice Score = 0.1668
# Saved predicted mask for image ID fold_3_1263 at results\predicted_masks\fold_3_1263_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1275.png
# Processing image ID: fold_3_1275
# Loaded ground truth mask for image ID: fold_3_1275
# Image ID fold_3_1275: Dice Score = 0.0743
# Saved predicted mask for image ID fold_3_1275 at results\predicted_masks\fold_3_1275_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1316.png
# Processing image ID: fold_3_1316
# Loaded ground truth mask for image ID: fold_3_1316
# Image ID fold_3_1316: Dice Score = 0.1088
# Saved predicted mask for image ID fold_3_1316 at results\predicted_masks\fold_3_1316_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1320.png
# Processing image ID: fold_3_1320
# Loaded ground truth mask for image ID: fold_3_1320
# Image ID fold_3_1320: Dice Score = 0.0145
# Saved predicted mask for image ID fold_3_1320 at results\predicted_masks\fold_3_1320_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1330.png
# Processing image ID: fold_3_1330
# Loaded ground truth mask for image ID: fold_3_1330
# Image ID fold_3_1330: Dice Score = 0.0526
# Saved predicted mask for image ID fold_3_1330 at results\predicted_masks\fold_3_1330_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1334.png
# Processing image ID: fold_3_1334
# Loaded ground truth mask for image ID: fold_3_1334
# Image ID fold_3_1334: Dice Score = 0.4342
# Saved predicted mask for image ID fold_3_1334 at results\predicted_masks\fold_3_1334_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1336.png
# Processing image ID: fold_3_1336
# Loaded ground truth mask for image ID: fold_3_1336
# Image ID fold_3_1336: Dice Score = 0.5949
# Saved predicted mask for image ID fold_3_1336 at results\predicted_masks\fold_3_1336_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1341.png
# Processing image ID: fold_3_1341
# Loaded ground truth mask for image ID: fold_3_1341
# Image ID fold_3_1341: Dice Score = 0.2992
# Saved predicted mask for image ID fold_3_1341 at results\predicted_masks\fold_3_1341_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1344.png
# Processing image ID: fold_3_1344
# Loaded ground truth mask for image ID: fold_3_1344
# Image ID fold_3_1344: Dice Score = 0.5574
# Saved predicted mask for image ID fold_3_1344 at results\predicted_masks\fold_3_1344_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1347.png
# Processing image ID: fold_3_1347
# Loaded ground truth mask for image ID: fold_3_1347
# Image ID fold_3_1347: Dice Score = 0.1161
# Saved predicted mask for image ID fold_3_1347 at results\predicted_masks\fold_3_1347_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1359.png
# Processing image ID: fold_3_1359
# Loaded ground truth mask for image ID: fold_3_1359
# Image ID fold_3_1359: Dice Score = 0.2457
# Saved predicted mask for image ID fold_3_1359 at results\predicted_masks\fold_3_1359_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1367.png
# Processing image ID: fold_3_1367
# Loaded ground truth mask for image ID: fold_3_1367
# Image ID fold_3_1367: Dice Score = 0.3202
# Saved predicted mask for image ID fold_3_1367 at results\predicted_masks\fold_3_1367_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1368.png
# Processing image ID: fold_3_1368
# Loaded ground truth mask for image ID: fold_3_1368
# Image ID fold_3_1368: Dice Score = 0.3783
# Saved predicted mask for image ID fold_3_1368 at results\predicted_masks\fold_3_1368_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1384.png
# Processing image ID: fold_3_1384
# Loaded ground truth mask for image ID: fold_3_1384
# Image ID fold_3_1384: Dice Score = 0.2956
# Saved predicted mask for image ID fold_3_1384 at results\predicted_masks\fold_3_1384_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_140.png
# Processing image ID: fold_3_140
# Loaded ground truth mask for image ID: fold_3_140
# Image ID fold_3_140: Dice Score = 0.1715
# Saved predicted mask for image ID fold_3_140 at results\predicted_masks\fold_3_140_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1400.png
# Processing image ID: fold_3_1400
# Loaded ground truth mask for image ID: fold_3_1400
# Image ID fold_3_1400: Dice Score = 0.3583
# Saved predicted mask for image ID fold_3_1400 at results\predicted_masks\fold_3_1400_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1455.png
# Processing image ID: fold_3_1455
# Loaded ground truth mask for image ID: fold_3_1455
# Image ID fold_3_1455: Dice Score = 0.2499
# Saved predicted mask for image ID fold_3_1455 at results\predicted_masks\fold_3_1455_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1456.png
# Processing image ID: fold_3_1456
# Loaded ground truth mask for image ID: fold_3_1456
# Image ID fold_3_1456: Dice Score = 0.0452
# Saved predicted mask for image ID fold_3_1456 at results\predicted_masks\fold_3_1456_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_15.png
# Processing image ID: fold_3_15
# Loaded ground truth mask for image ID: fold_3_15
# Image ID fold_3_15: Dice Score = 0.1715
# Saved predicted mask for image ID fold_3_15 at results\predicted_masks\fold_3_15_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1503.png
# Processing image ID: fold_3_1503
# Loaded ground truth mask for image ID: fold_3_1503
# Image ID fold_3_1503: Dice Score = 0.3885
# Saved predicted mask for image ID fold_3_1503 at results\predicted_masks\fold_3_1503_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1511.png
# Processing image ID: fold_3_1511
# Loaded ground truth mask for image ID: fold_3_1511
# Image ID fold_3_1511: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1511 at results\predicted_masks\fold_3_1511_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1512.png
# Processing image ID: fold_3_1512
# Loaded ground truth mask for image ID: fold_3_1512
# Image ID fold_3_1512: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1512 at results\predicted_masks\fold_3_1512_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1529.png
# Processing image ID: fold_3_1529
# Loaded ground truth mask for image ID: fold_3_1529
# Image ID fold_3_1529: Dice Score = 0.0431
# Saved predicted mask for image ID fold_3_1529 at results\predicted_masks\fold_3_1529_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_153.png
# Processing image ID: fold_3_153
# Loaded ground truth mask for image ID: fold_3_153
# Image ID fold_3_153: Dice Score = 0.0575
# Saved predicted mask for image ID fold_3_153 at results\predicted_masks\fold_3_153_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_154.png
# Processing image ID: fold_3_154
# Loaded ground truth mask for image ID: fold_3_154
# Image ID fold_3_154: Dice Score = 0.0209
# Saved predicted mask for image ID fold_3_154 at results\predicted_masks\fold_3_154_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1547.png
# Processing image ID: fold_3_1547
# Loaded ground truth mask for image ID: fold_3_1547
# Image ID fold_3_1547: Dice Score = 0.0879
# Saved predicted mask for image ID fold_3_1547 at results\predicted_masks\fold_3_1547_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1555.png
# Processing image ID: fold_3_1555
# Loaded ground truth mask for image ID: fold_3_1555
# Image ID fold_3_1555: Dice Score = 0.2909
# Saved predicted mask for image ID fold_3_1555 at results\predicted_masks\fold_3_1555_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1568.png
# Processing image ID: fold_3_1568
# Loaded ground truth mask for image ID: fold_3_1568
# Image ID fold_3_1568: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1568 at results\predicted_masks\fold_3_1568_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1587.png
# Processing image ID: fold_3_1587
# Loaded ground truth mask for image ID: fold_3_1587
# Image ID fold_3_1587: Dice Score = 0.3507
# Saved predicted mask for image ID fold_3_1587 at results\predicted_masks\fold_3_1587_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1590.png
# Processing image ID: fold_3_1590
# Loaded ground truth mask for image ID: fold_3_1590
# Image ID fold_3_1590: Dice Score = 0.4123
# Saved predicted mask for image ID fold_3_1590 at results\predicted_masks\fold_3_1590_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1593.png
# Processing image ID: fold_3_1593
# Loaded ground truth mask for image ID: fold_3_1593
# Image ID fold_3_1593: Dice Score = 0.4768
# Saved predicted mask for image ID fold_3_1593 at results\predicted_masks\fold_3_1593_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_16.png
# Processing image ID: fold_3_16
# Loaded ground truth mask for image ID: fold_3_16
# Image ID fold_3_16: Dice Score = 0.1900
# Saved predicted mask for image ID fold_3_16 at results\predicted_masks\fold_3_16_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_160.png
# Processing image ID: fold_3_160
# Loaded ground truth mask for image ID: fold_3_160
# Image ID fold_3_160: Dice Score = 0.0527
# Saved predicted mask for image ID fold_3_160 at results\predicted_masks\fold_3_160_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_162.png
# Processing image ID: fold_3_162
# Loaded ground truth mask for image ID: fold_3_162
# Image ID fold_3_162: Dice Score = 0.0725
# Saved predicted mask for image ID fold_3_162 at results\predicted_masks\fold_3_162_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1650.png
# Processing image ID: fold_3_1650
# Loaded ground truth mask for image ID: fold_3_1650
# Image ID fold_3_1650: Dice Score = 0.3664
# Saved predicted mask for image ID fold_3_1650 at results\predicted_masks\fold_3_1650_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1659.png
# Processing image ID: fold_3_1659
# Loaded ground truth mask for image ID: fold_3_1659
# Image ID fold_3_1659: Dice Score = 0.1559
# Saved predicted mask for image ID fold_3_1659 at results\predicted_masks\fold_3_1659_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1663.png
# Processing image ID: fold_3_1663
# Loaded ground truth mask for image ID: fold_3_1663
# Image ID fold_3_1663: Dice Score = 0.3307
# Saved predicted mask for image ID fold_3_1663 at results\predicted_masks\fold_3_1663_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1665.png
# Processing image ID: fold_3_1665
# Loaded ground truth mask for image ID: fold_3_1665
# Image ID fold_3_1665: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1665 at results\predicted_masks\fold_3_1665_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1671.png
# Processing image ID: fold_3_1671
# Loaded ground truth mask for image ID: fold_3_1671
# Image ID fold_3_1671: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1671 at results\predicted_masks\fold_3_1671_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1674.png
# Processing image ID: fold_3_1674
# Loaded ground truth mask for image ID: fold_3_1674
# Image ID fold_3_1674: Dice Score = 0.6497
# Saved predicted mask for image ID fold_3_1674 at results\predicted_masks\fold_3_1674_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1683.png
# Processing image ID: fold_3_1683
# Loaded ground truth mask for image ID: fold_3_1683
# Image ID fold_3_1683: Dice Score = 0.4586
# Saved predicted mask for image ID fold_3_1683 at results\predicted_masks\fold_3_1683_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1687.png
# Processing image ID: fold_3_1687
# Loaded ground truth mask for image ID: fold_3_1687
# Image ID fold_3_1687: Dice Score = 0.4320
# Saved predicted mask for image ID fold_3_1687 at results\predicted_masks\fold_3_1687_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1689.png
# Processing image ID: fold_3_1689
# Loaded ground truth mask for image ID: fold_3_1689
# Image ID fold_3_1689: Dice Score = 0.4115
# Saved predicted mask for image ID fold_3_1689 at results\predicted_masks\fold_3_1689_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1701.png
# Processing image ID: fold_3_1701
# Loaded ground truth mask for image ID: fold_3_1701
# Image ID fold_3_1701: Dice Score = 0.4703
# Saved predicted mask for image ID fold_3_1701 at results\predicted_masks\fold_3_1701_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_18.png
# Processing image ID: fold_3_18
# Loaded ground truth mask for image ID: fold_3_18
# Image ID fold_3_18: Dice Score = 0.3342
# Saved predicted mask for image ID fold_3_18 at results\predicted_masks\fold_3_18_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1838.png
# Processing image ID: fold_3_1838
# Loaded ground truth mask for image ID: fold_3_1838
# Image ID fold_3_1838: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1838 at results\predicted_masks\fold_3_1838_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1853.png
# Processing image ID: fold_3_1853
# Loaded ground truth mask for image ID: fold_3_1853
# Image ID fold_3_1853: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1853 at results\predicted_masks\fold_3_1853_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1940.png
# Processing image ID: fold_3_1940
# Loaded ground truth mask for image ID: fold_3_1940
# Image ID fold_3_1940: Dice Score = 0.4361
# Saved predicted mask for image ID fold_3_1940 at results\predicted_masks\fold_3_1940_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1945.png
# Processing image ID: fold_3_1945
# Loaded ground truth mask for image ID: fold_3_1945
# Image ID fold_3_1945: Dice Score = 0.0149
# Saved predicted mask for image ID fold_3_1945 at results\predicted_masks\fold_3_1945_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1953.png
# Processing image ID: fold_3_1953
# Loaded ground truth mask for image ID: fold_3_1953
# Image ID fold_3_1953: Dice Score = 0.3297
# Saved predicted mask for image ID fold_3_1953 at results\predicted_masks\fold_3_1953_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1954.png
# Processing image ID: fold_3_1954
# Loaded ground truth mask for image ID: fold_3_1954
# Image ID fold_3_1954: Dice Score = 0.3619
# Saved predicted mask for image ID fold_3_1954 at results\predicted_masks\fold_3_1954_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1960.png
# Processing image ID: fold_3_1960
# Loaded ground truth mask for image ID: fold_3_1960
# Image ID fold_3_1960: Dice Score = 0.2302
# Saved predicted mask for image ID fold_3_1960 at results\predicted_masks\fold_3_1960_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1970.png
# Processing image ID: fold_3_1970
# Loaded ground truth mask for image ID: fold_3_1970
# Image ID fold_3_1970: Dice Score = 0.4000
# Saved predicted mask for image ID fold_3_1970 at results\predicted_masks\fold_3_1970_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1989.png
# Processing image ID: fold_3_1989
# Loaded ground truth mask for image ID: fold_3_1989
# Image ID fold_3_1989: Dice Score = 1.0000
# Saved predicted mask for image ID fold_3_1989 at results\predicted_masks\fold_3_1989_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2006.png
# Processing image ID: fold_3_2006
# Loaded ground truth mask for image ID: fold_3_2006
# Image ID fold_3_2006: Dice Score = 0.2843
# Saved predicted mask for image ID fold_3_2006 at results\predicted_masks\fold_3_2006_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2015.png
# Processing image ID: fold_3_2015
# Loaded ground truth mask for image ID: fold_3_2015
# Image ID fold_3_2015: Dice Score = 0.2538
# Saved predicted mask for image ID fold_3_2015 at results\predicted_masks\fold_3_2015_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2022.png
# Processing image ID: fold_3_2022
# Loaded ground truth mask for image ID: fold_3_2022
# Image ID fold_3_2022: Dice Score = 0.2175
# Saved predicted mask for image ID fold_3_2022 at results\predicted_masks\fold_3_2022_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2099.png
# Processing image ID: fold_3_2099
# Loaded ground truth mask for image ID: fold_3_2099
# Image ID fold_3_2099: Dice Score = 0.6582
# Saved predicted mask for image ID fold_3_2099 at results\predicted_masks\fold_3_2099_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2121.png
# Processing image ID: fold_3_2121
# Loaded ground truth mask for image ID: fold_3_2121
# Image ID fold_3_2121: Dice Score = 0.1679
# Saved predicted mask for image ID fold_3_2121 at results\predicted_masks\fold_3_2121_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2126.png
# Processing image ID: fold_3_2126
# Loaded ground truth mask for image ID: fold_3_2126
# Image ID fold_3_2126: Dice Score = 0.1591
# Saved predicted mask for image ID fold_3_2126 at results\predicted_masks\fold_3_2126_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2130.png
# Processing image ID: fold_3_2130
# Loaded ground truth mask for image ID: fold_3_2130
# Image ID fold_3_2130: Dice Score = 0.6162
# Saved predicted mask for image ID fold_3_2130 at results\predicted_masks\fold_3_2130_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2156.png
# Processing image ID: fold_3_2156
# Loaded ground truth mask for image ID: fold_3_2156
# Image ID fold_3_2156: Dice Score = 0.2284
# Saved predicted mask for image ID fold_3_2156 at results\predicted_masks\fold_3_2156_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2169.png
# Processing image ID: fold_3_2169
# Loaded ground truth mask for image ID: fold_3_2169
# Image ID fold_3_2169: Dice Score = 0.1689
# Saved predicted mask for image ID fold_3_2169 at results\predicted_masks\fold_3_2169_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2171.png
# Processing image ID: fold_3_2171
# Loaded ground truth mask for image ID: fold_3_2171
# Image ID fold_3_2171: Dice Score = 0.0496
# Saved predicted mask for image ID fold_3_2171 at results\predicted_masks\fold_3_2171_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2174.png
# Processing image ID: fold_3_2174
# Loaded ground truth mask for image ID: fold_3_2174
# Image ID fold_3_2174: Dice Score = 0.1413
# Saved predicted mask for image ID fold_3_2174 at results\predicted_masks\fold_3_2174_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2207.png
# Processing image ID: fold_3_2207
# Loaded ground truth mask for image ID: fold_3_2207
# Image ID fold_3_2207: Dice Score = 0.3756
# Saved predicted mask for image ID fold_3_2207 at results\predicted_masks\fold_3_2207_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2214.png
# Processing image ID: fold_3_2214
# Loaded ground truth mask for image ID: fold_3_2214
# Image ID fold_3_2214: Dice Score = 0.3659
# Saved predicted mask for image ID fold_3_2214 at results\predicted_masks\fold_3_2214_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2228.png
# Processing image ID: fold_3_2228
# Loaded ground truth mask for image ID: fold_3_2228
# Image ID fold_3_2228: Dice Score = 0.3069
# Saved predicted mask for image ID fold_3_2228 at results\predicted_masks\fold_3_2228_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2260.png
# Processing image ID: fold_3_2260
# Loaded ground truth mask for image ID: fold_3_2260
# Image ID fold_3_2260: Dice Score = 0.3429
# Saved predicted mask for image ID fold_3_2260 at results\predicted_masks\fold_3_2260_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2264.png
# Processing image ID: fold_3_2264
# Loaded ground truth mask for image ID: fold_3_2264
# Image ID fold_3_2264: Dice Score = 0.0399
# Saved predicted mask for image ID fold_3_2264 at results\predicted_masks\fold_3_2264_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2287.png
# Processing image ID: fold_3_2287
# Loaded ground truth mask for image ID: fold_3_2287
# Image ID fold_3_2287: Dice Score = 0.3832
# Saved predicted mask for image ID fold_3_2287 at results\predicted_masks\fold_3_2287_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2312.png
# Processing image ID: fold_3_2312
# Loaded ground truth mask for image ID: fold_3_2312
# Image ID fold_3_2312: Dice Score = 0.6675
# Saved predicted mask for image ID fold_3_2312 at results\predicted_masks\fold_3_2312_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2339.png
# Processing image ID: fold_3_2339
# Loaded ground truth mask for image ID: fold_3_2339
# Image ID fold_3_2339: Dice Score = 0.4171
# Saved predicted mask for image ID fold_3_2339 at results\predicted_masks\fold_3_2339_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2345.png
# Processing image ID: fold_3_2345
# Loaded ground truth mask for image ID: fold_3_2345
# Image ID fold_3_2345: Dice Score = 0.2709
# Saved predicted mask for image ID fold_3_2345 at results\predicted_masks\fold_3_2345_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2372.png
# Processing image ID: fold_3_2372
# Loaded ground truth mask for image ID: fold_3_2372
# Image ID fold_3_2372: Dice Score = 0.1438
# Saved predicted mask for image ID fold_3_2372 at results\predicted_masks\fold_3_2372_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_238.png
# Processing image ID: fold_3_238
# Loaded ground truth mask for image ID: fold_3_238
# Image ID fold_3_238: Dice Score = 0.1027
# Saved predicted mask for image ID fold_3_238 at results\predicted_masks\fold_3_238_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2399.png
# Processing image ID: fold_3_2399
# Loaded ground truth mask for image ID: fold_3_2399
# Image ID fold_3_2399: Dice Score = 0.5461
# Saved predicted mask for image ID fold_3_2399 at results\predicted_masks\fold_3_2399_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2422.png
# Processing image ID: fold_3_2422
# Loaded ground truth mask for image ID: fold_3_2422
# Image ID fold_3_2422: Dice Score = 0.2762
# Saved predicted mask for image ID fold_3_2422 at results\predicted_masks\fold_3_2422_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2423.png
# Processing image ID: fold_3_2423
# Loaded ground truth mask for image ID: fold_3_2423
# Image ID fold_3_2423: Dice Score = 0.3682
# Saved predicted mask for image ID fold_3_2423 at results\predicted_masks\fold_3_2423_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2430.png
# Processing image ID: fold_3_2430
# Loaded ground truth mask for image ID: fold_3_2430
# Image ID fold_3_2430: Dice Score = 0.3485
# Saved predicted mask for image ID fold_3_2430 at results\predicted_masks\fold_3_2430_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2468.png
# Processing image ID: fold_3_2468
# Loaded ground truth mask for image ID: fold_3_2468
# Image ID fold_3_2468: Dice Score = 0.3658
# Saved predicted mask for image ID fold_3_2468 at results\predicted_masks\fold_3_2468_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2470.png
# Processing image ID: fold_3_2470
# Loaded ground truth mask for image ID: fold_3_2470
# Image ID fold_3_2470: Dice Score = 0.4218
# Saved predicted mask for image ID fold_3_2470 at results\predicted_masks\fold_3_2470_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2515.png
# Processing image ID: fold_3_2515
# Loaded ground truth mask for image ID: fold_3_2515
# Image ID fold_3_2515: Dice Score = 0.3483
# Saved predicted mask for image ID fold_3_2515 at results\predicted_masks\fold_3_2515_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2517.png
# Processing image ID: fold_3_2517
# Loaded ground truth mask for image ID: fold_3_2517
# Image ID fold_3_2517: Dice Score = 0.3790
# Saved predicted mask for image ID fold_3_2517 at results\predicted_masks\fold_3_2517_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2547.png
# Processing image ID: fold_3_2547
# Loaded ground truth mask for image ID: fold_3_2547
# Image ID fold_3_2547: Dice Score = 0.5501
# Saved predicted mask for image ID fold_3_2547 at results\predicted_masks\fold_3_2547_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2557.png
# Processing image ID: fold_3_2557
# Loaded ground truth mask for image ID: fold_3_2557
# Image ID fold_3_2557: Dice Score = 0.3608
# Saved predicted mask for image ID fold_3_2557 at results\predicted_masks\fold_3_2557_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2608.png
# Processing image ID: fold_3_2608
# Loaded ground truth mask for image ID: fold_3_2608
# Image ID fold_3_2608: Dice Score = 0.5188
# Saved predicted mask for image ID fold_3_2608 at results\predicted_masks\fold_3_2608_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2633.png
# Processing image ID: fold_3_2633
# Loaded ground truth mask for image ID: fold_3_2633
# Image ID fold_3_2633: Dice Score = 0.4095
# Saved predicted mask for image ID fold_3_2633 at results\predicted_masks\fold_3_2633_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2659.png
# Processing image ID: fold_3_2659
# Loaded ground truth mask for image ID: fold_3_2659
# Image ID fold_3_2659: Dice Score = 0.4039
# Saved predicted mask for image ID fold_3_2659 at results\predicted_masks\fold_3_2659_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2678.png
# Processing image ID: fold_3_2678
# Loaded ground truth mask for image ID: fold_3_2678
# Image ID fold_3_2678: Dice Score = 0.0362
# Saved predicted mask for image ID fold_3_2678 at results\predicted_masks\fold_3_2678_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2715.png
# Processing image ID: fold_3_2715
# Loaded ground truth mask for image ID: fold_3_2715
# Image ID fold_3_2715: Dice Score = 0.4932
# Saved predicted mask for image ID fold_3_2715 at results\predicted_masks\fold_3_2715_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2716.png
# Processing image ID: fold_3_2716
# Loaded ground truth mask for image ID: fold_3_2716
# Image ID fold_3_2716: Dice Score = 0.4739
# Saved predicted mask for image ID fold_3_2716 at results\predicted_masks\fold_3_2716_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2717.png
# Processing image ID: fold_3_2717
# Loaded ground truth mask for image ID: fold_3_2717
# Image ID fold_3_2717: Dice Score = 0.5510
# Saved predicted mask for image ID fold_3_2717 at results\predicted_masks\fold_3_2717_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_30.png
# Processing image ID: fold_3_30
# Loaded ground truth mask for image ID: fold_3_30
# Image ID fold_3_30: Dice Score = 0.0018
# Saved predicted mask for image ID fold_3_30 at results\predicted_masks\fold_3_30_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_316.png
# Processing image ID: fold_3_316
# Loaded ground truth mask for image ID: fold_3_316
# Image ID fold_3_316: Dice Score = 0.5555
# Saved predicted mask for image ID fold_3_316 at results\predicted_masks\fold_3_316_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_331.png
# Processing image ID: fold_3_331
# Loaded ground truth mask for image ID: fold_3_331
# Image ID fold_3_331: Dice Score = 0.2246
# Saved predicted mask for image ID fold_3_331 at results\predicted_masks\fold_3_331_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_332.png
# Processing image ID: fold_3_332
# Loaded ground truth mask for image ID: fold_3_332
# Image ID fold_3_332: Dice Score = 0.3033
# Saved predicted mask for image ID fold_3_332 at results\predicted_masks\fold_3_332_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_34.png
# Processing image ID: fold_3_34
# Loaded ground truth mask for image ID: fold_3_34
# Image ID fold_3_34: Dice Score = 0.1054
# Saved predicted mask for image ID fold_3_34 at results\predicted_masks\fold_3_34_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_356.png
# Processing image ID: fold_3_356
# Loaded ground truth mask for image ID: fold_3_356
# Image ID fold_3_356: Dice Score = 0.2977
# Saved predicted mask for image ID fold_3_356 at results\predicted_masks\fold_3_356_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_370.png
# Processing image ID: fold_3_370
# Loaded ground truth mask for image ID: fold_3_370
# Image ID fold_3_370: Dice Score = 0.4044
# Saved predicted mask for image ID fold_3_370 at results\predicted_masks\fold_3_370_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_384.png
# Processing image ID: fold_3_384
# Loaded ground truth mask for image ID: fold_3_384
# Image ID fold_3_384: Dice Score = 0.2704
# Saved predicted mask for image ID fold_3_384 at results\predicted_masks\fold_3_384_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_388.png
# Processing image ID: fold_3_388
# Loaded ground truth mask for image ID: fold_3_388
# Image ID fold_3_388: Dice Score = 0.0326
# Saved predicted mask for image ID fold_3_388 at results\predicted_masks\fold_3_388_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_427.png
# Processing image ID: fold_3_427
# Loaded ground truth mask for image ID: fold_3_427
# Image ID fold_3_427: Dice Score = 0.5004
# Saved predicted mask for image ID fold_3_427 at results\predicted_masks\fold_3_427_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_428.png
# Processing image ID: fold_3_428
# Loaded ground truth mask for image ID: fold_3_428
# Image ID fold_3_428: Dice Score = 0.2670
# Saved predicted mask for image ID fold_3_428 at results\predicted_masks\fold_3_428_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_440.png
# Processing image ID: fold_3_440
# Loaded ground truth mask for image ID: fold_3_440
# Image ID fold_3_440: Dice Score = 0.1303
# Saved predicted mask for image ID fold_3_440 at results\predicted_masks\fold_3_440_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_444.png
# Processing image ID: fold_3_444
# Loaded ground truth mask for image ID: fold_3_444
# Image ID fold_3_444: Dice Score = 0.0231
# Saved predicted mask for image ID fold_3_444 at results\predicted_masks\fold_3_444_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_460.png
# Processing image ID: fold_3_460
# Loaded ground truth mask for image ID: fold_3_460
# Image ID fold_3_460: Dice Score = 0.2640
# Saved predicted mask for image ID fold_3_460 at results\predicted_masks\fold_3_460_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_462.png
# Processing image ID: fold_3_462
# Loaded ground truth mask for image ID: fold_3_462
# Image ID fold_3_462: Dice Score = 0.0420
# Saved predicted mask for image ID fold_3_462 at results\predicted_masks\fold_3_462_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_465.png
# Processing image ID: fold_3_465
# Loaded ground truth mask for image ID: fold_3_465
# Image ID fold_3_465: Dice Score = 0.0453
# Saved predicted mask for image ID fold_3_465 at results\predicted_masks\fold_3_465_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_471.png
# Processing image ID: fold_3_471
# Loaded ground truth mask for image ID: fold_3_471
# Image ID fold_3_471: Dice Score = 0.2925
# Saved predicted mask for image ID fold_3_471 at results\predicted_masks\fold_3_471_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_475.png
# Processing image ID: fold_3_475
# Loaded ground truth mask for image ID: fold_3_475
# Image ID fold_3_475: Dice Score = 0.1068
# Saved predicted mask for image ID fold_3_475 at results\predicted_masks\fold_3_475_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_479.png
# Processing image ID: fold_3_479
# Loaded ground truth mask for image ID: fold_3_479
# Image ID fold_3_479: Dice Score = 0.0032
# Saved predicted mask for image ID fold_3_479 at results\predicted_masks\fold_3_479_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_48.png
# Processing image ID: fold_3_48
# Loaded ground truth mask for image ID: fold_3_48
# Image ID fold_3_48: Dice Score = 0.1711
# Saved predicted mask for image ID fold_3_48 at results\predicted_masks\fold_3_48_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_485.png
# Processing image ID: fold_3_485
# Loaded ground truth mask for image ID: fold_3_485
# Image ID fold_3_485: Dice Score = 0.2947
# Saved predicted mask for image ID fold_3_485 at results\predicted_masks\fold_3_485_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_49.png
# Processing image ID: fold_3_49
# Loaded ground truth mask for image ID: fold_3_49
# Image ID fold_3_49: Dice Score = 0.0165
# Saved predicted mask for image ID fold_3_49 at results\predicted_masks\fold_3_49_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_491.png
# Processing image ID: fold_3_491
# Loaded ground truth mask for image ID: fold_3_491
# Image ID fold_3_491: Dice Score = 0.1599
# Saved predicted mask for image ID fold_3_491 at results\predicted_masks\fold_3_491_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_495.png
# Processing image ID: fold_3_495
# Loaded ground truth mask for image ID: fold_3_495
# Image ID fold_3_495: Dice Score = 0.4395
# Saved predicted mask for image ID fold_3_495 at results\predicted_masks\fold_3_495_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_513.png
# Processing image ID: fold_3_513
# Loaded ground truth mask for image ID: fold_3_513
# Image ID fold_3_513: Dice Score = 0.0115
# Saved predicted mask for image ID fold_3_513 at results\predicted_masks\fold_3_513_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_516.png
# Processing image ID: fold_3_516
# Loaded ground truth mask for image ID: fold_3_516
# Image ID fold_3_516: Dice Score = 0.4068
# Saved predicted mask for image ID fold_3_516 at results\predicted_masks\fold_3_516_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_518.png
# Processing image ID: fold_3_518
# Loaded ground truth mask for image ID: fold_3_518
# Image ID fold_3_518: Dice Score = 0.0041
# Saved predicted mask for image ID fold_3_518 at results\predicted_masks\fold_3_518_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_526.png
# Processing image ID: fold_3_526
# Loaded ground truth mask for image ID: fold_3_526
# Image ID fold_3_526: Dice Score = 0.1943
# Saved predicted mask for image ID fold_3_526 at results\predicted_masks\fold_3_526_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_549.png
# Processing image ID: fold_3_549
# Loaded ground truth mask for image ID: fold_3_549
# Image ID fold_3_549: Dice Score = 0.3835
# Saved predicted mask for image ID fold_3_549 at results\predicted_masks\fold_3_549_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_554.png
# Processing image ID: fold_3_554
# Loaded ground truth mask for image ID: fold_3_554
# Image ID fold_3_554: Dice Score = 0.3074
# Saved predicted mask for image ID fold_3_554 at results\predicted_masks\fold_3_554_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_557.png
# Processing image ID: fold_3_557
# Loaded ground truth mask for image ID: fold_3_557
# Image ID fold_3_557: Dice Score = 0.3926
# Saved predicted mask for image ID fold_3_557 at results\predicted_masks\fold_3_557_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_559.png
# Processing image ID: fold_3_559
# Loaded ground truth mask for image ID: fold_3_559
# Image ID fold_3_559: Dice Score = 0.2744
# Saved predicted mask for image ID fold_3_559 at results\predicted_masks\fold_3_559_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_569.png
# Processing image ID: fold_3_569
# Loaded ground truth mask for image ID: fold_3_569
# Image ID fold_3_569: Dice Score = 0.2331
# Saved predicted mask for image ID fold_3_569 at results\predicted_masks\fold_3_569_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_578.png
# Processing image ID: fold_3_578
# Loaded ground truth mask for image ID: fold_3_578
# Image ID fold_3_578: Dice Score = 0.4323
# Saved predicted mask for image ID fold_3_578 at results\predicted_masks\fold_3_578_predicted_mask.png
# ...
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_615.png
# Processing image ID: fold_3_615
# Loaded ground truth mask for image ID: fold_3_615
# Image ID fold_3_615: Dice Score = 0.4916
# Saved predicted mask for image ID fold_3_615 at results\predicted_masks\fold_3_615_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_635.png
# Processing image ID: fold_3_635
# Loaded ground truth mask for image ID: fold_3_635
# Image ID fold_3_635: Dice Score = 0.3914
# Saved predicted mask for image ID fold_3_635 at results\predicted_masks\fold_3_635_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_654.png
# Processing image ID: fold_3_654
# Loaded ground truth mask for image ID: fold_3_654
# Image ID fold_3_654: Dice Score = 0.1196
# Saved predicted mask for image ID fold_3_654 at results\predicted_masks\fold_3_654_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_659.png
# Processing image ID: fold_3_659
# Loaded ground truth mask for image ID: fold_3_659
# Image ID fold_3_659: Dice Score = 0.1557
# Saved predicted mask for image ID fold_3_659 at results\predicted_masks\fold_3_659_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_661.png
# Processing image ID: fold_3_661
# Loaded ground truth mask for image ID: fold_3_661
# Image ID fold_3_661: Dice Score = 0.3789
# Saved predicted mask for image ID fold_3_661 at results\predicted_masks\fold_3_661_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_662.png
# Processing image ID: fold_3_662
# Loaded ground truth mask for image ID: fold_3_662
# Image ID fold_3_662: Dice Score = 0.2187
# Saved predicted mask for image ID fold_3_662 at results\predicted_masks\fold_3_662_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_675.png
# Processing image ID: fold_3_675
# Loaded ground truth mask for image ID: fold_3_675
# Image ID fold_3_675: Dice Score = 0.2466
# Saved predicted mask for image ID fold_3_675 at results\predicted_masks\fold_3_675_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_677.png
# Processing image ID: fold_3_677
# Loaded ground truth mask for image ID: fold_3_677
# Image ID fold_3_677: Dice Score = 0.3485
# Saved predicted mask for image ID fold_3_677 at results\predicted_masks\fold_3_677_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_680.png
# Processing image ID: fold_3_680
# Loaded ground truth mask for image ID: fold_3_680
# Image ID fold_3_680: Dice Score = 0.3312
# Saved predicted mask for image ID fold_3_680 at results\predicted_masks\fold_3_680_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_684.png
# Processing image ID: fold_3_684
# Loaded ground truth mask for image ID: fold_3_684
# Image ID fold_3_684: Dice Score = 0.4781
# Saved predicted mask for image ID fold_3_684 at results\predicted_masks\fold_3_684_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_690.png
# Processing image ID: fold_3_690
# Loaded ground truth mask for image ID: fold_3_690
# Image ID fold_3_690: Dice Score = 0.2522
# Saved predicted mask for image ID fold_3_690 at results\predicted_masks\fold_3_690_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_701.png
# Processing image ID: fold_3_701
# Loaded ground truth mask for image ID: fold_3_701
# Image ID fold_3_701: Dice Score = 0.3221
# Saved predicted mask for image ID fold_3_701 at results\predicted_masks\fold_3_701_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_705.png
# Processing image ID: fold_3_705
# Loaded ground truth mask for image ID: fold_3_705
# Image ID fold_3_705: Dice Score = 0.1620
# Saved predicted mask for image ID fold_3_705 at results\predicted_masks\fold_3_705_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_711.png
# Processing image ID: fold_3_711
# Loaded ground truth mask for image ID: fold_3_711
# Image ID fold_3_711: Dice Score = 0.0291
# Saved predicted mask for image ID fold_3_711 at results\predicted_masks\fold_3_711_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_715.png
# Processing image ID: fold_3_715
# Loaded ground truth mask for image ID: fold_3_715
# Image ID fold_3_715: Dice Score = 0.2239
# Saved predicted mask for image ID fold_3_715 at results\predicted_masks\fold_3_715_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_718.png
# Processing image ID: fold_3_718
# Loaded ground truth mask for image ID: fold_3_718
# Image ID fold_3_718: Dice Score = 0.0449
# Saved predicted mask for image ID fold_3_718 at results\predicted_masks\fold_3_718_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_740.png
# Processing image ID: fold_3_740
# Loaded ground truth mask for image ID: fold_3_740
# Image ID fold_3_740: Dice Score = 0.3705
# Saved predicted mask for image ID fold_3_740 at results\predicted_masks\fold_3_740_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_764.png
# Processing image ID: fold_3_764
# Loaded ground truth mask for image ID: fold_3_764
# Image ID fold_3_764: Dice Score = 0.2777
# Saved predicted mask for image ID fold_3_764 at results\predicted_masks\fold_3_764_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_766.png
# Processing image ID: fold_3_766
# Loaded ground truth mask for image ID: fold_3_766
# Image ID fold_3_766: Dice Score = 0.2476
# Saved predicted mask for image ID fold_3_766 at results\predicted_masks\fold_3_766_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_769.png
# Processing image ID: fold_3_769
# Loaded ground truth mask for image ID: fold_3_769
# Image ID fold_3_769: Dice Score = 0.3226
# Saved predicted mask for image ID fold_3_769 at results\predicted_masks\fold_3_769_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_776.png
# Processing image ID: fold_3_776
# Loaded ground truth mask for image ID: fold_3_776
# Image ID fold_3_776: Dice Score = 0.3838
# Saved predicted mask for image ID fold_3_776 at results\predicted_masks\fold_3_776_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_789.png
# Processing image ID: fold_3_789
# Loaded ground truth mask for image ID: fold_3_789
# Image ID fold_3_789: Dice Score = 0.0219
# Saved predicted mask for image ID fold_3_789 at results\predicted_masks\fold_3_789_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_790.png
# Processing image ID: fold_3_790
# Loaded ground truth mask for image ID: fold_3_790
# Image ID fold_3_790: Dice Score = 0.1182
# Saved predicted mask for image ID fold_3_790 at results\predicted_masks\fold_3_790_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_814.png
# Processing image ID: fold_3_814
# Loaded ground truth mask for image ID: fold_3_814
# Image ID fold_3_814: Dice Score = 0.3874
# Saved predicted mask for image ID fold_3_814 at results\predicted_masks\fold_3_814_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_815.png
# Processing image ID: fold_3_815
# Loaded ground truth mask for image ID: fold_3_815
# Image ID fold_3_815: Dice Score = 0.0119
# Saved predicted mask for image ID fold_3_815 at results\predicted_masks\fold_3_815_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_818.png
# Processing image ID: fold_3_818
# Loaded ground truth mask for image ID: fold_3_818
# Image ID fold_3_818: Dice Score = 0.4473
# Saved predicted mask for image ID fold_3_818 at results\predicted_masks\fold_3_818_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_826.png
# Processing image ID: fold_3_826
# Loaded ground truth mask for image ID: fold_3_826
# Image ID fold_3_826: Dice Score = 0.4384
# Saved predicted mask for image ID fold_3_826 at results\predicted_masks\fold_3_826_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_827.png
# Processing image ID: fold_3_827
# Loaded ground truth mask for image ID: fold_3_827
# Image ID fold_3_827: Dice Score = 0.4030
# Saved predicted mask for image ID fold_3_827 at results\predicted_masks\fold_3_827_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_838.png
# Processing image ID: fold_3_838
# Loaded ground truth mask for image ID: fold_3_838
# Image ID fold_3_838: Dice Score = 0.2834
# Saved predicted mask for image ID fold_3_838 at results\predicted_masks\fold_3_838_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_847.png
# Processing image ID: fold_3_847
# Loaded ground truth mask for image ID: fold_3_847
# Image ID fold_3_847: Dice Score = 0.1577
# Saved predicted mask for image ID fold_3_847 at results\predicted_masks\fold_3_847_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_851.png
# Processing image ID: fold_3_851
# Loaded ground truth mask for image ID: fold_3_851
# Image ID fold_3_851: Dice Score = 0.2388
# Saved predicted mask for image ID fold_3_851 at results\predicted_masks\fold_3_851_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_862.png
# Processing image ID: fold_3_862
# Loaded ground truth mask for image ID: fold_3_862
# Image ID fold_3_862: Dice Score = 0.2370
# Saved predicted mask for image ID fold_3_862 at results\predicted_masks\fold_3_862_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_87.png
# Processing image ID: fold_3_87
# Loaded ground truth mask for image ID: fold_3_87
# Image ID fold_3_87: Dice Score = 0.0913
# Saved predicted mask for image ID fold_3_87 at results\predicted_masks\fold_3_87_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_872.png
# Processing image ID: fold_3_872
# Loaded ground truth mask for image ID: fold_3_872
# Image ID fold_3_872: Dice Score = 0.1817
# Saved predicted mask for image ID fold_3_872 at results\predicted_masks\fold_3_872_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_878.png
# Processing image ID: fold_3_878
# Loaded ground truth mask for image ID: fold_3_878
# Image ID fold_3_878: Dice Score = 0.2413
# Saved predicted mask for image ID fold_3_878 at results\predicted_masks\fold_3_878_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_88.png
# Processing image ID: fold_3_88
# Loaded ground truth mask for image ID: fold_3_88
# Image ID fold_3_88: Dice Score = 0.1906
# Saved predicted mask for image ID fold_3_88 at results\predicted_masks\fold_3_88_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_890.png
# Processing image ID: fold_3_890
# Loaded ground truth mask for image ID: fold_3_890
# Image ID fold_3_890: Dice Score = 0.0299
# Saved predicted mask for image ID fold_3_890 at results\predicted_masks\fold_3_890_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_908.png
# Processing image ID: fold_3_908
# Loaded ground truth mask for image ID: fold_3_908
# Image ID fold_3_908: Dice Score = 0.5514
# Saved predicted mask for image ID fold_3_908 at results\predicted_masks\fold_3_908_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_910.png
# Processing image ID: fold_3_910
# Loaded ground truth mask for image ID: fold_3_910
# Image ID fold_3_910: Dice Score = 0.5348
# Saved predicted mask for image ID fold_3_910 at results\predicted_masks\fold_3_910_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_933.png
# Processing image ID: fold_3_933
# Loaded ground truth mask for image ID: fold_3_933
# Image ID fold_3_933: Dice Score = 0.1432
# Saved predicted mask for image ID fold_3_933 at results\predicted_masks\fold_3_933_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_934.png
# Processing image ID: fold_3_934
# Loaded ground truth mask for image ID: fold_3_934
# Image ID fold_3_934: Dice Score = 0.0649
# Saved predicted mask for image ID fold_3_934 at results\predicted_masks\fold_3_934_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_944.png
# Processing image ID: fold_3_944
# Loaded ground truth mask for image ID: fold_3_944
# Image ID fold_3_944: Dice Score = 0.3143
# Saved predicted mask for image ID fold_3_944 at results\predicted_masks\fold_3_944_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_950.png
# Processing image ID: fold_3_950
# Loaded ground truth mask for image ID: fold_3_950
# Image ID fold_3_950: Dice Score = 0.0099
# Saved predicted mask for image ID fold_3_950 at results\predicted_masks\fold_3_950_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_960.png
# Processing image ID: fold_3_960
# Loaded ground truth mask for image ID: fold_3_960
# Image ID fold_3_960: Dice Score = 0.4350
# Saved predicted mask for image ID fold_3_960 at results\predicted_masks\fold_3_960_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_964.png
# Processing image ID: fold_3_964
# Loaded ground truth mask for image ID: fold_3_964
# Image ID fold_3_964: Dice Score = 0.4921
# Saved predicted mask for image ID fold_3_964 at results\predicted_masks\fold_3_964_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_969.png
# Processing image ID: fold_3_969
# Loaded ground truth mask for image ID: fold_3_969
# Image ID fold_3_969: Dice Score = 0.3680
# Saved predicted mask for image ID fold_3_969 at results\predicted_masks\fold_3_969_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_972.png
# Processing image ID: fold_3_972
# Loaded ground truth mask for image ID: fold_3_972
# Image ID fold_3_972: Dice Score = 0.4457
# Saved predicted mask for image ID fold_3_972 at results\predicted_masks\fold_3_972_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_986.png
# Processing image ID: fold_3_986
# Loaded ground truth mask for image ID: fold_3_986
# Image ID fold_3_986: Dice Score = 0.3907
# Saved predicted mask for image ID fold_3_986 at results\predicted_masks\fold_3_986_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_991.png
# Processing image ID: fold_3_991
# Loaded ground truth mask for image ID: fold_3_991
# Image ID fold_3_991: Dice Score = 0.4037
# Saved predicted mask for image ID fold_3_991 at results\predicted_masks\fold_3_991_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_995.png
# Processing image ID: fold_3_995
# Loaded ground truth mask for image ID: fold_3_995
# Image ID fold_3_995: Dice Score = 0.1119
# Saved predicted mask for image ID fold_3_995 at results\predicted_masks\fold_3_995_predicted_mask.png
# Mean Dice Score on Test Set: 0.3076

# %% [markdown]
# ### 4.3. Mask has all nuclei in one image |
#
# ###### Save dice and iou into a .csv file --> without attention

# %%
# Block 8

import csv

# Function to calculate IoU
def iou_coefficient(pred_mask, gt_mask, smooth=1e-5):
    pred_mask = (pred_mask > 0.5).astype(np.uint8)
    gt_mask = (gt_mask > 0.5).astype(np.uint8)
    intersection = np.sum(pred_mask * gt_mask)
    union = np.sum(pred_mask) + np.sum(gt_mask) - intersection
    return (intersection + smooth) / (union + smooth)

# Initialize lists to store results
dice_scores = []
iou_scores = []
image_ids_list = []

# In the prediction loop, after resizing the predicted mask:
for images, image_ids in test_loader:
    images = images.to(device)

    # Make prediction
    with torch.no_grad():
        outputs = model(images)
        predicted_mask = torch.sigmoid(outputs).squeeze().cpu().numpy()

        # Ensure predicted mask is binary
        predicted_mask = (predicted_mask > 0.5).astype(np.uint8)  # Threshold to binary

    image_id = image_ids[0]
    print(f'Processing image ID: {image_id}')  # Debugging: Confirm current image_id

    # Load ground truth mask
    gt_mask_path_full = preprocessed_test_masks / f'{image_id}.png'
    gt_mask = imread(gt_mask_path_full).astype(np.uint8)

    print(f'Loaded ground truth mask for image ID: {image_id}')

    # Ensure the resized predicted mask is binary
    predicted_mask = (predicted_mask > 0.5).astype(np.uint8)

    # Calculate Dice coefficient
    dice_score = dice_coefficient(predicted_mask, gt_mask)

    # Calculate IoU
    iou_score = iou_coefficient(predicted_mask, gt_mask)

    # Append results to the lists
    dice_scores.append(dice_score)
    iou_scores.append(iou_score)
    image_ids_list.append(image_id)

    print(f'Image ID {image_id}: Dice Score = {dice_score:.4f}, IoU = {iou_score:.4f}')  # Debugging

    # Save the predicted mask as png
    save_path = predicted_masks / f'{image_id}_predicted_mask.png'
    imsave(save_path, (predicted_mask * 255).astype(np.uint8))  # Save as uint8
    print(f'Saved predicted mask for image ID {image_id} at {save_path}')  # Debugging

# Calculate and print the mean Dice and IoU scores
mean_dice_score = np.mean(dice_scores)
mean_iou_score = np.mean(iou_scores)
print(f"Mean Dice Score on Test Set: {mean_dice_score:.4f}")
print(f"Mean IoU Score on Test Set: {mean_iou_score:.4f}")

# Save results into a CSV file
csv_filename = results / 'csv' / 'dice_iou_scores.csv'
csv_filename.parent.mkdir(parents=True, exist_ok=True)

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Image ID', 'Dice Score', 'IoU Score'])  # Write the header
    for i in range(len(image_ids_list)):
        writer.writerow([image_ids_list[i], dice_scores[i], iou_scores[i]])  # Write each row of results

print(f'Results saved to {csv_filename}')
# Out:
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1004.png
# Processing image ID: fold_3_1004
# Loaded ground truth mask for image ID: fold_3_1004
# Image ID fold_3_1004: Dice Score = 0.3441, IoU = 0.2078
# Saved predicted mask for image ID fold_3_1004 at results\predicted_masks\fold_3_1004_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_102.png
# Processing image ID: fold_3_102
# Loaded ground truth mask for image ID: fold_3_102
# Image ID fold_3_102: Dice Score = 0.6127, IoU = 0.4417
# Saved predicted mask for image ID fold_3_102 at results\predicted_masks\fold_3_102_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1067.png
# Processing image ID: fold_3_1067
# Loaded ground truth mask for image ID: fold_3_1067
# Image ID fold_3_1067: Dice Score = 0.4848, IoU = 0.3200
# Saved predicted mask for image ID fold_3_1067 at results\predicted_masks\fold_3_1067_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1071.png
# Processing image ID: fold_3_1071
# Loaded ground truth mask for image ID: fold_3_1071
# Image ID fold_3_1071: Dice Score = 0.3846, IoU = 0.2381
# Saved predicted mask for image ID fold_3_1071 at results\predicted_masks\fold_3_1071_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1074.png
# Processing image ID: fold_3_1074
# Loaded ground truth mask for image ID: fold_3_1074
# Image ID fold_3_1074: Dice Score = 0.3721, IoU = 0.2286
# Saved predicted mask for image ID fold_3_1074 at results\predicted_masks\fold_3_1074_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1096.png
# Processing image ID: fold_3_1096
# Loaded ground truth mask for image ID: fold_3_1096
# Image ID fold_3_1096: Dice Score = 0.2827, IoU = 0.1646
# Saved predicted mask for image ID fold_3_1096 at results\predicted_masks\fold_3_1096_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1111.png
# Processing image ID: fold_3_1111
# Loaded ground truth mask for image ID: fold_3_1111
# Image ID fold_3_1111: Dice Score = 0.2333, IoU = 0.1320
# Saved predicted mask for image ID fold_3_1111 at results\predicted_masks\fold_3_1111_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1113.png
# Processing image ID: fold_3_1113
# Loaded ground truth mask for image ID: fold_3_1113
# Image ID fold_3_1113: Dice Score = 0.1635, IoU = 0.0890
# Saved predicted mask for image ID fold_3_1113 at results\predicted_masks\fold_3_1113_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1118.png
# Processing image ID: fold_3_1118
# Loaded ground truth mask for image ID: fold_3_1118
# Image ID fold_3_1118: Dice Score = 0.2141, IoU = 0.1199
# Saved predicted mask for image ID fold_3_1118 at results\predicted_masks\fold_3_1118_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1139.png
# Processing image ID: fold_3_1139
# Loaded ground truth mask for image ID: fold_3_1139
# Image ID fold_3_1139: Dice Score = 0.1407, IoU = 0.0757
# Saved predicted mask for image ID fold_3_1139 at results\predicted_masks\fold_3_1139_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1141.png
# Processing image ID: fold_3_1141
# Loaded ground truth mask for image ID: fold_3_1141
# Image ID fold_3_1141: Dice Score = 0.2240, IoU = 0.1261
# Saved predicted mask for image ID fold_3_1141 at results\predicted_masks\fold_3_1141_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1146.png
# Processing image ID: fold_3_1146
# Loaded ground truth mask for image ID: fold_3_1146
# Image ID fold_3_1146: Dice Score = 0.2365, IoU = 0.1341
# Saved predicted mask for image ID fold_3_1146 at results\predicted_masks\fold_3_1146_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1150.png
# Processing image ID: fold_3_1150
# Loaded ground truth mask for image ID: fold_3_1150
# Image ID fold_3_1150: Dice Score = 0.3694, IoU = 0.2265
# Saved predicted mask for image ID fold_3_1150 at results\predicted_masks\fold_3_1150_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1156.png
# Processing image ID: fold_3_1156
# Loaded ground truth mask for image ID: fold_3_1156
# Image ID fold_3_1156: Dice Score = 0.2927, IoU = 0.1714
# Saved predicted mask for image ID fold_3_1156 at results\predicted_masks\fold_3_1156_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1179.png
# Processing image ID: fold_3_1179
# Loaded ground truth mask for image ID: fold_3_1179
# Image ID fold_3_1179: Dice Score = 0.0645, IoU = 0.0333
# Saved predicted mask for image ID fold_3_1179 at results\predicted_masks\fold_3_1179_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1181.png
# Processing image ID: fold_3_1181
# Loaded ground truth mask for image ID: fold_3_1181
# Image ID fold_3_1181: Dice Score = 0.1574, IoU = 0.0854
# Saved predicted mask for image ID fold_3_1181 at results\predicted_masks\fold_3_1181_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1182.png
# Processing image ID: fold_3_1182
# Loaded ground truth mask for image ID: fold_3_1182
# Image ID fold_3_1182: Dice Score = 0.0137, IoU = 0.0069
# Saved predicted mask for image ID fold_3_1182 at results\predicted_masks\fold_3_1182_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1183.png
# Processing image ID: fold_3_1183
# Loaded ground truth mask for image ID: fold_3_1183
# Image ID fold_3_1183: Dice Score = 0.4080, IoU = 0.2563
# Saved predicted mask for image ID fold_3_1183 at results\predicted_masks\fold_3_1183_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1212.png
# Processing image ID: fold_3_1212
# Loaded ground truth mask for image ID: fold_3_1212
# Image ID fold_3_1212: Dice Score = 0.2192, IoU = 0.1231
# Saved predicted mask for image ID fold_3_1212 at results\predicted_masks\fold_3_1212_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1227.png
# Processing image ID: fold_3_1227
# Loaded ground truth mask for image ID: fold_3_1227
# Image ID fold_3_1227: Dice Score = 0.3939, IoU = 0.2452
# Saved predicted mask for image ID fold_3_1227 at results\predicted_masks\fold_3_1227_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1237.png
# Processing image ID: fold_3_1237
# Loaded ground truth mask for image ID: fold_3_1237
# Image ID fold_3_1237: Dice Score = 0.4131, IoU = 0.2603
# Saved predicted mask for image ID fold_3_1237 at results\predicted_masks\fold_3_1237_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1242.png
# Processing image ID: fold_3_1242
# Loaded ground truth mask for image ID: fold_3_1242
# Image ID fold_3_1242: Dice Score = 0.5325, IoU = 0.3628
# Saved predicted mask for image ID fold_3_1242 at results\predicted_masks\fold_3_1242_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1263.png
# Processing image ID: fold_3_1263
# Loaded ground truth mask for image ID: fold_3_1263
# Image ID fold_3_1263: Dice Score = 0.1668, IoU = 0.0910
# Saved predicted mask for image ID fold_3_1263 at results\predicted_masks\fold_3_1263_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1275.png
# Processing image ID: fold_3_1275
# Loaded ground truth mask for image ID: fold_3_1275
# Image ID fold_3_1275: Dice Score = 0.0743, IoU = 0.0386
# Saved predicted mask for image ID fold_3_1275 at results\predicted_masks\fold_3_1275_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1316.png
# Processing image ID: fold_3_1316
# Loaded ground truth mask for image ID: fold_3_1316
# Image ID fold_3_1316: Dice Score = 0.1088, IoU = 0.0575
# Saved predicted mask for image ID fold_3_1316 at results\predicted_masks\fold_3_1316_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1320.png
# Processing image ID: fold_3_1320
# Loaded ground truth mask for image ID: fold_3_1320
# Image ID fold_3_1320: Dice Score = 0.0145, IoU = 0.0073
# Saved predicted mask for image ID fold_3_1320 at results\predicted_masks\fold_3_1320_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1330.png
# Processing image ID: fold_3_1330
# Loaded ground truth mask for image ID: fold_3_1330
# Image ID fold_3_1330: Dice Score = 0.0526, IoU = 0.0270
# Saved predicted mask for image ID fold_3_1330 at results\predicted_masks\fold_3_1330_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1334.png
# Processing image ID: fold_3_1334
# Loaded ground truth mask for image ID: fold_3_1334
# Image ID fold_3_1334: Dice Score = 0.4342, IoU = 0.2773
# Saved predicted mask for image ID fold_3_1334 at results\predicted_masks\fold_3_1334_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1336.png
# Processing image ID: fold_3_1336
# Loaded ground truth mask for image ID: fold_3_1336
# Image ID fold_3_1336: Dice Score = 0.5949, IoU = 0.4233
# Saved predicted mask for image ID fold_3_1336 at results\predicted_masks\fold_3_1336_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1341.png
# Processing image ID: fold_3_1341
# Loaded ground truth mask for image ID: fold_3_1341
# Image ID fold_3_1341: Dice Score = 0.2992, IoU = 0.1759
# Saved predicted mask for image ID fold_3_1341 at results\predicted_masks\fold_3_1341_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1344.png
# Processing image ID: fold_3_1344
# Loaded ground truth mask for image ID: fold_3_1344
# Image ID fold_3_1344: Dice Score = 0.5574, IoU = 0.3863
# Saved predicted mask for image ID fold_3_1344 at results\predicted_masks\fold_3_1344_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1347.png
# Processing image ID: fold_3_1347
# Loaded ground truth mask for image ID: fold_3_1347
# Image ID fold_3_1347: Dice Score = 0.1161, IoU = 0.0616
# Saved predicted mask for image ID fold_3_1347 at results\predicted_masks\fold_3_1347_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1359.png
# Processing image ID: fold_3_1359
# Loaded ground truth mask for image ID: fold_3_1359
# Image ID fold_3_1359: Dice Score = 0.2457, IoU = 0.1400
# Saved predicted mask for image ID fold_3_1359 at results\predicted_masks\fold_3_1359_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1367.png
# Processing image ID: fold_3_1367
# Loaded ground truth mask for image ID: fold_3_1367
# Image ID fold_3_1367: Dice Score = 0.3202, IoU = 0.1906
# Saved predicted mask for image ID fold_3_1367 at results\predicted_masks\fold_3_1367_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1368.png
# Processing image ID: fold_3_1368
# Loaded ground truth mask for image ID: fold_3_1368
# Image ID fold_3_1368: Dice Score = 0.3783, IoU = 0.2333
# Saved predicted mask for image ID fold_3_1368 at results\predicted_masks\fold_3_1368_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1384.png
# Processing image ID: fold_3_1384
# Loaded ground truth mask for image ID: fold_3_1384
# Image ID fold_3_1384: Dice Score = 0.2956, IoU = 0.1734
# Saved predicted mask for image ID fold_3_1384 at results\predicted_masks\fold_3_1384_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_140.png
# Processing image ID: fold_3_140
# Loaded ground truth mask for image ID: fold_3_140
# Image ID fold_3_140: Dice Score = 0.1715, IoU = 0.0938
# Saved predicted mask for image ID fold_3_140 at results\predicted_masks\fold_3_140_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1400.png
# Processing image ID: fold_3_1400
# Loaded ground truth mask for image ID: fold_3_1400
# Image ID fold_3_1400: Dice Score = 0.3583, IoU = 0.2182
# Saved predicted mask for image ID fold_3_1400 at results\predicted_masks\fold_3_1400_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1455.png
# Processing image ID: fold_3_1455
# Loaded ground truth mask for image ID: fold_3_1455
# Image ID fold_3_1455: Dice Score = 0.2499, IoU = 0.1428
# Saved predicted mask for image ID fold_3_1455 at results\predicted_masks\fold_3_1455_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1456.png
# Processing image ID: fold_3_1456
# Loaded ground truth mask for image ID: fold_3_1456
# Image ID fold_3_1456: Dice Score = 0.0452, IoU = 0.0231
# Saved predicted mask for image ID fold_3_1456 at results\predicted_masks\fold_3_1456_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_15.png
# Processing image ID: fold_3_15
# Loaded ground truth mask for image ID: fold_3_15
# Image ID fold_3_15: Dice Score = 0.1715, IoU = 0.0938
# Saved predicted mask for image ID fold_3_15 at results\predicted_masks\fold_3_15_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1503.png
# Processing image ID: fold_3_1503
# Loaded ground truth mask for image ID: fold_3_1503
# Image ID fold_3_1503: Dice Score = 0.3885, IoU = 0.2411
# Saved predicted mask for image ID fold_3_1503 at results\predicted_masks\fold_3_1503_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1511.png
# Processing image ID: fold_3_1511
# Loaded ground truth mask for image ID: fold_3_1511
# Image ID fold_3_1511: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1511 at results\predicted_masks\fold_3_1511_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1512.png
# Processing image ID: fold_3_1512
# Loaded ground truth mask for image ID: fold_3_1512
# Image ID fold_3_1512: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1512 at results\predicted_masks\fold_3_1512_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1529.png
# Processing image ID: fold_3_1529
# Loaded ground truth mask for image ID: fold_3_1529
# Image ID fold_3_1529: Dice Score = 0.0431, IoU = 0.0220
# Saved predicted mask for image ID fold_3_1529 at results\predicted_masks\fold_3_1529_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_153.png
# Processing image ID: fold_3_153
# Loaded ground truth mask for image ID: fold_3_153
# Image ID fold_3_153: Dice Score = 0.0575, IoU = 0.0296
# Saved predicted mask for image ID fold_3_153 at results\predicted_masks\fold_3_153_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_154.png
# Processing image ID: fold_3_154
# Loaded ground truth mask for image ID: fold_3_154
# Image ID fold_3_154: Dice Score = 0.0209, IoU = 0.0106
# Saved predicted mask for image ID fold_3_154 at results\predicted_masks\fold_3_154_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1547.png
# Processing image ID: fold_3_1547
# Loaded ground truth mask for image ID: fold_3_1547
# Image ID fold_3_1547: Dice Score = 0.0879, IoU = 0.0459
# Saved predicted mask for image ID fold_3_1547 at results\predicted_masks\fold_3_1547_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1555.png
# Processing image ID: fold_3_1555
# Loaded ground truth mask for image ID: fold_3_1555
# Image ID fold_3_1555: Dice Score = 0.2909, IoU = 0.1702
# Saved predicted mask for image ID fold_3_1555 at results\predicted_masks\fold_3_1555_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1568.png
# Processing image ID: fold_3_1568
# Loaded ground truth mask for image ID: fold_3_1568
# Image ID fold_3_1568: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1568 at results\predicted_masks\fold_3_1568_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1587.png
# Processing image ID: fold_3_1587
# Loaded ground truth mask for image ID: fold_3_1587
# Image ID fold_3_1587: Dice Score = 0.3507, IoU = 0.2126
# Saved predicted mask for image ID fold_3_1587 at results\predicted_masks\fold_3_1587_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1590.png
# Processing image ID: fold_3_1590
# Loaded ground truth mask for image ID: fold_3_1590
# Image ID fold_3_1590: Dice Score = 0.4123, IoU = 0.2597
# Saved predicted mask for image ID fold_3_1590 at results\predicted_masks\fold_3_1590_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1593.png
# Processing image ID: fold_3_1593
# Loaded ground truth mask for image ID: fold_3_1593
# Image ID fold_3_1593: Dice Score = 0.4768, IoU = 0.3130
# Saved predicted mask for image ID fold_3_1593 at results\predicted_masks\fold_3_1593_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_16.png
# Processing image ID: fold_3_16
# Loaded ground truth mask for image ID: fold_3_16
# Image ID fold_3_16: Dice Score = 0.1900, IoU = 0.1049
# Saved predicted mask for image ID fold_3_16 at results\predicted_masks\fold_3_16_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_160.png
# Processing image ID: fold_3_160
# Loaded ground truth mask for image ID: fold_3_160
# Image ID fold_3_160: Dice Score = 0.0527, IoU = 0.0270
# Saved predicted mask for image ID fold_3_160 at results\predicted_masks\fold_3_160_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_162.png
# Processing image ID: fold_3_162
# Loaded ground truth mask for image ID: fold_3_162
# Image ID fold_3_162: Dice Score = 0.0725, IoU = 0.0376
# Saved predicted mask for image ID fold_3_162 at results\predicted_masks\fold_3_162_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1650.png
# Processing image ID: fold_3_1650
# Loaded ground truth mask for image ID: fold_3_1650
# Image ID fold_3_1650: Dice Score = 0.3664, IoU = 0.2243
# Saved predicted mask for image ID fold_3_1650 at results\predicted_masks\fold_3_1650_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1659.png
# Processing image ID: fold_3_1659
# Loaded ground truth mask for image ID: fold_3_1659
# Image ID fold_3_1659: Dice Score = 0.1559, IoU = 0.0845
# Saved predicted mask for image ID fold_3_1659 at results\predicted_masks\fold_3_1659_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1663.png
# Processing image ID: fold_3_1663
# Loaded ground truth mask for image ID: fold_3_1663
# Image ID fold_3_1663: Dice Score = 0.3307, IoU = 0.1981
# Saved predicted mask for image ID fold_3_1663 at results\predicted_masks\fold_3_1663_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1665.png
# Processing image ID: fold_3_1665
# Loaded ground truth mask for image ID: fold_3_1665
# Image ID fold_3_1665: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1665 at results\predicted_masks\fold_3_1665_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1671.png
# Processing image ID: fold_3_1671
# Loaded ground truth mask for image ID: fold_3_1671
# Image ID fold_3_1671: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1671 at results\predicted_masks\fold_3_1671_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1674.png
# Processing image ID: fold_3_1674
# Loaded ground truth mask for image ID: fold_3_1674
# Image ID fold_3_1674: Dice Score = 0.6497, IoU = 0.4812
# Saved predicted mask for image ID fold_3_1674 at results\predicted_masks\fold_3_1674_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1683.png
# Processing image ID: fold_3_1683
# Loaded ground truth mask for image ID: fold_3_1683
# Image ID fold_3_1683: Dice Score = 0.4586, IoU = 0.2975
# Saved predicted mask for image ID fold_3_1683 at results\predicted_masks\fold_3_1683_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1687.png
# Processing image ID: fold_3_1687
# Loaded ground truth mask for image ID: fold_3_1687
# Image ID fold_3_1687: Dice Score = 0.4320, IoU = 0.2755
# Saved predicted mask for image ID fold_3_1687 at results\predicted_masks\fold_3_1687_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1689.png
# Processing image ID: fold_3_1689
# Loaded ground truth mask for image ID: fold_3_1689
# Image ID fold_3_1689: Dice Score = 0.4115, IoU = 0.2591
# Saved predicted mask for image ID fold_3_1689 at results\predicted_masks\fold_3_1689_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1701.png
# Processing image ID: fold_3_1701
# Loaded ground truth mask for image ID: fold_3_1701
# Image ID fold_3_1701: Dice Score = 0.4703, IoU = 0.3074
# Saved predicted mask for image ID fold_3_1701 at results\predicted_masks\fold_3_1701_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_18.png
# Processing image ID: fold_3_18
# Loaded ground truth mask for image ID: fold_3_18
# Image ID fold_3_18: Dice Score = 0.3342, IoU = 0.2007
# Saved predicted mask for image ID fold_3_18 at results\predicted_masks\fold_3_18_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1838.png
# Processing image ID: fold_3_1838
# Loaded ground truth mask for image ID: fold_3_1838
# Image ID fold_3_1838: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1838 at results\predicted_masks\fold_3_1838_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1853.png
# Processing image ID: fold_3_1853
# Loaded ground truth mask for image ID: fold_3_1853
# Image ID fold_3_1853: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1853 at results\predicted_masks\fold_3_1853_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1940.png
# Processing image ID: fold_3_1940
# Loaded ground truth mask for image ID: fold_3_1940
# Image ID fold_3_1940: Dice Score = 0.4361, IoU = 0.2788
# Saved predicted mask for image ID fold_3_1940 at results\predicted_masks\fold_3_1940_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1945.png
# Processing image ID: fold_3_1945
# Loaded ground truth mask for image ID: fold_3_1945
# Image ID fold_3_1945: Dice Score = 0.0149, IoU = 0.0075
# Saved predicted mask for image ID fold_3_1945 at results\predicted_masks\fold_3_1945_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1953.png
# Processing image ID: fold_3_1953
# Loaded ground truth mask for image ID: fold_3_1953
# Image ID fold_3_1953: Dice Score = 0.3297, IoU = 0.1974
# Saved predicted mask for image ID fold_3_1953 at results\predicted_masks\fold_3_1953_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1954.png
# Processing image ID: fold_3_1954
# Loaded ground truth mask for image ID: fold_3_1954
# Image ID fold_3_1954: Dice Score = 0.3619, IoU = 0.2209
# Saved predicted mask for image ID fold_3_1954 at results\predicted_masks\fold_3_1954_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1960.png
# Processing image ID: fold_3_1960
# Loaded ground truth mask for image ID: fold_3_1960
# Image ID fold_3_1960: Dice Score = 0.2302, IoU = 0.1301
# Saved predicted mask for image ID fold_3_1960 at results\predicted_masks\fold_3_1960_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1970.png
# Processing image ID: fold_3_1970
# Loaded ground truth mask for image ID: fold_3_1970
# Image ID fold_3_1970: Dice Score = 0.4000, IoU = 0.2500
# Saved predicted mask for image ID fold_3_1970 at results\predicted_masks\fold_3_1970_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1989.png
# Processing image ID: fold_3_1989
# Loaded ground truth mask for image ID: fold_3_1989
# Image ID fold_3_1989: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1989 at results\predicted_masks\fold_3_1989_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2006.png
# Processing image ID: fold_3_2006
# Loaded ground truth mask for image ID: fold_3_2006
# Image ID fold_3_2006: Dice Score = 0.2843, IoU = 0.1657
# Saved predicted mask for image ID fold_3_2006 at results\predicted_masks\fold_3_2006_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2015.png
# Processing image ID: fold_3_2015
# Loaded ground truth mask for image ID: fold_3_2015
# Image ID fold_3_2015: Dice Score = 0.2538, IoU = 0.1453
# Saved predicted mask for image ID fold_3_2015 at results\predicted_masks\fold_3_2015_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2022.png
# Processing image ID: fold_3_2022
# Loaded ground truth mask for image ID: fold_3_2022
# Image ID fold_3_2022: Dice Score = 0.2175, IoU = 0.1220
# Saved predicted mask for image ID fold_3_2022 at results\predicted_masks\fold_3_2022_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2099.png
# Processing image ID: fold_3_2099
# Loaded ground truth mask for image ID: fold_3_2099
# Image ID fold_3_2099: Dice Score = 0.6582, IoU = 0.4905
# Saved predicted mask for image ID fold_3_2099 at results\predicted_masks\fold_3_2099_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2121.png
# Processing image ID: fold_3_2121
# Loaded ground truth mask for image ID: fold_3_2121
# Image ID fold_3_2121: Dice Score = 0.1679, IoU = 0.0917
# Saved predicted mask for image ID fold_3_2121 at results\predicted_masks\fold_3_2121_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2126.png
# Processing image ID: fold_3_2126
# Loaded ground truth mask for image ID: fold_3_2126
# Image ID fold_3_2126: Dice Score = 0.1591, IoU = 0.0864
# Saved predicted mask for image ID fold_3_2126 at results\predicted_masks\fold_3_2126_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2130.png
# Processing image ID: fold_3_2130
# Loaded ground truth mask for image ID: fold_3_2130
# Image ID fold_3_2130: Dice Score = 0.6162, IoU = 0.4453
# Saved predicted mask for image ID fold_3_2130 at results\predicted_masks\fold_3_2130_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2156.png
# Processing image ID: fold_3_2156
# Loaded ground truth mask for image ID: fold_3_2156
# Image ID fold_3_2156: Dice Score = 0.2284, IoU = 0.1289
# Saved predicted mask for image ID fold_3_2156 at results\predicted_masks\fold_3_2156_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2169.png
# Processing image ID: fold_3_2169
# Loaded ground truth mask for image ID: fold_3_2169
# Image ID fold_3_2169: Dice Score = 0.1689, IoU = 0.0922
# Saved predicted mask for image ID fold_3_2169 at results\predicted_masks\fold_3_2169_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2171.png
# Processing image ID: fold_3_2171
# Loaded ground truth mask for image ID: fold_3_2171
# Image ID fold_3_2171: Dice Score = 0.0496, IoU = 0.0254
# Saved predicted mask for image ID fold_3_2171 at results\predicted_masks\fold_3_2171_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2174.png
# Processing image ID: fold_3_2174
# Loaded ground truth mask for image ID: fold_3_2174
# Image ID fold_3_2174: Dice Score = 0.1413, IoU = 0.0760
# Saved predicted mask for image ID fold_3_2174 at results\predicted_masks\fold_3_2174_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2207.png
# Processing image ID: fold_3_2207
# Loaded ground truth mask for image ID: fold_3_2207
# Image ID fold_3_2207: Dice Score = 0.3756, IoU = 0.2312
# Saved predicted mask for image ID fold_3_2207 at results\predicted_masks\fold_3_2207_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2214.png
# Processing image ID: fold_3_2214
# Loaded ground truth mask for image ID: fold_3_2214
# Image ID fold_3_2214: Dice Score = 0.3659, IoU = 0.2239
# Saved predicted mask for image ID fold_3_2214 at results\predicted_masks\fold_3_2214_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2228.png
# Processing image ID: fold_3_2228
# Loaded ground truth mask for image ID: fold_3_2228
# Image ID fold_3_2228: Dice Score = 0.3069, IoU = 0.1812
# Saved predicted mask for image ID fold_3_2228 at results\predicted_masks\fold_3_2228_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2260.png
# Processing image ID: fold_3_2260
# Loaded ground truth mask for image ID: fold_3_2260
# Image ID fold_3_2260: Dice Score = 0.3429, IoU = 0.2069
# Saved predicted mask for image ID fold_3_2260 at results\predicted_masks\fold_3_2260_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2264.png
# Processing image ID: fold_3_2264
# Loaded ground truth mask for image ID: fold_3_2264
# Image ID fold_3_2264: Dice Score = 0.0399, IoU = 0.0203
# Saved predicted mask for image ID fold_3_2264 at results\predicted_masks\fold_3_2264_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2287.png
# Processing image ID: fold_3_2287
# Loaded ground truth mask for image ID: fold_3_2287
# Image ID fold_3_2287: Dice Score = 0.3832, IoU = 0.2370
# Saved predicted mask for image ID fold_3_2287 at results\predicted_masks\fold_3_2287_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2312.png
# Processing image ID: fold_3_2312
# Loaded ground truth mask for image ID: fold_3_2312
# Image ID fold_3_2312: Dice Score = 0.6675, IoU = 0.5009
# Saved predicted mask for image ID fold_3_2312 at results\predicted_masks\fold_3_2312_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2339.png
# Processing image ID: fold_3_2339
# Loaded ground truth mask for image ID: fold_3_2339
# Image ID fold_3_2339: Dice Score = 0.4171, IoU = 0.2635
# Saved predicted mask for image ID fold_3_2339 at results\predicted_masks\fold_3_2339_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2345.png
# Processing image ID: fold_3_2345
# Loaded ground truth mask for image ID: fold_3_2345
# Image ID fold_3_2345: Dice Score = 0.2709, IoU = 0.1567
# Saved predicted mask for image ID fold_3_2345 at results\predicted_masks\fold_3_2345_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2372.png
# Processing image ID: fold_3_2372
# Loaded ground truth mask for image ID: fold_3_2372
# Image ID fold_3_2372: Dice Score = 0.1438, IoU = 0.0775
# Saved predicted mask for image ID fold_3_2372 at results\predicted_masks\fold_3_2372_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_238.png
# Processing image ID: fold_3_238
# Loaded ground truth mask for image ID: fold_3_238
# Image ID fold_3_238: Dice Score = 0.1027, IoU = 0.0541
# Saved predicted mask for image ID fold_3_238 at results\predicted_masks\fold_3_238_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2399.png
# Processing image ID: fold_3_2399
# Loaded ground truth mask for image ID: fold_3_2399
# Image ID fold_3_2399: Dice Score = 0.5461, IoU = 0.3756
# Saved predicted mask for image ID fold_3_2399 at results\predicted_masks\fold_3_2399_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2422.png
# Processing image ID: fold_3_2422
# Loaded ground truth mask for image ID: fold_3_2422
# Image ID fold_3_2422: Dice Score = 0.2762, IoU = 0.1602
# Saved predicted mask for image ID fold_3_2422 at results\predicted_masks\fold_3_2422_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2423.png
# Processing image ID: fold_3_2423
# Loaded ground truth mask for image ID: fold_3_2423
# Image ID fold_3_2423: Dice Score = 0.3682, IoU = 0.2256
# Saved predicted mask for image ID fold_3_2423 at results\predicted_masks\fold_3_2423_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2430.png
# Processing image ID: fold_3_2430
# Loaded ground truth mask for image ID: fold_3_2430
# Image ID fold_3_2430: Dice Score = 0.3485, IoU = 0.2110
# Saved predicted mask for image ID fold_3_2430 at results\predicted_masks\fold_3_2430_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2468.png
# Processing image ID: fold_3_2468
# Loaded ground truth mask for image ID: fold_3_2468
# Image ID fold_3_2468: Dice Score = 0.3658, IoU = 0.2238
# Saved predicted mask for image ID fold_3_2468 at results\predicted_masks\fold_3_2468_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2470.png
# Processing image ID: fold_3_2470
# Loaded ground truth mask for image ID: fold_3_2470
# Image ID fold_3_2470: Dice Score = 0.4218, IoU = 0.2672
# Saved predicted mask for image ID fold_3_2470 at results\predicted_masks\fold_3_2470_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2515.png
# Processing image ID: fold_3_2515
# Loaded ground truth mask for image ID: fold_3_2515
# Image ID fold_3_2515: Dice Score = 0.3483, IoU = 0.2109
# Saved predicted mask for image ID fold_3_2515 at results\predicted_masks\fold_3_2515_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2517.png
# Processing image ID: fold_3_2517
# Loaded ground truth mask for image ID: fold_3_2517
# Image ID fold_3_2517: Dice Score = 0.3790, IoU = 0.2338
# Saved predicted mask for image ID fold_3_2517 at results\predicted_masks\fold_3_2517_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2547.png
# Processing image ID: fold_3_2547
# Loaded ground truth mask for image ID: fold_3_2547
# Image ID fold_3_2547: Dice Score = 0.5501, IoU = 0.3794
# Saved predicted mask for image ID fold_3_2547 at results\predicted_masks\fold_3_2547_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2557.png
# Processing image ID: fold_3_2557
# Loaded ground truth mask for image ID: fold_3_2557
# Image ID fold_3_2557: Dice Score = 0.3608, IoU = 0.2201
# Saved predicted mask for image ID fold_3_2557 at results\predicted_masks\fold_3_2557_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2608.png
# Processing image ID: fold_3_2608
# Loaded ground truth mask for image ID: fold_3_2608
# Image ID fold_3_2608: Dice Score = 0.5188, IoU = 0.3503
# Saved predicted mask for image ID fold_3_2608 at results\predicted_masks\fold_3_2608_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2633.png
# Processing image ID: fold_3_2633
# Loaded ground truth mask for image ID: fold_3_2633
# Image ID fold_3_2633: Dice Score = 0.4095, IoU = 0.2575
# Saved predicted mask for image ID fold_3_2633 at results\predicted_masks\fold_3_2633_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2659.png
# Processing image ID: fold_3_2659
# Loaded ground truth mask for image ID: fold_3_2659
# Image ID fold_3_2659: Dice Score = 0.4039, IoU = 0.2530
# Saved predicted mask for image ID fold_3_2659 at results\predicted_masks\fold_3_2659_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2678.png
# Processing image ID: fold_3_2678
# Loaded ground truth mask for image ID: fold_3_2678
# Image ID fold_3_2678: Dice Score = 0.0362, IoU = 0.0184
# Saved predicted mask for image ID fold_3_2678 at results\predicted_masks\fold_3_2678_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2715.png
# Processing image ID: fold_3_2715
# Loaded ground truth mask for image ID: fold_3_2715
# Image ID fold_3_2715: Dice Score = 0.4932, IoU = 0.3273
# Saved predicted mask for image ID fold_3_2715 at results\predicted_masks\fold_3_2715_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2716.png
# Processing image ID: fold_3_2716
# Loaded ground truth mask for image ID: fold_3_2716
# Image ID fold_3_2716: Dice Score = 0.4739, IoU = 0.3105
# Saved predicted mask for image ID fold_3_2716 at results\predicted_masks\fold_3_2716_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2717.png
# Processing image ID: fold_3_2717
# Loaded ground truth mask for image ID: fold_3_2717
# Image ID fold_3_2717: Dice Score = 0.5510, IoU = 0.3803
# Saved predicted mask for image ID fold_3_2717 at results\predicted_masks\fold_3_2717_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_30.png
# Processing image ID: fold_3_30
# Loaded ground truth mask for image ID: fold_3_30
# Image ID fold_3_30: Dice Score = 0.0018, IoU = 0.0009
# Saved predicted mask for image ID fold_3_30 at results\predicted_masks\fold_3_30_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_316.png
# Processing image ID: fold_3_316
# Loaded ground truth mask for image ID: fold_3_316
# Image ID fold_3_316: Dice Score = 0.5555, IoU = 0.3845
# Saved predicted mask for image ID fold_3_316 at results\predicted_masks\fold_3_316_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_331.png
# Processing image ID: fold_3_331
# Loaded ground truth mask for image ID: fold_3_331
# Image ID fold_3_331: Dice Score = 0.2246, IoU = 0.1265
# Saved predicted mask for image ID fold_3_331 at results\predicted_masks\fold_3_331_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_332.png
# Processing image ID: fold_3_332
# Loaded ground truth mask for image ID: fold_3_332
# Image ID fold_3_332: Dice Score = 0.3033, IoU = 0.1787
# Saved predicted mask for image ID fold_3_332 at results\predicted_masks\fold_3_332_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_34.png
# Processing image ID: fold_3_34
# Loaded ground truth mask for image ID: fold_3_34
# Image ID fold_3_34: Dice Score = 0.1054, IoU = 0.0556
# Saved predicted mask for image ID fold_3_34 at results\predicted_masks\fold_3_34_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_356.png
# Processing image ID: fold_3_356
# Loaded ground truth mask for image ID: fold_3_356
# Image ID fold_3_356: Dice Score = 0.2977, IoU = 0.1749
# Saved predicted mask for image ID fold_3_356 at results\predicted_masks\fold_3_356_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_370.png
# Processing image ID: fold_3_370
# Loaded ground truth mask for image ID: fold_3_370
# Image ID fold_3_370: Dice Score = 0.4044, IoU = 0.2534
# Saved predicted mask for image ID fold_3_370 at results\predicted_masks\fold_3_370_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_384.png
# Processing image ID: fold_3_384
# Loaded ground truth mask for image ID: fold_3_384
# Image ID fold_3_384: Dice Score = 0.2704, IoU = 0.1564
# Saved predicted mask for image ID fold_3_384 at results\predicted_masks\fold_3_384_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_388.png
# Processing image ID: fold_3_388
# Loaded ground truth mask for image ID: fold_3_388
# Image ID fold_3_388: Dice Score = 0.0326, IoU = 0.0166
# Saved predicted mask for image ID fold_3_388 at results\predicted_masks\fold_3_388_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_427.png
# Processing image ID: fold_3_427
# Loaded ground truth mask for image ID: fold_3_427
# Image ID fold_3_427: Dice Score = 0.5004, IoU = 0.3337
# Saved predicted mask for image ID fold_3_427 at results\predicted_masks\fold_3_427_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_428.png
# Processing image ID: fold_3_428
# Loaded ground truth mask for image ID: fold_3_428
# Image ID fold_3_428: Dice Score = 0.2670, IoU = 0.1541
# Saved predicted mask for image ID fold_3_428 at results\predicted_masks\fold_3_428_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_440.png
# Processing image ID: fold_3_440
# Loaded ground truth mask for image ID: fold_3_440
# Image ID fold_3_440: Dice Score = 0.1303, IoU = 0.0697
# Saved predicted mask for image ID fold_3_440 at results\predicted_masks\fold_3_440_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_444.png
# Processing image ID: fold_3_444
# Loaded ground truth mask for image ID: fold_3_444
# Image ID fold_3_444: Dice Score = 0.0231, IoU = 0.0117
# Saved predicted mask for image ID fold_3_444 at results\predicted_masks\fold_3_444_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_460.png
# Processing image ID: fold_3_460
# Loaded ground truth mask for image ID: fold_3_460
# Image ID fold_3_460: Dice Score = 0.2640, IoU = 0.1521
# Saved predicted mask for image ID fold_3_460 at results\predicted_masks\fold_3_460_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_462.png
# Processing image ID: fold_3_462
# Loaded ground truth mask for image ID: fold_3_462
# Image ID fold_3_462: Dice Score = 0.0420, IoU = 0.0214
# Saved predicted mask for image ID fold_3_462 at results\predicted_masks\fold_3_462_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_465.png
# Processing image ID: fold_3_465
# Loaded ground truth mask for image ID: fold_3_465
# Image ID fold_3_465: Dice Score = 0.0453, IoU = 0.0232
# Saved predicted mask for image ID fold_3_465 at results\predicted_masks\fold_3_465_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_471.png
# Processing image ID: fold_3_471
# Loaded ground truth mask for image ID: fold_3_471
# Image ID fold_3_471: Dice Score = 0.2925, IoU = 0.1713
# Saved predicted mask for image ID fold_3_471 at results\predicted_masks\fold_3_471_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_475.png
# Processing image ID: fold_3_475
# Loaded ground truth mask for image ID: fold_3_475
# Image ID fold_3_475: Dice Score = 0.1068, IoU = 0.0564
# Saved predicted mask for image ID fold_3_475 at results\predicted_masks\fold_3_475_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_479.png
# Processing image ID: fold_3_479
# Loaded ground truth mask for image ID: fold_3_479
# Image ID fold_3_479: Dice Score = 0.0032, IoU = 0.0016
# Saved predicted mask for image ID fold_3_479 at results\predicted_masks\fold_3_479_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_48.png
# Processing image ID: fold_3_48
# Loaded ground truth mask for image ID: fold_3_48
# Image ID fold_3_48: Dice Score = 0.1711, IoU = 0.0935
# Saved predicted mask for image ID fold_3_48 at results\predicted_masks\fold_3_48_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_485.png
# Processing image ID: fold_3_485
# Loaded ground truth mask for image ID: fold_3_485
# Image ID fold_3_485: Dice Score = 0.2947, IoU = 0.1728
# Saved predicted mask for image ID fold_3_485 at results\predicted_masks\fold_3_485_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_49.png
# Processing image ID: fold_3_49
# Loaded ground truth mask for image ID: fold_3_49
# Image ID fold_3_49: Dice Score = 0.0165, IoU = 0.0083
# Saved predicted mask for image ID fold_3_49 at results\predicted_masks\fold_3_49_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_491.png
# Processing image ID: fold_3_491
# Loaded ground truth mask for image ID: fold_3_491
# Image ID fold_3_491: Dice Score = 0.1599, IoU = 0.0869
# Saved predicted mask for image ID fold_3_491 at results\predicted_masks\fold_3_491_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_495.png
# Processing image ID: fold_3_495
# Loaded ground truth mask for image ID: fold_3_495
# Image ID fold_3_495: Dice Score = 0.4395, IoU = 0.2816
# Saved predicted mask for image ID fold_3_495 at results\predicted_masks\fold_3_495_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_513.png
# Processing image ID: fold_3_513
# Loaded ground truth mask for image ID: fold_3_513
# Image ID fold_3_513: Dice Score = 0.0115, IoU = 0.0058
# Saved predicted mask for image ID fold_3_513 at results\predicted_masks\fold_3_513_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_516.png
# Processing image ID: fold_3_516
# Loaded ground truth mask for image ID: fold_3_516
# Image ID fold_3_516: Dice Score = 0.4068, IoU = 0.2554
# Saved predicted mask for image ID fold_3_516 at results\predicted_masks\fold_3_516_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_518.png
# Processing image ID: fold_3_518
# Loaded ground truth mask for image ID: fold_3_518
# Image ID fold_3_518: Dice Score = 0.0041, IoU = 0.0020
# Saved predicted mask for image ID fold_3_518 at results\predicted_masks\fold_3_518_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_526.png
# Processing image ID: fold_3_526
# Loaded ground truth mask for image ID: fold_3_526
# Image ID fold_3_526: Dice Score = 0.1943, IoU = 0.1076
# ...
# Processing image ID: fold_3_654
# Loaded ground truth mask for image ID: fold_3_654
# Image ID fold_3_654: Dice Score = 0.1196, IoU = 0.0636
# Saved predicted mask for image ID fold_3_654 at results\predicted_masks\fold_3_654_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_659.png
# Processing image ID: fold_3_659
# Loaded ground truth mask for image ID: fold_3_659
# Image ID fold_3_659: Dice Score = 0.1557, IoU = 0.0844
# Saved predicted mask for image ID fold_3_659 at results\predicted_masks\fold_3_659_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_661.png
# Processing image ID: fold_3_661
# Loaded ground truth mask for image ID: fold_3_661
# Image ID fold_3_661: Dice Score = 0.3789, IoU = 0.2337
# Saved predicted mask for image ID fold_3_661 at results\predicted_masks\fold_3_661_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_662.png
# Processing image ID: fold_3_662
# Loaded ground truth mask for image ID: fold_3_662
# Image ID fold_3_662: Dice Score = 0.2187, IoU = 0.1228
# Saved predicted mask for image ID fold_3_662 at results\predicted_masks\fold_3_662_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_675.png
# Processing image ID: fold_3_675
# Loaded ground truth mask for image ID: fold_3_675
# Image ID fold_3_675: Dice Score = 0.2466, IoU = 0.1406
# Saved predicted mask for image ID fold_3_675 at results\predicted_masks\fold_3_675_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_677.png
# Processing image ID: fold_3_677
# Loaded ground truth mask for image ID: fold_3_677
# Image ID fold_3_677: Dice Score = 0.3485, IoU = 0.2110
# Saved predicted mask for image ID fold_3_677 at results\predicted_masks\fold_3_677_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_680.png
# Processing image ID: fold_3_680
# Loaded ground truth mask for image ID: fold_3_680
# Image ID fold_3_680: Dice Score = 0.3312, IoU = 0.1984
# Saved predicted mask for image ID fold_3_680 at results\predicted_masks\fold_3_680_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_684.png
# Processing image ID: fold_3_684
# Loaded ground truth mask for image ID: fold_3_684
# Image ID fold_3_684: Dice Score = 0.4781, IoU = 0.3142
# Saved predicted mask for image ID fold_3_684 at results\predicted_masks\fold_3_684_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_690.png
# Processing image ID: fold_3_690
# Loaded ground truth mask for image ID: fold_3_690
# Image ID fold_3_690: Dice Score = 0.2522, IoU = 0.1443
# Saved predicted mask for image ID fold_3_690 at results\predicted_masks\fold_3_690_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_701.png
# Processing image ID: fold_3_701
# Loaded ground truth mask for image ID: fold_3_701
# Image ID fold_3_701: Dice Score = 0.3221, IoU = 0.1919
# Saved predicted mask for image ID fold_3_701 at results\predicted_masks\fold_3_701_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_705.png
# Processing image ID: fold_3_705
# Loaded ground truth mask for image ID: fold_3_705
# Image ID fold_3_705: Dice Score = 0.1620, IoU = 0.0882
# Saved predicted mask for image ID fold_3_705 at results\predicted_masks\fold_3_705_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_711.png
# Processing image ID: fold_3_711
# Loaded ground truth mask for image ID: fold_3_711
# Image ID fold_3_711: Dice Score = 0.0291, IoU = 0.0147
# Saved predicted mask for image ID fold_3_711 at results\predicted_masks\fold_3_711_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_715.png
# Processing image ID: fold_3_715
# Loaded ground truth mask for image ID: fold_3_715
# Image ID fold_3_715: Dice Score = 0.2239, IoU = 0.1261
# Saved predicted mask for image ID fold_3_715 at results\predicted_masks\fold_3_715_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_718.png
# Processing image ID: fold_3_718
# Loaded ground truth mask for image ID: fold_3_718
# Image ID fold_3_718: Dice Score = 0.0449, IoU = 0.0229
# Saved predicted mask for image ID fold_3_718 at results\predicted_masks\fold_3_718_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_740.png
# Processing image ID: fold_3_740
# Loaded ground truth mask for image ID: fold_3_740
# Image ID fold_3_740: Dice Score = 0.3705, IoU = 0.2274
# Saved predicted mask for image ID fold_3_740 at results\predicted_masks\fold_3_740_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_764.png
# Processing image ID: fold_3_764
# Loaded ground truth mask for image ID: fold_3_764
# Image ID fold_3_764: Dice Score = 0.2777, IoU = 0.1612
# Saved predicted mask for image ID fold_3_764 at results\predicted_masks\fold_3_764_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_766.png
# Processing image ID: fold_3_766
# Loaded ground truth mask for image ID: fold_3_766
# Image ID fold_3_766: Dice Score = 0.2476, IoU = 0.1413
# Saved predicted mask for image ID fold_3_766 at results\predicted_masks\fold_3_766_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_769.png
# Processing image ID: fold_3_769
# Loaded ground truth mask for image ID: fold_3_769
# Image ID fold_3_769: Dice Score = 0.3226, IoU = 0.1923
# Saved predicted mask for image ID fold_3_769 at results\predicted_masks\fold_3_769_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_776.png
# Processing image ID: fold_3_776
# Loaded ground truth mask for image ID: fold_3_776
# Image ID fold_3_776: Dice Score = 0.3838, IoU = 0.2375
# Saved predicted mask for image ID fold_3_776 at results\predicted_masks\fold_3_776_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_789.png
# Processing image ID: fold_3_789
# Loaded ground truth mask for image ID: fold_3_789
# Image ID fold_3_789: Dice Score = 0.0219, IoU = 0.0111
# Saved predicted mask for image ID fold_3_789 at results\predicted_masks\fold_3_789_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_790.png
# Processing image ID: fold_3_790
# Loaded ground truth mask for image ID: fold_3_790
# Image ID fold_3_790: Dice Score = 0.1182, IoU = 0.0628
# Saved predicted mask for image ID fold_3_790 at results\predicted_masks\fold_3_790_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_814.png
# Processing image ID: fold_3_814
# Loaded ground truth mask for image ID: fold_3_814
# Image ID fold_3_814: Dice Score = 0.3874, IoU = 0.2402
# Saved predicted mask for image ID fold_3_814 at results\predicted_masks\fold_3_814_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_815.png
# Processing image ID: fold_3_815
# Loaded ground truth mask for image ID: fold_3_815
# Image ID fold_3_815: Dice Score = 0.0119, IoU = 0.0060
# Saved predicted mask for image ID fold_3_815 at results\predicted_masks\fold_3_815_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_818.png
# Processing image ID: fold_3_818
# Loaded ground truth mask for image ID: fold_3_818
# Image ID fold_3_818: Dice Score = 0.4473, IoU = 0.2880
# Saved predicted mask for image ID fold_3_818 at results\predicted_masks\fold_3_818_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_826.png
# Processing image ID: fold_3_826
# Loaded ground truth mask for image ID: fold_3_826
# Image ID fold_3_826: Dice Score = 0.4384, IoU = 0.2808
# Saved predicted mask for image ID fold_3_826 at results\predicted_masks\fold_3_826_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_827.png
# Processing image ID: fold_3_827
# Loaded ground truth mask for image ID: fold_3_827
# Image ID fold_3_827: Dice Score = 0.4030, IoU = 0.2524
# Saved predicted mask for image ID fold_3_827 at results\predicted_masks\fold_3_827_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_838.png
# Processing image ID: fold_3_838
# Loaded ground truth mask for image ID: fold_3_838
# Image ID fold_3_838: Dice Score = 0.2834, IoU = 0.1651
# Saved predicted mask for image ID fold_3_838 at results\predicted_masks\fold_3_838_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_847.png
# Processing image ID: fold_3_847
# Loaded ground truth mask for image ID: fold_3_847
# Image ID fold_3_847: Dice Score = 0.1577, IoU = 0.0856
# Saved predicted mask for image ID fold_3_847 at results\predicted_masks\fold_3_847_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_851.png
# Processing image ID: fold_3_851
# Loaded ground truth mask for image ID: fold_3_851
# Image ID fold_3_851: Dice Score = 0.2388, IoU = 0.1356
# Saved predicted mask for image ID fold_3_851 at results\predicted_masks\fold_3_851_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_862.png
# Processing image ID: fold_3_862
# Loaded ground truth mask for image ID: fold_3_862
# Image ID fold_3_862: Dice Score = 0.2370, IoU = 0.1344
# Saved predicted mask for image ID fold_3_862 at results\predicted_masks\fold_3_862_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_87.png
# Processing image ID: fold_3_87
# Loaded ground truth mask for image ID: fold_3_87
# Image ID fold_3_87: Dice Score = 0.0913, IoU = 0.0479
# Saved predicted mask for image ID fold_3_87 at results\predicted_masks\fold_3_87_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_872.png
# Processing image ID: fold_3_872
# Loaded ground truth mask for image ID: fold_3_872
# Image ID fold_3_872: Dice Score = 0.1817, IoU = 0.0999
# Saved predicted mask for image ID fold_3_872 at results\predicted_masks\fold_3_872_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_878.png
# Processing image ID: fold_3_878
# Loaded ground truth mask for image ID: fold_3_878
# Image ID fold_3_878: Dice Score = 0.2413, IoU = 0.1372
# Saved predicted mask for image ID fold_3_878 at results\predicted_masks\fold_3_878_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_88.png
# Processing image ID: fold_3_88
# Loaded ground truth mask for image ID: fold_3_88
# Image ID fold_3_88: Dice Score = 0.1906, IoU = 0.1053
# Saved predicted mask for image ID fold_3_88 at results\predicted_masks\fold_3_88_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_890.png
# Processing image ID: fold_3_890
# Loaded ground truth mask for image ID: fold_3_890
# Image ID fold_3_890: Dice Score = 0.0299, IoU = 0.0152
# Saved predicted mask for image ID fold_3_890 at results\predicted_masks\fold_3_890_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_908.png
# Processing image ID: fold_3_908
# Loaded ground truth mask for image ID: fold_3_908
# Image ID fold_3_908: Dice Score = 0.5514, IoU = 0.3806
# Saved predicted mask for image ID fold_3_908 at results\predicted_masks\fold_3_908_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_910.png
# Processing image ID: fold_3_910
# Loaded ground truth mask for image ID: fold_3_910
# Image ID fold_3_910: Dice Score = 0.5348, IoU = 0.3650
# Saved predicted mask for image ID fold_3_910 at results\predicted_masks\fold_3_910_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_933.png
# Processing image ID: fold_3_933
# Loaded ground truth mask for image ID: fold_3_933
# Image ID fold_3_933: Dice Score = 0.1432, IoU = 0.0771
# Saved predicted mask for image ID fold_3_933 at results\predicted_masks\fold_3_933_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_934.png
# Processing image ID: fold_3_934
# Loaded ground truth mask for image ID: fold_3_934
# Image ID fold_3_934: Dice Score = 0.0649, IoU = 0.0335
# Saved predicted mask for image ID fold_3_934 at results\predicted_masks\fold_3_934_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_944.png
# Processing image ID: fold_3_944
# Loaded ground truth mask for image ID: fold_3_944
# Image ID fold_3_944: Dice Score = 0.3143, IoU = 0.1864
# Saved predicted mask for image ID fold_3_944 at results\predicted_masks\fold_3_944_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_950.png
# Processing image ID: fold_3_950
# Loaded ground truth mask for image ID: fold_3_950
# Image ID fold_3_950: Dice Score = 0.0099, IoU = 0.0049
# Saved predicted mask for image ID fold_3_950 at results\predicted_masks\fold_3_950_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_960.png
# Processing image ID: fold_3_960
# Loaded ground truth mask for image ID: fold_3_960
# Image ID fold_3_960: Dice Score = 0.4350, IoU = 0.2780
# Saved predicted mask for image ID fold_3_960 at results\predicted_masks\fold_3_960_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_964.png
# Processing image ID: fold_3_964
# Loaded ground truth mask for image ID: fold_3_964
# Image ID fold_3_964: Dice Score = 0.4921, IoU = 0.3263
# Saved predicted mask for image ID fold_3_964 at results\predicted_masks\fold_3_964_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_969.png
# Processing image ID: fold_3_969
# Loaded ground truth mask for image ID: fold_3_969
# Image ID fold_3_969: Dice Score = 0.3680, IoU = 0.2255
# Saved predicted mask for image ID fold_3_969 at results\predicted_masks\fold_3_969_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_972.png
# Processing image ID: fold_3_972
# Loaded ground truth mask for image ID: fold_3_972
# Image ID fold_3_972: Dice Score = 0.4457, IoU = 0.2867
# Saved predicted mask for image ID fold_3_972 at results\predicted_masks\fold_3_972_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_986.png
# Processing image ID: fold_3_986
# Loaded ground truth mask for image ID: fold_3_986
# Image ID fold_3_986: Dice Score = 0.3907, IoU = 0.2427
# Saved predicted mask for image ID fold_3_986 at results\predicted_masks\fold_3_986_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_991.png
# Processing image ID: fold_3_991
# Loaded ground truth mask for image ID: fold_3_991
# Image ID fold_3_991: Dice Score = 0.4037, IoU = 0.2529
# Saved predicted mask for image ID fold_3_991 at results\predicted_masks\fold_3_991_predicted_mask.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_995.png
# Processing image ID: fold_3_995
# Loaded ground truth mask for image ID: fold_3_995
# Image ID fold_3_995: Dice Score = 0.1119, IoU = 0.0592
# Saved predicted mask for image ID fold_3_995 at results\predicted_masks\fold_3_995_predicted_mask.png
# Mean Dice Score on Test Set: 0.3076
# Mean IoU Score on Test Set: 0.2058
# Results saved to results\csv\dice_iou_scores.csv

# %% [markdown]
# ### 4.4. One image per nucleus modified well structured. It iterates the directory of singled mask |

# %%
# Block 9

from skimage.measure import label, regionprops

# Function to calculate IoU
def iou_coefficient(pred_mask, gt_mask, smooth=1e-5):
    pred_mask = (pred_mask > 0.5).astype(np.uint8)
    gt_mask = (gt_mask > 0.5).astype(np.uint8)
    intersection = np.sum(pred_mask * gt_mask)
    union = np.sum(pred_mask) + np.sum(gt_mask) - intersection
    return (intersection + smooth) / (union + smooth)

# Initialize lists to store results
dice_scores = []
iou_scores = []
image_ids_list = []

# Directory to save individual nucleus masks
single_nucleus_masks = results / 'single_nucleus_masks/'
Path(single_nucleus_masks).mkdir(parents=True, exist_ok=True)

# In the prediction loop, after resizing the predicted mask:
for images, image_ids in test_loader:
    images = images.to(device)

    # Make prediction
    with torch.no_grad():
        outputs = model(images)
        predicted_mask = torch.sigmoid(outputs).squeeze().cpu().numpy()

        # Ensure predicted mask is binary
        predicted_mask = (predicted_mask > 0.5).astype(np.uint8)  # Threshold to binary

    image_id = image_ids[0]
    print(f"Processing image ID: {image_id}")  # Debugging: Confirm current image_id

    # Load ground truth mask
    gt_mask_path_full = preprocessed_test_masks / f'{image_id}.png'
    gt_mask = imread(gt_mask_path_full).astype(np.uint8)

    print(f'Loaded ground truth mask for image ID: {image_id}')

    # Ensure the resized predicted mask is binary
    predicted_mask = (predicted_mask > 0.5).astype(np.uint8)

    # Calculate Dice coefficient
    dice_score = dice_coefficient(predicted_mask, gt_mask)

    # Calculate IoU
    iou_score = iou_coefficient(predicted_mask, gt_mask)

    # Append results to the lists
    dice_scores.append(dice_score)
    iou_scores.append(iou_score)
    image_ids_list.append(image_id)

    print(f'Image ID {image_id}: Dice Score = {dice_score:.4f}, IoU = {iou_score:.4f}')  # Debugging

    # Save the predicted mask as png
    save_path = predicted_masks / f'{image_id}_predicted_mask.png'
    imsave(save_path, (predicted_mask * 255).astype(np.uint8))  # Save as uint8
    print(f'Saved predicted mask for image ID {image_id} at {save_path}')  # Debugging

    # ------------------ Additional code to save individual nucleus masks ------------------ #

    # Label connected components in the predicted mask
    labeled_mask = label(predicted_mask)

    # Iterate over each nucleus and save each as a separate mask
    for region in regionprops(labeled_mask):
        # Create an empty mask for each nucleus
        single_nucleus_mask = np.zeros_like(predicted_mask, dtype=np.uint8)

        # Set pixels of the current region (nucleus) to 1 in the mask
        single_nucleus_mask[labeled_mask == region.label] = 1

        # Define path to save individual nucleus mask
        nucleus_save_path = single_nucleus_masks / f'{image_id}_nucleus_{region.label}.png'

        # Save the single nucleus mask
        imsave(nucleus_save_path, (single_nucleus_mask * 255).astype(np.uint8))
        print(f'Saved individual nucleus mask for image ID {image_id}, Nucleus {region.label} at {nucleus_save_path}')

# Calculate and print the mean Dice and IoU scores
mean_dice_score = np.mean(dice_scores)
mean_iou_score = np.mean(iou_scores)
print(f'Mean Dice Score on Test Set: {mean_dice_score:.4f}')
print(f'Mean IoU Score on Test Set: {mean_iou_score:.4f}')

# Save results into a CSV file
csv_filename = results / 'csv' / 'dice_iou_scores.csv'
csv_filename.parent.mkdir(parents=True, exist_ok=True)

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Image ID', 'Dice Score', 'IoU Score'])  # Write the header
    for i in range(len(image_ids_list)):
        writer.writerow([image_ids_list[i], dice_scores[i], iou_scores[i]])  # Write each row of results

print(f'Results saved to {csv_filename}')
# Out:
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1004.png
# Processing image ID: fold_3_1004
# Loaded ground truth mask for image ID: fold_3_1004
# Image ID fold_3_1004: Dice Score = 0.3441, IoU = 0.2078
# Saved predicted mask for image ID fold_3_1004 at results\predicted_masks\fold_3_1004_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1004, Nucleus 1 at results\single_nucleus_masks\fold_3_1004_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_102.png
# Processing image ID: fold_3_102
# Loaded ground truth mask for image ID: fold_3_102
# Image ID fold_3_102: Dice Score = 0.6127, IoU = 0.4417
# Saved predicted mask for image ID fold_3_102 at results\predicted_masks\fold_3_102_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_102, Nucleus 1 at results\single_nucleus_masks\fold_3_102_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1067.png
# Processing image ID: fold_3_1067
# Loaded ground truth mask for image ID: fold_3_1067
# Image ID fold_3_1067: Dice Score = 0.4848, IoU = 0.3200
# Saved predicted mask for image ID fold_3_1067 at results\predicted_masks\fold_3_1067_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1067, Nucleus 1 at results\single_nucleus_masks\fold_3_1067_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1071.png
# Processing image ID: fold_3_1071
# Loaded ground truth mask for image ID: fold_3_1071
# Image ID fold_3_1071: Dice Score = 0.3846, IoU = 0.2381
# Saved predicted mask for image ID fold_3_1071 at results\predicted_masks\fold_3_1071_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1071, Nucleus 1 at results\single_nucleus_masks\fold_3_1071_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1074.png
# Processing image ID: fold_3_1074
# Loaded ground truth mask for image ID: fold_3_1074
# Image ID fold_3_1074: Dice Score = 0.3721, IoU = 0.2286
# Saved predicted mask for image ID fold_3_1074 at results\predicted_masks\fold_3_1074_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1074, Nucleus 1 at results\single_nucleus_masks\fold_3_1074_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1096.png
# Processing image ID: fold_3_1096
# Loaded ground truth mask for image ID: fold_3_1096
# Image ID fold_3_1096: Dice Score = 0.2827, IoU = 0.1646
# Saved predicted mask for image ID fold_3_1096 at results\predicted_masks\fold_3_1096_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1096, Nucleus 1 at results\single_nucleus_masks\fold_3_1096_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1111.png
# Processing image ID: fold_3_1111
# Loaded ground truth mask for image ID: fold_3_1111
# Image ID fold_3_1111: Dice Score = 0.2333, IoU = 0.1320
# Saved predicted mask for image ID fold_3_1111 at results\predicted_masks\fold_3_1111_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1111, Nucleus 1 at results\single_nucleus_masks\fold_3_1111_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1113.png
# Processing image ID: fold_3_1113
# Loaded ground truth mask for image ID: fold_3_1113
# Image ID fold_3_1113: Dice Score = 0.1635, IoU = 0.0890
# Saved predicted mask for image ID fold_3_1113 at results\predicted_masks\fold_3_1113_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1113, Nucleus 1 at results\single_nucleus_masks\fold_3_1113_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1118.png
# Processing image ID: fold_3_1118
# Loaded ground truth mask for image ID: fold_3_1118
# Image ID fold_3_1118: Dice Score = 0.2141, IoU = 0.1199
# Saved predicted mask for image ID fold_3_1118 at results\predicted_masks\fold_3_1118_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1118, Nucleus 1 at results\single_nucleus_masks\fold_3_1118_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1139.png
# Processing image ID: fold_3_1139
# Loaded ground truth mask for image ID: fold_3_1139
# Image ID fold_3_1139: Dice Score = 0.1407, IoU = 0.0757
# Saved predicted mask for image ID fold_3_1139 at results\predicted_masks\fold_3_1139_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1139, Nucleus 1 at results\single_nucleus_masks\fold_3_1139_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1141.png
# Processing image ID: fold_3_1141
# Loaded ground truth mask for image ID: fold_3_1141
# Image ID fold_3_1141: Dice Score = 0.2240, IoU = 0.1261
# Saved predicted mask for image ID fold_3_1141 at results\predicted_masks\fold_3_1141_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1141, Nucleus 1 at results\single_nucleus_masks\fold_3_1141_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1146.png
# Processing image ID: fold_3_1146
# Loaded ground truth mask for image ID: fold_3_1146
# Image ID fold_3_1146: Dice Score = 0.2365, IoU = 0.1341
# Saved predicted mask for image ID fold_3_1146 at results\predicted_masks\fold_3_1146_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1146, Nucleus 1 at results\single_nucleus_masks\fold_3_1146_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1150.png
# Processing image ID: fold_3_1150
# Loaded ground truth mask for image ID: fold_3_1150
# Image ID fold_3_1150: Dice Score = 0.3694, IoU = 0.2265
# Saved predicted mask for image ID fold_3_1150 at results\predicted_masks\fold_3_1150_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1150, Nucleus 1 at results\single_nucleus_masks\fold_3_1150_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1156.png
# Processing image ID: fold_3_1156
# Loaded ground truth mask for image ID: fold_3_1156
# Image ID fold_3_1156: Dice Score = 0.2927, IoU = 0.1714
# Saved predicted mask for image ID fold_3_1156 at results\predicted_masks\fold_3_1156_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1156, Nucleus 1 at results\single_nucleus_masks\fold_3_1156_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1179.png
# Processing image ID: fold_3_1179
# Loaded ground truth mask for image ID: fold_3_1179
# Image ID fold_3_1179: Dice Score = 0.0645, IoU = 0.0333
# Saved predicted mask for image ID fold_3_1179 at results\predicted_masks\fold_3_1179_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1179, Nucleus 1 at results\single_nucleus_masks\fold_3_1179_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1181.png
# Processing image ID: fold_3_1181
# Loaded ground truth mask for image ID: fold_3_1181
# Image ID fold_3_1181: Dice Score = 0.1574, IoU = 0.0854
# Saved predicted mask for image ID fold_3_1181 at results\predicted_masks\fold_3_1181_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1181, Nucleus 1 at results\single_nucleus_masks\fold_3_1181_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1182.png
# Processing image ID: fold_3_1182
# Loaded ground truth mask for image ID: fold_3_1182
# Image ID fold_3_1182: Dice Score = 0.0137, IoU = 0.0069
# Saved predicted mask for image ID fold_3_1182 at results\predicted_masks\fold_3_1182_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1182, Nucleus 1 at results\single_nucleus_masks\fold_3_1182_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1183.png
# Processing image ID: fold_3_1183
# Loaded ground truth mask for image ID: fold_3_1183
# Image ID fold_3_1183: Dice Score = 0.4080, IoU = 0.2563
# Saved predicted mask for image ID fold_3_1183 at results\predicted_masks\fold_3_1183_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1183, Nucleus 1 at results\single_nucleus_masks\fold_3_1183_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1212.png
# Processing image ID: fold_3_1212
# Loaded ground truth mask for image ID: fold_3_1212
# Image ID fold_3_1212: Dice Score = 0.2192, IoU = 0.1231
# Saved predicted mask for image ID fold_3_1212 at results\predicted_masks\fold_3_1212_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1212, Nucleus 1 at results\single_nucleus_masks\fold_3_1212_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1227.png
# Processing image ID: fold_3_1227
# Loaded ground truth mask for image ID: fold_3_1227
# Image ID fold_3_1227: Dice Score = 0.3939, IoU = 0.2452
# Saved predicted mask for image ID fold_3_1227 at results\predicted_masks\fold_3_1227_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1227, Nucleus 1 at results\single_nucleus_masks\fold_3_1227_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1237.png
# Processing image ID: fold_3_1237
# Loaded ground truth mask for image ID: fold_3_1237
# Image ID fold_3_1237: Dice Score = 0.4131, IoU = 0.2603
# Saved predicted mask for image ID fold_3_1237 at results\predicted_masks\fold_3_1237_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1237, Nucleus 1 at results\single_nucleus_masks\fold_3_1237_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1242.png
# Processing image ID: fold_3_1242
# Loaded ground truth mask for image ID: fold_3_1242
# Image ID fold_3_1242: Dice Score = 0.5325, IoU = 0.3628
# Saved predicted mask for image ID fold_3_1242 at results\predicted_masks\fold_3_1242_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1242, Nucleus 1 at results\single_nucleus_masks\fold_3_1242_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1263.png
# Processing image ID: fold_3_1263
# Loaded ground truth mask for image ID: fold_3_1263
# Image ID fold_3_1263: Dice Score = 0.1668, IoU = 0.0910
# Saved predicted mask for image ID fold_3_1263 at results\predicted_masks\fold_3_1263_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1263, Nucleus 1 at results\single_nucleus_masks\fold_3_1263_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1275.png
# Processing image ID: fold_3_1275
# Loaded ground truth mask for image ID: fold_3_1275
# Image ID fold_3_1275: Dice Score = 0.0743, IoU = 0.0386
# Saved predicted mask for image ID fold_3_1275 at results\predicted_masks\fold_3_1275_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1275, Nucleus 1 at results\single_nucleus_masks\fold_3_1275_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1316.png
# Processing image ID: fold_3_1316
# Loaded ground truth mask for image ID: fold_3_1316
# Image ID fold_3_1316: Dice Score = 0.1088, IoU = 0.0575
# Saved predicted mask for image ID fold_3_1316 at results\predicted_masks\fold_3_1316_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1316, Nucleus 1 at results\single_nucleus_masks\fold_3_1316_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1320.png
# Processing image ID: fold_3_1320
# Loaded ground truth mask for image ID: fold_3_1320
# Image ID fold_3_1320: Dice Score = 0.0145, IoU = 0.0073
# Saved predicted mask for image ID fold_3_1320 at results\predicted_masks\fold_3_1320_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1320, Nucleus 1 at results\single_nucleus_masks\fold_3_1320_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1330.png
# Processing image ID: fold_3_1330
# Loaded ground truth mask for image ID: fold_3_1330
# Image ID fold_3_1330: Dice Score = 0.0526, IoU = 0.0270
# Saved predicted mask for image ID fold_3_1330 at results\predicted_masks\fold_3_1330_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1330, Nucleus 1 at results\single_nucleus_masks\fold_3_1330_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1334.png
# Processing image ID: fold_3_1334
# Loaded ground truth mask for image ID: fold_3_1334
# Image ID fold_3_1334: Dice Score = 0.4342, IoU = 0.2773
# Saved predicted mask for image ID fold_3_1334 at results\predicted_masks\fold_3_1334_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1334, Nucleus 1 at results\single_nucleus_masks\fold_3_1334_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1336.png
# Processing image ID: fold_3_1336
# Loaded ground truth mask for image ID: fold_3_1336
# Image ID fold_3_1336: Dice Score = 0.5949, IoU = 0.4233
# Saved predicted mask for image ID fold_3_1336 at results\predicted_masks\fold_3_1336_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1336, Nucleus 1 at results\single_nucleus_masks\fold_3_1336_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1341.png
# Processing image ID: fold_3_1341
# Loaded ground truth mask for image ID: fold_3_1341
# Image ID fold_3_1341: Dice Score = 0.2992, IoU = 0.1759
# Saved predicted mask for image ID fold_3_1341 at results\predicted_masks\fold_3_1341_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1341, Nucleus 1 at results\single_nucleus_masks\fold_3_1341_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1344.png
# Processing image ID: fold_3_1344
# Loaded ground truth mask for image ID: fold_3_1344
# Image ID fold_3_1344: Dice Score = 0.5574, IoU = 0.3863
# Saved predicted mask for image ID fold_3_1344 at results\predicted_masks\fold_3_1344_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1344, Nucleus 1 at results\single_nucleus_masks\fold_3_1344_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1347.png
# Processing image ID: fold_3_1347
# Loaded ground truth mask for image ID: fold_3_1347
# Image ID fold_3_1347: Dice Score = 0.1161, IoU = 0.0616
# Saved predicted mask for image ID fold_3_1347 at results\predicted_masks\fold_3_1347_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1347, Nucleus 1 at results\single_nucleus_masks\fold_3_1347_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1359.png
# Processing image ID: fold_3_1359
# Loaded ground truth mask for image ID: fold_3_1359
# Image ID fold_3_1359: Dice Score = 0.2457, IoU = 0.1400
# Saved predicted mask for image ID fold_3_1359 at results\predicted_masks\fold_3_1359_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1359, Nucleus 1 at results\single_nucleus_masks\fold_3_1359_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1367.png
# Processing image ID: fold_3_1367
# Loaded ground truth mask for image ID: fold_3_1367
# Image ID fold_3_1367: Dice Score = 0.3202, IoU = 0.1906
# Saved predicted mask for image ID fold_3_1367 at results\predicted_masks\fold_3_1367_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1367, Nucleus 1 at results\single_nucleus_masks\fold_3_1367_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1368.png
# Processing image ID: fold_3_1368
# Loaded ground truth mask for image ID: fold_3_1368
# Image ID fold_3_1368: Dice Score = 0.3783, IoU = 0.2333
# Saved predicted mask for image ID fold_3_1368 at results\predicted_masks\fold_3_1368_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1368, Nucleus 1 at results\single_nucleus_masks\fold_3_1368_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1384.png
# Processing image ID: fold_3_1384
# Loaded ground truth mask for image ID: fold_3_1384
# Image ID fold_3_1384: Dice Score = 0.2956, IoU = 0.1734
# Saved predicted mask for image ID fold_3_1384 at results\predicted_masks\fold_3_1384_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1384, Nucleus 1 at results\single_nucleus_masks\fold_3_1384_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_140.png
# Processing image ID: fold_3_140
# Loaded ground truth mask for image ID: fold_3_140
# Image ID fold_3_140: Dice Score = 0.1715, IoU = 0.0938
# Saved predicted mask for image ID fold_3_140 at results\predicted_masks\fold_3_140_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_140, Nucleus 1 at results\single_nucleus_masks\fold_3_140_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1400.png
# Processing image ID: fold_3_1400
# Loaded ground truth mask for image ID: fold_3_1400
# Image ID fold_3_1400: Dice Score = 0.3583, IoU = 0.2182
# Saved predicted mask for image ID fold_3_1400 at results\predicted_masks\fold_3_1400_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1400, Nucleus 1 at results\single_nucleus_masks\fold_3_1400_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1455.png
# Processing image ID: fold_3_1455
# Loaded ground truth mask for image ID: fold_3_1455
# Image ID fold_3_1455: Dice Score = 0.2499, IoU = 0.1428
# Saved predicted mask for image ID fold_3_1455 at results\predicted_masks\fold_3_1455_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1455, Nucleus 1 at results\single_nucleus_masks\fold_3_1455_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1456.png
# Processing image ID: fold_3_1456
# Loaded ground truth mask for image ID: fold_3_1456
# Image ID fold_3_1456: Dice Score = 0.0452, IoU = 0.0231
# Saved predicted mask for image ID fold_3_1456 at results\predicted_masks\fold_3_1456_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1456, Nucleus 1 at results\single_nucleus_masks\fold_3_1456_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_15.png
# Processing image ID: fold_3_15
# Loaded ground truth mask for image ID: fold_3_15
# Image ID fold_3_15: Dice Score = 0.1715, IoU = 0.0938
# Saved predicted mask for image ID fold_3_15 at results\predicted_masks\fold_3_15_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_15, Nucleus 1 at results\single_nucleus_masks\fold_3_15_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1503.png
# Processing image ID: fold_3_1503
# Loaded ground truth mask for image ID: fold_3_1503
# Image ID fold_3_1503: Dice Score = 0.3885, IoU = 0.2411
# Saved predicted mask for image ID fold_3_1503 at results\predicted_masks\fold_3_1503_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1503, Nucleus 1 at results\single_nucleus_masks\fold_3_1503_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1511.png
# Processing image ID: fold_3_1511
# Loaded ground truth mask for image ID: fold_3_1511
# Image ID fold_3_1511: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1511 at results\predicted_masks\fold_3_1511_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1511, Nucleus 1 at results\single_nucleus_masks\fold_3_1511_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1512.png
# Processing image ID: fold_3_1512
# Loaded ground truth mask for image ID: fold_3_1512
# Image ID fold_3_1512: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1512 at results\predicted_masks\fold_3_1512_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1512, Nucleus 1 at results\single_nucleus_masks\fold_3_1512_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1529.png
# Processing image ID: fold_3_1529
# Loaded ground truth mask for image ID: fold_3_1529
# Image ID fold_3_1529: Dice Score = 0.0431, IoU = 0.0220
# Saved predicted mask for image ID fold_3_1529 at results\predicted_masks\fold_3_1529_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1529, Nucleus 1 at results\single_nucleus_masks\fold_3_1529_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_153.png
# Processing image ID: fold_3_153
# Loaded ground truth mask for image ID: fold_3_153
# Image ID fold_3_153: Dice Score = 0.0575, IoU = 0.0296
# Saved predicted mask for image ID fold_3_153 at results\predicted_masks\fold_3_153_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_153, Nucleus 1 at results\single_nucleus_masks\fold_3_153_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_154.png
# Processing image ID: fold_3_154
# Loaded ground truth mask for image ID: fold_3_154
# Image ID fold_3_154: Dice Score = 0.0209, IoU = 0.0106
# Saved predicted mask for image ID fold_3_154 at results\predicted_masks\fold_3_154_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_154, Nucleus 1 at results\single_nucleus_masks\fold_3_154_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1547.png
# Processing image ID: fold_3_1547
# Loaded ground truth mask for image ID: fold_3_1547
# Image ID fold_3_1547: Dice Score = 0.0879, IoU = 0.0459
# Saved predicted mask for image ID fold_3_1547 at results\predicted_masks\fold_3_1547_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1547, Nucleus 1 at results\single_nucleus_masks\fold_3_1547_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1555.png
# Processing image ID: fold_3_1555
# Loaded ground truth mask for image ID: fold_3_1555
# Image ID fold_3_1555: Dice Score = 0.2909, IoU = 0.1702
# Saved predicted mask for image ID fold_3_1555 at results\predicted_masks\fold_3_1555_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1555, Nucleus 1 at results\single_nucleus_masks\fold_3_1555_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1568.png
# Processing image ID: fold_3_1568
# Loaded ground truth mask for image ID: fold_3_1568
# Image ID fold_3_1568: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1568 at results\predicted_masks\fold_3_1568_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1568, Nucleus 1 at results\single_nucleus_masks\fold_3_1568_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1587.png
# Processing image ID: fold_3_1587
# Loaded ground truth mask for image ID: fold_3_1587
# Image ID fold_3_1587: Dice Score = 0.3507, IoU = 0.2126
# Saved predicted mask for image ID fold_3_1587 at results\predicted_masks\fold_3_1587_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1587, Nucleus 1 at results\single_nucleus_masks\fold_3_1587_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1590.png
# Processing image ID: fold_3_1590
# Loaded ground truth mask for image ID: fold_3_1590
# Image ID fold_3_1590: Dice Score = 0.4123, IoU = 0.2597
# Saved predicted mask for image ID fold_3_1590 at results\predicted_masks\fold_3_1590_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1590, Nucleus 1 at results\single_nucleus_masks\fold_3_1590_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1593.png
# Processing image ID: fold_3_1593
# Loaded ground truth mask for image ID: fold_3_1593
# Image ID fold_3_1593: Dice Score = 0.4768, IoU = 0.3130
# Saved predicted mask for image ID fold_3_1593 at results\predicted_masks\fold_3_1593_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1593, Nucleus 1 at results\single_nucleus_masks\fold_3_1593_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_16.png
# Processing image ID: fold_3_16
# Loaded ground truth mask for image ID: fold_3_16
# Image ID fold_3_16: Dice Score = 0.1900, IoU = 0.1049
# Saved predicted mask for image ID fold_3_16 at results\predicted_masks\fold_3_16_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_16, Nucleus 1 at results\single_nucleus_masks\fold_3_16_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_160.png
# Processing image ID: fold_3_160
# Loaded ground truth mask for image ID: fold_3_160
# Image ID fold_3_160: Dice Score = 0.0527, IoU = 0.0270
# Saved predicted mask for image ID fold_3_160 at results\predicted_masks\fold_3_160_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_160, Nucleus 1 at results\single_nucleus_masks\fold_3_160_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_162.png
# Processing image ID: fold_3_162
# Loaded ground truth mask for image ID: fold_3_162
# Image ID fold_3_162: Dice Score = 0.0725, IoU = 0.0376
# Saved predicted mask for image ID fold_3_162 at results\predicted_masks\fold_3_162_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_162, Nucleus 1 at results\single_nucleus_masks\fold_3_162_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1650.png
# Processing image ID: fold_3_1650
# Loaded ground truth mask for image ID: fold_3_1650
# Image ID fold_3_1650: Dice Score = 0.3664, IoU = 0.2243
# Saved predicted mask for image ID fold_3_1650 at results\predicted_masks\fold_3_1650_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1650, Nucleus 1 at results\single_nucleus_masks\fold_3_1650_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1659.png
# Processing image ID: fold_3_1659
# Loaded ground truth mask for image ID: fold_3_1659
# Image ID fold_3_1659: Dice Score = 0.1559, IoU = 0.0845
# Saved predicted mask for image ID fold_3_1659 at results\predicted_masks\fold_3_1659_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1659, Nucleus 1 at results\single_nucleus_masks\fold_3_1659_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1663.png
# Processing image ID: fold_3_1663
# Loaded ground truth mask for image ID: fold_3_1663
# Image ID fold_3_1663: Dice Score = 0.3307, IoU = 0.1981
# Saved predicted mask for image ID fold_3_1663 at results\predicted_masks\fold_3_1663_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1663, Nucleus 1 at results\single_nucleus_masks\fold_3_1663_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1665.png
# Processing image ID: fold_3_1665
# Loaded ground truth mask for image ID: fold_3_1665
# Image ID fold_3_1665: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1665 at results\predicted_masks\fold_3_1665_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1665, Nucleus 1 at results\single_nucleus_masks\fold_3_1665_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1671.png
# Processing image ID: fold_3_1671
# Loaded ground truth mask for image ID: fold_3_1671
# Image ID fold_3_1671: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1671 at results\predicted_masks\fold_3_1671_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1671, Nucleus 1 at results\single_nucleus_masks\fold_3_1671_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1674.png
# Processing image ID: fold_3_1674
# Loaded ground truth mask for image ID: fold_3_1674
# Image ID fold_3_1674: Dice Score = 0.6497, IoU = 0.4812
# Saved predicted mask for image ID fold_3_1674 at results\predicted_masks\fold_3_1674_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1674, Nucleus 1 at results\single_nucleus_masks\fold_3_1674_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1683.png
# Processing image ID: fold_3_1683
# Loaded ground truth mask for image ID: fold_3_1683
# Image ID fold_3_1683: Dice Score = 0.4586, IoU = 0.2975
# Saved predicted mask for image ID fold_3_1683 at results\predicted_masks\fold_3_1683_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1683, Nucleus 1 at results\single_nucleus_masks\fold_3_1683_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1687.png
# Processing image ID: fold_3_1687
# Loaded ground truth mask for image ID: fold_3_1687
# Image ID fold_3_1687: Dice Score = 0.4320, IoU = 0.2755
# Saved predicted mask for image ID fold_3_1687 at results\predicted_masks\fold_3_1687_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1687, Nucleus 1 at results\single_nucleus_masks\fold_3_1687_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1689.png
# Processing image ID: fold_3_1689
# Loaded ground truth mask for image ID: fold_3_1689
# Image ID fold_3_1689: Dice Score = 0.4115, IoU = 0.2591
# Saved predicted mask for image ID fold_3_1689 at results\predicted_masks\fold_3_1689_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1689, Nucleus 1 at results\single_nucleus_masks\fold_3_1689_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1701.png
# Processing image ID: fold_3_1701
# Loaded ground truth mask for image ID: fold_3_1701
# Image ID fold_3_1701: Dice Score = 0.4703, IoU = 0.3074
# Saved predicted mask for image ID fold_3_1701 at results\predicted_masks\fold_3_1701_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1701, Nucleus 1 at results\single_nucleus_masks\fold_3_1701_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_18.png
# Processing image ID: fold_3_18
# Loaded ground truth mask for image ID: fold_3_18
# Image ID fold_3_18: Dice Score = 0.3342, IoU = 0.2007
# Saved predicted mask for image ID fold_3_18 at results\predicted_masks\fold_3_18_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_18, Nucleus 1 at results\single_nucleus_masks\fold_3_18_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1838.png
# Processing image ID: fold_3_1838
# Loaded ground truth mask for image ID: fold_3_1838
# Image ID fold_3_1838: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1838 at results\predicted_masks\fold_3_1838_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1838, Nucleus 1 at results\single_nucleus_masks\fold_3_1838_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1853.png
# Processing image ID: fold_3_1853
# Loaded ground truth mask for image ID: fold_3_1853
# Image ID fold_3_1853: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1853 at results\predicted_masks\fold_3_1853_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1853, Nucleus 1 at results\single_nucleus_masks\fold_3_1853_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1940.png
# Processing image ID: fold_3_1940
# Loaded ground truth mask for image ID: fold_3_1940
# Image ID fold_3_1940: Dice Score = 0.4361, IoU = 0.2788
# Saved predicted mask for image ID fold_3_1940 at results\predicted_masks\fold_3_1940_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1940, Nucleus 1 at results\single_nucleus_masks\fold_3_1940_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1945.png
# Processing image ID: fold_3_1945
# Loaded ground truth mask for image ID: fold_3_1945
# Image ID fold_3_1945: Dice Score = 0.0149, IoU = 0.0075
# Saved predicted mask for image ID fold_3_1945 at results\predicted_masks\fold_3_1945_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1945, Nucleus 1 at results\single_nucleus_masks\fold_3_1945_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1953.png
# Processing image ID: fold_3_1953
# Loaded ground truth mask for image ID: fold_3_1953
# Image ID fold_3_1953: Dice Score = 0.3297, IoU = 0.1974
# Saved predicted mask for image ID fold_3_1953 at results\predicted_masks\fold_3_1953_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1953, Nucleus 1 at results\single_nucleus_masks\fold_3_1953_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1954.png
# Processing image ID: fold_3_1954
# Loaded ground truth mask for image ID: fold_3_1954
# Image ID fold_3_1954: Dice Score = 0.3619, IoU = 0.2209
# Saved predicted mask for image ID fold_3_1954 at results\predicted_masks\fold_3_1954_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1954, Nucleus 1 at results\single_nucleus_masks\fold_3_1954_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1960.png
# Processing image ID: fold_3_1960
# Loaded ground truth mask for image ID: fold_3_1960
# Image ID fold_3_1960: Dice Score = 0.2302, IoU = 0.1301
# Saved predicted mask for image ID fold_3_1960 at results\predicted_masks\fold_3_1960_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1960, Nucleus 1 at results\single_nucleus_masks\fold_3_1960_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1970.png
# Processing image ID: fold_3_1970
# Loaded ground truth mask for image ID: fold_3_1970
# Image ID fold_3_1970: Dice Score = 0.4000, IoU = 0.2500
# Saved predicted mask for image ID fold_3_1970 at results\predicted_masks\fold_3_1970_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1970, Nucleus 1 at results\single_nucleus_masks\fold_3_1970_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_1989.png
# Processing image ID: fold_3_1989
# Loaded ground truth mask for image ID: fold_3_1989
# Image ID fold_3_1989: Dice Score = 1.0000, IoU = 1.0000
# Saved predicted mask for image ID fold_3_1989 at results\predicted_masks\fold_3_1989_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_1989, Nucleus 1 at results\single_nucleus_masks\fold_3_1989_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2006.png
# Processing image ID: fold_3_2006
# Loaded ground truth mask for image ID: fold_3_2006
# Image ID fold_3_2006: Dice Score = 0.2843, IoU = 0.1657
# Saved predicted mask for image ID fold_3_2006 at results\predicted_masks\fold_3_2006_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2006, Nucleus 1 at results\single_nucleus_masks\fold_3_2006_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2015.png
# Processing image ID: fold_3_2015
# Loaded ground truth mask for image ID: fold_3_2015
# Image ID fold_3_2015: Dice Score = 0.2538, IoU = 0.1453
# Saved predicted mask for image ID fold_3_2015 at results\predicted_masks\fold_3_2015_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2015, Nucleus 1 at results\single_nucleus_masks\fold_3_2015_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2022.png
# Processing image ID: fold_3_2022
# Loaded ground truth mask for image ID: fold_3_2022
# Image ID fold_3_2022: Dice Score = 0.2175, IoU = 0.1220
# Saved predicted mask for image ID fold_3_2022 at results\predicted_masks\fold_3_2022_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2022, Nucleus 1 at results\single_nucleus_masks\fold_3_2022_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2099.png
# Processing image ID: fold_3_2099
# Loaded ground truth mask for image ID: fold_3_2099
# Image ID fold_3_2099: Dice Score = 0.6582, IoU = 0.4905
# Saved predicted mask for image ID fold_3_2099 at results\predicted_masks\fold_3_2099_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2099, Nucleus 1 at results\single_nucleus_masks\fold_3_2099_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2121.png
# Processing image ID: fold_3_2121
# Loaded ground truth mask for image ID: fold_3_2121
# Image ID fold_3_2121: Dice Score = 0.1679, IoU = 0.0917
# Saved predicted mask for image ID fold_3_2121 at results\predicted_masks\fold_3_2121_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2121, Nucleus 1 at results\single_nucleus_masks\fold_3_2121_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2126.png
# Processing image ID: fold_3_2126
# Loaded ground truth mask for image ID: fold_3_2126
# Image ID fold_3_2126: Dice Score = 0.1591, IoU = 0.0864
# Saved predicted mask for image ID fold_3_2126 at results\predicted_masks\fold_3_2126_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2126, Nucleus 1 at results\single_nucleus_masks\fold_3_2126_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2130.png
# Processing image ID: fold_3_2130
# Loaded ground truth mask for image ID: fold_3_2130
# Image ID fold_3_2130: Dice Score = 0.6162, IoU = 0.4453
# Saved predicted mask for image ID fold_3_2130 at results\predicted_masks\fold_3_2130_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2130, Nucleus 1 at results\single_nucleus_masks\fold_3_2130_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2156.png
# Processing image ID: fold_3_2156
# Loaded ground truth mask for image ID: fold_3_2156
# Image ID fold_3_2156: Dice Score = 0.2284, IoU = 0.1289
# Saved predicted mask for image ID fold_3_2156 at results\predicted_masks\fold_3_2156_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2156, Nucleus 1 at results\single_nucleus_masks\fold_3_2156_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2169.png
# Processing image ID: fold_3_2169
# Loaded ground truth mask for image ID: fold_3_2169
# Image ID fold_3_2169: Dice Score = 0.1689, IoU = 0.0922
# Saved predicted mask for image ID fold_3_2169 at results\predicted_masks\fold_3_2169_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2169, Nucleus 1 at results\single_nucleus_masks\fold_3_2169_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2171.png
# Processing image ID: fold_3_2171
# Loaded ground truth mask for image ID: fold_3_2171
# Image ID fold_3_2171: Dice Score = 0.0496, IoU = 0.0254
# Saved predicted mask for image ID fold_3_2171 at results\predicted_masks\fold_3_2171_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2171, Nucleus 1 at results\single_nucleus_masks\fold_3_2171_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2174.png
# Processing image ID: fold_3_2174
# Loaded ground truth mask for image ID: fold_3_2174
# Image ID fold_3_2174: Dice Score = 0.1413, IoU = 0.0760
# Saved predicted mask for image ID fold_3_2174 at results\predicted_masks\fold_3_2174_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2174, Nucleus 1 at results\single_nucleus_masks\fold_3_2174_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2207.png
# Processing image ID: fold_3_2207
# Loaded ground truth mask for image ID: fold_3_2207
# Image ID fold_3_2207: Dice Score = 0.3756, IoU = 0.2312
# Saved predicted mask for image ID fold_3_2207 at results\predicted_masks\fold_3_2207_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2207, Nucleus 1 at results\single_nucleus_masks\fold_3_2207_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2214.png
# Processing image ID: fold_3_2214
# Loaded ground truth mask for image ID: fold_3_2214
# Image ID fold_3_2214: Dice Score = 0.3659, IoU = 0.2239
# Saved predicted mask for image ID fold_3_2214 at results\predicted_masks\fold_3_2214_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2214, Nucleus 1 at results\single_nucleus_masks\fold_3_2214_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2228.png
# Processing image ID: fold_3_2228
# Loaded ground truth mask for image ID: fold_3_2228
# Image ID fold_3_2228: Dice Score = 0.3069, IoU = 0.1812
# Saved predicted mask for image ID fold_3_2228 at results\predicted_masks\fold_3_2228_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2228, Nucleus 1 at results\single_nucleus_masks\fold_3_2228_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2260.png
# Processing image ID: fold_3_2260
# Loaded ground truth mask for image ID: fold_3_2260
# Image ID fold_3_2260: Dice Score = 0.3429, IoU = 0.2069
# Saved predicted mask for image ID fold_3_2260 at results\predicted_masks\fold_3_2260_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2260, Nucleus 1 at results\single_nucleus_masks\fold_3_2260_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2264.png
# Processing image ID: fold_3_2264
# Loaded ground truth mask for image ID: fold_3_2264
# Image ID fold_3_2264: Dice Score = 0.0399, IoU = 0.0203
# Saved predicted mask for image ID fold_3_2264 at results\predicted_masks\fold_3_2264_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2264, Nucleus 1 at results\single_nucleus_masks\fold_3_2264_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2287.png
# Processing image ID: fold_3_2287
# Loaded ground truth mask for image ID: fold_3_2287
# Image ID fold_3_2287: Dice Score = 0.3832, IoU = 0.2370
# Saved predicted mask for image ID fold_3_2287 at results\predicted_masks\fold_3_2287_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2287, Nucleus 1 at results\single_nucleus_masks\fold_3_2287_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2312.png
# Processing image ID: fold_3_2312
# Loaded ground truth mask for image ID: fold_3_2312
# Image ID fold_3_2312: Dice Score = 0.6675, IoU = 0.5009
# Saved predicted mask for image ID fold_3_2312 at results\predicted_masks\fold_3_2312_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2312, Nucleus 1 at results\single_nucleus_masks\fold_3_2312_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2339.png
# Processing image ID: fold_3_2339
# Loaded ground truth mask for image ID: fold_3_2339
# Image ID fold_3_2339: Dice Score = 0.4171, IoU = 0.2635
# Saved predicted mask for image ID fold_3_2339 at results\predicted_masks\fold_3_2339_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2339, Nucleus 1 at results\single_nucleus_masks\fold_3_2339_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2345.png
# Processing image ID: fold_3_2345
# Loaded ground truth mask for image ID: fold_3_2345
# Image ID fold_3_2345: Dice Score = 0.2709, IoU = 0.1567
# Saved predicted mask for image ID fold_3_2345 at results\predicted_masks\fold_3_2345_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2345, Nucleus 1 at results\single_nucleus_masks\fold_3_2345_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2372.png
# Processing image ID: fold_3_2372
# Loaded ground truth mask for image ID: fold_3_2372
# Image ID fold_3_2372: Dice Score = 0.1438, IoU = 0.0775
# Saved predicted mask for image ID fold_3_2372 at results\predicted_masks\fold_3_2372_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2372, Nucleus 1 at results\single_nucleus_masks\fold_3_2372_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_238.png
# Processing image ID: fold_3_238
# Loaded ground truth mask for image ID: fold_3_238
# Image ID fold_3_238: Dice Score = 0.1027, IoU = 0.0541
# Saved predicted mask for image ID fold_3_238 at results\predicted_masks\fold_3_238_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_238, Nucleus 1 at results\single_nucleus_masks\fold_3_238_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2399.png
# Processing image ID: fold_3_2399
# Loaded ground truth mask for image ID: fold_3_2399
# Image ID fold_3_2399: Dice Score = 0.5461, IoU = 0.3756
# Saved predicted mask for image ID fold_3_2399 at results\predicted_masks\fold_3_2399_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2399, Nucleus 1 at results\single_nucleus_masks\fold_3_2399_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2422.png
# Processing image ID: fold_3_2422
# Loaded ground truth mask for image ID: fold_3_2422
# Image ID fold_3_2422: Dice Score = 0.2762, IoU = 0.1602
# Saved predicted mask for image ID fold_3_2422 at results\predicted_masks\fold_3_2422_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2422, Nucleus 1 at results\single_nucleus_masks\fold_3_2422_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2423.png
# Processing image ID: fold_3_2423
# Loaded ground truth mask for image ID: fold_3_2423
# Image ID fold_3_2423: Dice Score = 0.3682, IoU = 0.2256
# Saved predicted mask for image ID fold_3_2423 at results\predicted_masks\fold_3_2423_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2423, Nucleus 1 at results\single_nucleus_masks\fold_3_2423_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2430.png
# Processing image ID: fold_3_2430
# Loaded ground truth mask for image ID: fold_3_2430
# Image ID fold_3_2430: Dice Score = 0.3485, IoU = 0.2110
# Saved predicted mask for image ID fold_3_2430 at results\predicted_masks\fold_3_2430_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2430, Nucleus 1 at results\single_nucleus_masks\fold_3_2430_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2468.png
# Processing image ID: fold_3_2468
# Loaded ground truth mask for image ID: fold_3_2468
# Image ID fold_3_2468: Dice Score = 0.3658, IoU = 0.2238
# Saved predicted mask for image ID fold_3_2468 at results\predicted_masks\fold_3_2468_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2468, Nucleus 1 at results\single_nucleus_masks\fold_3_2468_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_2470.png
# Processing image ID: fold_3_2470
# Loaded ground truth mask for image ID: fold_3_2470
# Image ID fold_3_2470: Dice Score = 0.4218, IoU = 0.2672
# Saved predicted mask for image ID fold_3_2470 at results\predicted_masks\fold_3_2470_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_2470, Nucleus 1 at results\single_nucleus_masks\fold_3_2470_nucleus_1.png
# ...
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_718.png
# Processing image ID: fold_3_718
# Loaded ground truth mask for image ID: fold_3_718
# Image ID fold_3_718: Dice Score = 0.0449, IoU = 0.0229
# Saved predicted mask for image ID fold_3_718 at results\predicted_masks\fold_3_718_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_718, Nucleus 1 at results\single_nucleus_masks\fold_3_718_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_740.png
# Processing image ID: fold_3_740
# Loaded ground truth mask for image ID: fold_3_740
# Image ID fold_3_740: Dice Score = 0.3705, IoU = 0.2274
# Saved predicted mask for image ID fold_3_740 at results\predicted_masks\fold_3_740_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_740, Nucleus 1 at results\single_nucleus_masks\fold_3_740_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_764.png
# Processing image ID: fold_3_764
# Loaded ground truth mask for image ID: fold_3_764
# Image ID fold_3_764: Dice Score = 0.2777, IoU = 0.1612
# Saved predicted mask for image ID fold_3_764 at results\predicted_masks\fold_3_764_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_764, Nucleus 1 at results\single_nucleus_masks\fold_3_764_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_766.png
# Processing image ID: fold_3_766
# Loaded ground truth mask for image ID: fold_3_766
# Image ID fold_3_766: Dice Score = 0.2476, IoU = 0.1413
# Saved predicted mask for image ID fold_3_766 at results\predicted_masks\fold_3_766_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_766, Nucleus 1 at results\single_nucleus_masks\fold_3_766_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_769.png
# Processing image ID: fold_3_769
# Loaded ground truth mask for image ID: fold_3_769
# Image ID fold_3_769: Dice Score = 0.3226, IoU = 0.1923
# Saved predicted mask for image ID fold_3_769 at results\predicted_masks\fold_3_769_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_769, Nucleus 1 at results\single_nucleus_masks\fold_3_769_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_776.png
# Processing image ID: fold_3_776
# Loaded ground truth mask for image ID: fold_3_776
# Image ID fold_3_776: Dice Score = 0.3838, IoU = 0.2375
# Saved predicted mask for image ID fold_3_776 at results\predicted_masks\fold_3_776_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_776, Nucleus 1 at results\single_nucleus_masks\fold_3_776_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_789.png
# Processing image ID: fold_3_789
# Loaded ground truth mask for image ID: fold_3_789
# Image ID fold_3_789: Dice Score = 0.0219, IoU = 0.0111
# Saved predicted mask for image ID fold_3_789 at results\predicted_masks\fold_3_789_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_789, Nucleus 1 at results\single_nucleus_masks\fold_3_789_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_790.png
# Processing image ID: fold_3_790
# Loaded ground truth mask for image ID: fold_3_790
# Image ID fold_3_790: Dice Score = 0.1182, IoU = 0.0628
# Saved predicted mask for image ID fold_3_790 at results\predicted_masks\fold_3_790_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_790, Nucleus 1 at results\single_nucleus_masks\fold_3_790_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_814.png
# Processing image ID: fold_3_814
# Loaded ground truth mask for image ID: fold_3_814
# Image ID fold_3_814: Dice Score = 0.3874, IoU = 0.2402
# Saved predicted mask for image ID fold_3_814 at results\predicted_masks\fold_3_814_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_814, Nucleus 1 at results\single_nucleus_masks\fold_3_814_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_815.png
# Processing image ID: fold_3_815
# Loaded ground truth mask for image ID: fold_3_815
# Image ID fold_3_815: Dice Score = 0.0119, IoU = 0.0060
# Saved predicted mask for image ID fold_3_815 at results\predicted_masks\fold_3_815_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_815, Nucleus 1 at results\single_nucleus_masks\fold_3_815_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_818.png
# Processing image ID: fold_3_818
# Loaded ground truth mask for image ID: fold_3_818
# Image ID fold_3_818: Dice Score = 0.4473, IoU = 0.2880
# Saved predicted mask for image ID fold_3_818 at results\predicted_masks\fold_3_818_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_818, Nucleus 1 at results\single_nucleus_masks\fold_3_818_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_826.png
# Processing image ID: fold_3_826
# Loaded ground truth mask for image ID: fold_3_826
# Image ID fold_3_826: Dice Score = 0.4384, IoU = 0.2808
# Saved predicted mask for image ID fold_3_826 at results\predicted_masks\fold_3_826_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_826, Nucleus 1 at results\single_nucleus_masks\fold_3_826_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_827.png
# Processing image ID: fold_3_827
# Loaded ground truth mask for image ID: fold_3_827
# Image ID fold_3_827: Dice Score = 0.4030, IoU = 0.2524
# Saved predicted mask for image ID fold_3_827 at results\predicted_masks\fold_3_827_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_827, Nucleus 1 at results\single_nucleus_masks\fold_3_827_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_838.png
# Processing image ID: fold_3_838
# Loaded ground truth mask for image ID: fold_3_838
# Image ID fold_3_838: Dice Score = 0.2834, IoU = 0.1651
# Saved predicted mask for image ID fold_3_838 at results\predicted_masks\fold_3_838_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_838, Nucleus 1 at results\single_nucleus_masks\fold_3_838_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_847.png
# Processing image ID: fold_3_847
# Loaded ground truth mask for image ID: fold_3_847
# Image ID fold_3_847: Dice Score = 0.1577, IoU = 0.0856
# Saved predicted mask for image ID fold_3_847 at results\predicted_masks\fold_3_847_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_847, Nucleus 1 at results\single_nucleus_masks\fold_3_847_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_851.png
# Processing image ID: fold_3_851
# Loaded ground truth mask for image ID: fold_3_851
# Image ID fold_3_851: Dice Score = 0.2388, IoU = 0.1356
# Saved predicted mask for image ID fold_3_851 at results\predicted_masks\fold_3_851_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_851, Nucleus 1 at results\single_nucleus_masks\fold_3_851_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_862.png
# Processing image ID: fold_3_862
# Loaded ground truth mask for image ID: fold_3_862
# Image ID fold_3_862: Dice Score = 0.2370, IoU = 0.1344
# Saved predicted mask for image ID fold_3_862 at results\predicted_masks\fold_3_862_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_862, Nucleus 1 at results\single_nucleus_masks\fold_3_862_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_87.png
# Processing image ID: fold_3_87
# Loaded ground truth mask for image ID: fold_3_87
# Image ID fold_3_87: Dice Score = 0.0913, IoU = 0.0479
# Saved predicted mask for image ID fold_3_87 at results\predicted_masks\fold_3_87_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_87, Nucleus 1 at results\single_nucleus_masks\fold_3_87_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_872.png
# Processing image ID: fold_3_872
# Loaded ground truth mask for image ID: fold_3_872
# Image ID fold_3_872: Dice Score = 0.1817, IoU = 0.0999
# Saved predicted mask for image ID fold_3_872 at results\predicted_masks\fold_3_872_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_872, Nucleus 1 at results\single_nucleus_masks\fold_3_872_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_878.png
# Processing image ID: fold_3_878
# Loaded ground truth mask for image ID: fold_3_878
# Image ID fold_3_878: Dice Score = 0.2413, IoU = 0.1372
# Saved predicted mask for image ID fold_3_878 at results\predicted_masks\fold_3_878_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_878, Nucleus 1 at results\single_nucleus_masks\fold_3_878_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_88.png
# Processing image ID: fold_3_88
# Loaded ground truth mask for image ID: fold_3_88
# Image ID fold_3_88: Dice Score = 0.1906, IoU = 0.1053
# Saved predicted mask for image ID fold_3_88 at results\predicted_masks\fold_3_88_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_88, Nucleus 1 at results\single_nucleus_masks\fold_3_88_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_890.png
# Processing image ID: fold_3_890
# Loaded ground truth mask for image ID: fold_3_890
# Image ID fold_3_890: Dice Score = 0.0299, IoU = 0.0152
# Saved predicted mask for image ID fold_3_890 at results\predicted_masks\fold_3_890_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_890, Nucleus 1 at results\single_nucleus_masks\fold_3_890_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_908.png
# Processing image ID: fold_3_908
# Loaded ground truth mask for image ID: fold_3_908
# Image ID fold_3_908: Dice Score = 0.5514, IoU = 0.3806
# Saved predicted mask for image ID fold_3_908 at results\predicted_masks\fold_3_908_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_908, Nucleus 1 at results\single_nucleus_masks\fold_3_908_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_910.png
# Processing image ID: fold_3_910
# Loaded ground truth mask for image ID: fold_3_910
# Image ID fold_3_910: Dice Score = 0.5348, IoU = 0.3650
# Saved predicted mask for image ID fold_3_910 at results\predicted_masks\fold_3_910_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_910, Nucleus 1 at results\single_nucleus_masks\fold_3_910_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_933.png
# Processing image ID: fold_3_933
# Loaded ground truth mask for image ID: fold_3_933
# Image ID fold_3_933: Dice Score = 0.1432, IoU = 0.0771
# Saved predicted mask for image ID fold_3_933 at results\predicted_masks\fold_3_933_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_933, Nucleus 1 at results\single_nucleus_masks\fold_3_933_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_934.png
# Processing image ID: fold_3_934
# Loaded ground truth mask for image ID: fold_3_934
# Image ID fold_3_934: Dice Score = 0.0649, IoU = 0.0335
# Saved predicted mask for image ID fold_3_934 at results\predicted_masks\fold_3_934_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_934, Nucleus 1 at results\single_nucleus_masks\fold_3_934_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_944.png
# Processing image ID: fold_3_944
# Loaded ground truth mask for image ID: fold_3_944
# Image ID fold_3_944: Dice Score = 0.3143, IoU = 0.1864
# Saved predicted mask for image ID fold_3_944 at results\predicted_masks\fold_3_944_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_944, Nucleus 1 at results\single_nucleus_masks\fold_3_944_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_950.png
# Processing image ID: fold_3_950
# Loaded ground truth mask for image ID: fold_3_950
# Image ID fold_3_950: Dice Score = 0.0099, IoU = 0.0049
# Saved predicted mask for image ID fold_3_950 at results\predicted_masks\fold_3_950_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_950, Nucleus 1 at results\single_nucleus_masks\fold_3_950_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_960.png
# Processing image ID: fold_3_960
# Loaded ground truth mask for image ID: fold_3_960
# Image ID fold_3_960: Dice Score = 0.4350, IoU = 0.2780
# Saved predicted mask for image ID fold_3_960 at results\predicted_masks\fold_3_960_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_960, Nucleus 1 at results\single_nucleus_masks\fold_3_960_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_964.png
# Processing image ID: fold_3_964
# Loaded ground truth mask for image ID: fold_3_964
# Image ID fold_3_964: Dice Score = 0.4921, IoU = 0.3263
# Saved predicted mask for image ID fold_3_964 at results\predicted_masks\fold_3_964_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_964, Nucleus 1 at results\single_nucleus_masks\fold_3_964_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_969.png
# Processing image ID: fold_3_969
# Loaded ground truth mask for image ID: fold_3_969
# Image ID fold_3_969: Dice Score = 0.3680, IoU = 0.2255
# Saved predicted mask for image ID fold_3_969 at results\predicted_masks\fold_3_969_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_969, Nucleus 1 at results\single_nucleus_masks\fold_3_969_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_972.png
# Processing image ID: fold_3_972
# Loaded ground truth mask for image ID: fold_3_972
# Image ID fold_3_972: Dice Score = 0.4457, IoU = 0.2867
# Saved predicted mask for image ID fold_3_972 at results\predicted_masks\fold_3_972_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_972, Nucleus 1 at results\single_nucleus_masks\fold_3_972_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_986.png
# Processing image ID: fold_3_986
# Loaded ground truth mask for image ID: fold_3_986
# Image ID fold_3_986: Dice Score = 0.3907, IoU = 0.2427
# Saved predicted mask for image ID fold_3_986 at results\predicted_masks\fold_3_986_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_986, Nucleus 1 at results\single_nucleus_masks\fold_3_986_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_991.png
# Processing image ID: fold_3_991
# Loaded ground truth mask for image ID: fold_3_991
# Image ID fold_3_991: Dice Score = 0.4037, IoU = 0.2529
# Saved predicted mask for image ID fold_3_991 at results\predicted_masks\fold_3_991_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_991, Nucleus 1 at results\single_nucleus_masks\fold_3_991_nucleus_1.png
# Loading image: image_preprocessing\preprocessed_data\preprocessed_test_images\fold_3_995.png
# Processing image ID: fold_3_995
# Loaded ground truth mask for image ID: fold_3_995
# Image ID fold_3_995: Dice Score = 0.1119, IoU = 0.0592
# Saved predicted mask for image ID fold_3_995 at results\predicted_masks\fold_3_995_predicted_mask.png
# Saved individual nucleus mask for image ID fold_3_995, Nucleus 1 at results\single_nucleus_masks\fold_3_995_nucleus_1.png
# Mean Dice Score on Test Set: 0.3076
# Mean IoU Score on Test Set: 0.2058
# Results saved to results\csv\dice_iou_scores.csv

# %% [markdown]
# ### 4.5. One image per nucleus |

# %%
# Block 10

from skimage.filters import threshold_otsu
from scipy import ndimage as ndi  # Import binary_fill_holes from here
from skimage.morphology import disk, remove_small_objects, binary_opening, binary_closing
from skimage import measure  # For contrast enhancement and labeling connected components
from skimage.segmentation import watershed  # Correct import for watershed

# Load the trained model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = UNetPlusPlus(in_channels=3, out_channels=1).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# Custom dataset for test images
class TestDataset(Dataset):
    def __init__(self, img_dir, transform=None):
        self.img_dir = img_dir
        self.image_ids = sorted([file.name.replace('_pp_enhanced.png', '') for file in img_dir.iterdir() if file.name.endswith('_pp_enhanced.png')])
        self.transform = transform

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        img_path = self.img_dir / f'{image_id}_pp_enhanced.png'
        image = imread(img_path).astype(np.float32) / 255.0  # Normalize to [0, 1]
        if self.transform:
            image = self.transform(image)
        return image, image_id

# Define a transformation for the test data
test_transform = transforms.Compose([
    transforms.ToTensor(),  # Converts numpy array to tensor
    transforms.ConvertImageDtype(torch.float32)  # Ensures the image is in float32
])

# DataLoader for test data
test_dataset = TestDataset(preprocessed_test_images, transform=test_transform)
test_loader  = DataLoader(test_dataset, batch_size=1, shuffle=False)


def post_process_instance_segmentation(binary_mask):
    """Apply post-processing to turn binary mask into instance segmentation."""

    # Step 1: Thresholding - If Otsu's method is too aggressive, try other thresholds or manual tuning
    threshold = threshold_otsu(binary_mask)
    binary_mask = binary_mask > threshold  # Binarize using Otsu threshold

    # Optional: Adaptive thresholding or manual thresholding can be applied here if necessary
    # binary_mask = binary_mask > 0.5  # Example of manual thresholding

    # Step 2: Fill holes and apply morphological operations for cleaning
    cleaned_mask = ndi.binary_fill_holes(binary_mask)  # Fill holes in the binary mask

    # Increase the structuring element size to better handle gaps and noise
    cleaned_mask = binary_closing(cleaned_mask, footprint=disk(5))  # Closing with a larger structuring element
    cleaned_mask = binary_opening(cleaned_mask, footprint=disk(3))  # Add opening to remove small artifacts

    # Step 3: Remove small objects based on size threshold
    cleaned_mask = remove_small_objects(cleaned_mask, min_size=50)  # Adjust min_size based on dataset

    # Step 4: Apply distance transform
    distance = ndi.distance_transform_edt(cleaned_mask)  # Compute distance transform

    # Optionally, you can visualize the distance transform for debugging purposes
    # import matplotlib.pyplot as plt
    # plt.imshow(distance, cmap='jet')
    # plt.show()

    # Step 5: Detect local maxima to use as markers for the watershed algorithm
    local_maxi = measure.label(ndi.maximum_filter(distance, size=5))  # Increase filter size to detect better markers

    # Optional: Use the peak_local_max function for more refined marker detection
    #from skimage.feature import peak_local_max
    #local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)), labels=cleaned_mask)
    #markers = ndi.label(local_maxi)[0]

    # Step 6: Apply watershed algorithm
    labels = watershed(-distance, local_maxi, mask=cleaned_mask)

    # Return labeled instance mask where each nucleus is a separate label
    return labels


# Main loop for test-time prediction and saving individual masks
for images, image_ids in test_loader:
    images = images.to(device)

    # Make prediction
    with torch.no_grad():
        outputs = model(images)
        predicted_mask = torch.sigmoid(outputs).squeeze().cpu().numpy()
        predicted_mask = (predicted_mask > 0.5).astype(np.uint8)  # Threshold to binary

    image_id = image_ids[0]
    print(f'Processing image ID: {image_id}')

    # Apply post-processing to generate instance masks
    instance_labels = post_process_instance_segmentation(predicted_mask)

    # Save each nucleus as a separate mask
    for nucleus_id in range(1, instance_labels.max() + 1):
        individual_nucleus_mask = (instance_labels == nucleus_id).astype(np.uint8)  # Extract individual nucleus
        save_path = predicted_masks / f'{image_id}_nucleus_{nucleus_id}.png'
        imsave(save_path, individual_nucleus_mask * 255)  # Save each mask as a binary image
        print(f'Saved nucleus {nucleus_id} mask for image ID {image_id} at {save_path}')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
